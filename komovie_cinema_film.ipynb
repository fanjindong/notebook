# %% [markdown]
# # 抠电影接口调用

# %%
import json
import time
import traceback
import hashlib
import urllib
import operator
import requests
from pprint import pprint

from pymongo import MongoClient, ReturnDocument

class KoudianyingTask():
    # 本地部署，所有和mongo、redis建立链接参数改变
    abstract = True
    _loc = None
    _pro = None  # 生产只可读
    _prow = None  # 生产可读写
    _stg = None
    _dev = None
    _rdb = None

    @property
    def loc(self):
        if self._loc is None:
            _loc = MongoClient('mongodb://localhost:27017')
            self._loc = _loc["boluome"]
        return self._loc

    @property
    def rdb(self):
        if self._rdb is None:
            self._rdb = redis.StrictRedis(
                host='127.0.0.1',
                port='6379',
                db=0,
                charset="utf-8",
                decode_responses=True
            )
        return self._rdb

    @property
    def pro(self):
        if self._pro is None:
            _pro = MongoClient(
                'mongodb://mongoc:Boluome123@139.198.1.168:10017/')
            self._pro = _pro["boluome"]
        return self._pro

    @property
    def prow(self):
        if self._prow is None:
            _prow = MongoClient(
                'mongodb://mongoc:Boluome123@139.198.1.168:10018/')
            self._prow = _prow["boluome"]
        return self._prow

    @property
    def stg(self):
        if self._stg is None:
            _stg = MongoClient(
                'mongodb://mongoc:Boluome123@139.198.1.168:12017/')
            self._stg = _stg["boluome"]
        return self._stg

    @property
    def dev(self):
        if self._dev is None:
            _dev = MongoClient(
                'mongodb://root:Boluome123@139.198.1.168:11017/')
            self._dev = _dev["boluome"]
        return self._dev

server = 'http://api.komovie.cn/movie/service'
channel_id = '189'
md5_key = 'GglrL3WIjp6CUZnj'

k=KoudianyingTask()

# %% [markdown]
# ## 抠电影电影院信息获取

# %%
def city_id_fetch():
    """获取城市列表，作为参数调用获取影院详细接口
    """
    city_list = set()
    action = 'city_Query'
    time_stamp = int(time.time() * 1000)
    hstr = urllib.request.quote(
        "{action}{time_stamp}{md5_key}".format(
            action=action,
            time_stamp=time_stamp,
            md5_key=md5_key
        )
    )
    enc = hashlib.md5(hstr.encode('utf-8')).hexdigest()

    post_data = {"action": action,
                 "time_stamp": time_stamp,
                 "enc": enc}
    headers = {"channel_id": channel_id}


    resp = requests.post(server,
                         headers=headers,
                         params=post_data)
    resp_data = resp.json()

    for item in resp_data['cities']:
        city_id=item['cityId']
        get_cinema_message_from_city_id(city_id)
        break
        print(city_id,'fetch is ok')
    return ['city_id_fetch function is ok']

# %%
def get_cinema_message_from_city_id(city_id):
    """传入参数城市ID,调用接口:通过城市获取影院列表,
       数据插入数据库dianying_cinema_kou,
       并调用get_movie_message_from_city_id()函数
    """
#     cinema_list = set()
    action = 'cinema_Query'
    time_stamp = int(time.time() * 1000)

    hstr = urllib.request.quote(
        "{action}{city_id}{time_stamp}{md5_key}".format(
            action=action,
            city_id=city_id,
            time_stamp=time_stamp,
            md5_key=md5_key
        )
    )
    enc = hashlib.md5(hstr.encode('utf-8')).hexdigest()

    post_data = {"action": action,
                 "city_id": city_id,
                 "time_stamp": time_stamp,
                 "enc": enc}
    headers = {"channel_id": channel_id}


    resp = requests.post(server,
                         headers=headers,
                         params=post_data)
    resp_data = resp.json()

    cinema_data = resp_data['cinemas']
    for cinema in cinema_data:
#             cinema_list.add(cinema['cinemaId'])
        k.loc['dianying_cinema_kou'].update_one(
            {'cinemaId':cinema['cinemaId']}, 
            {'$set': cinema}, 
            upsert=True
        )
    get_movie_message_from_city_id(city_id)

# %% [markdown]
# ## 抠电影获取影院上映的影片列表

# %%
def get_movie_message_from_city_id(city_id):
    """传入城市ID,遍历dianying_cinema_kou表所有影院ID,两者作为参数，
       调用接口：获取影院上映的影片列表，插入数据库，并返回
       get_movie_plans_from_cinema_id()函数"""
    cinema_ids=set()
    for cinema_id in k.loc['dianying_cinema_kou'].find({'cityId':city_id},{'_id':0,'cinemaId':1}):
        cinema_ids.add(cinema_id['cinemaId'])
        
    action = 'movie_Query'
    time_stamp = int(time.time() * 1000)

    hstr = urllib.request.quote(
        "{action}{city_id}{time_stamp}{md5_key}".format(
            action=action,
            city_id=city_id,
            time_stamp=time_stamp,
            md5_key=md5_key
        )
    )
    enc = hashlib.md5(hstr.encode('utf-8')).hexdigest()

    post_data = {
        "action": action,
        "city_id": city_id,
        "time_stamp": time_stamp,
        "enc": enc
    }
    headers = {"channel_id": channel_id}

    resp = requests.post(server,
                         headers=headers,
                         params=post_data)
    resp_data = resp.json()
    

    for cinema_id in cinema_ids:
        for item in resp_data['movies']:
            movie_id=item['movieId']
            
            k.loc['dianying_film_kou'].update_one(
                {'cinemaId':cinema_id,'movieId':movie_id},
                {'$set':item},
                upsert=True
            )
            print(cinema_id,movie_id,'message insert is ok')
        get_movie_plans_from_cinema_id(cinema_id)
        
    return

# %%
def get_movie_plans_from_cinema_id(cinema_id):
    """传入电影院ID,调用接口：查看排期列表,插入数据库"""
    action = 'plan_Query'
    ts = time.time()
    time_stamp = int(ts * 1000)

    plans_data = {}
    
    hstr = urllib.request.quote(
        "{action}{cinema_id}{time_stamp}{md5_key}".format(
            action=action,
            cinema_id=cinema_id,
            time_stamp=time_stamp,
            md5_key=md5_key
        )
    )
    enc = hashlib.md5(hstr.encode('utf-8')).hexdigest()

    post_data = {"action": action,
                 "cinema_id": cinema_id,
                 "time_stamp": time_stamp,
                 "enc": enc}
    headers = {"channel_id": channel_id}

    resp = requests.post(server,headers=headers,params=post_data)
    resp_data = resp.json()

    for item in resp_data.get('plans',[]):
#             if not data[key]:
#                 data[key] = item['movie']
        plans_data.setdefault(item['movieId'],[])
        item.pop('cinema', None)
        item.pop('movie', None)
        plans_data[item['movieId']].append(item)
    
    for movie_id,movie_plans in plans_data.items():
        k.loc['dianying_film_kou'].update_one(
            {'cinemaId':cinema_id,'movieId':movie_id},
            {'$set':{'plans':movie_plans}},
            upsert=True
        )
        print(cinema_id,movie_id,'plans insert is ok')

# %%
if __name__=="__main__":
    city_id_fetch()
# Out:
# 2464 7246 message insert is ok
# 2464 27413 message insert is ok
# 2464 1397643 message insert is ok
# 2464 1344887 message insert is ok
# 2464 1194178 message insert is ok
# 2464 7199 message insert is ok
# 2464 1092316 message insert is ok
# 2464 1473913 message insert is ok
# 2464 1331012 message insert is ok
# 2464 1347927 message insert is ok
# 2464 1175248 message insert is ok
# 2464 1157874 message insert is ok
# 2464 1347074 message insert is ok
# 2464 1593361 message insert is ok
# 2464 387735 message insert is ok
# 2464 1594707 message insert is ok
# 2464 1577050 message insert is ok
# 2464 1580228 message insert is ok
# 2464 1658014 message insert is ok
# 2464 1175248 plans insert is ok
# 2464 1593361 plans insert is ok
# 2464 1594707 plans insert is ok
# 2464 27413 plans insert is ok
# 2464 1577050 plans insert is ok
# 2464 1397643 plans insert is ok
# 2464 1092316 plans insert is ok
# 2464 7246 plans insert is ok
# 2464 7199 plans insert is ok
# 2208 7246 message insert is ok
# 2208 27413 message insert is ok
# 2208 1397643 message insert is ok
# 2208 1344887 message insert is ok
# 2208 1194178 message insert is ok
# 2208 7199 message insert is ok
# 2208 1092316 message insert is ok
# 2208 1473913 message insert is ok
# 2208 1331012 message insert is ok
# 2208 1347927 message insert is ok
# 2208 1175248 message insert is ok
# 2208 1157874 message insert is ok
# 2208 1347074 message insert is ok
# 2208 1593361 message insert is ok
# 2208 387735 message insert is ok
# 2208 1594707 message insert is ok
# 2208 1577050 message insert is ok
# 2208 1580228 message insert is ok
# 2208 1658014 message insert is ok
# 2208 1194178 plans insert is ok
# 2208 1397643 plans insert is ok
# 2208 1331012 plans insert is ok
# 2208 1347927 plans insert is ok
# 2208 7246 plans insert is ok
# 2208 1593361 plans insert is ok
# 2208 1594707 plans insert is ok
# 2208 27413 plans insert is ok
# 2208 1344887 plans insert is ok
# 2208 1473913 plans insert is ok
# 2208 1577050 plans insert is ok
# 2208 1092316 plans insert is ok
# 2208 1580228 plans insert is ok
# 2208 7199 plans insert is ok
# 5346 7246 message insert is ok
# 5346 27413 message insert is ok
# 5346 1397643 message insert is ok
# 5346 1344887 message insert is ok
# 5346 1194178 message insert is ok
# 5346 7199 message insert is ok
# 5346 1092316 message insert is ok
# 5346 1473913 message insert is ok
# 5346 1331012 message insert is ok
# 5346 1347927 message insert is ok
# 5346 1175248 message insert is ok
# 5346 1157874 message insert is ok
# 5346 1347074 message insert is ok
# 5346 1593361 message insert is ok
# 5346 387735 message insert is ok
# 5346 1594707 message insert is ok
# 5346 1577050 message insert is ok
# 5346 1580228 message insert is ok
# 5346 1658014 message insert is ok
# 5346 1175248 plans insert is ok
# 5346 27413 plans insert is ok
# 5346 1344887 plans insert is ok
# 5346 1397643 plans insert is ok
# 5346 1092316 plans insert is ok
# 5346 7246 plans insert is ok
# 5346 7199 plans insert is ok
# 5347 7246 message insert is ok
# 5347 27413 message insert is ok
# 5347 1397643 message insert is ok
# 5347 1344887 message insert is ok
# 5347 1194178 message insert is ok
# 5347 7199 message insert is ok
# 5347 1092316 message insert is ok
# 5347 1473913 message insert is ok
# 5347 1331012 message insert is ok
# 5347 1347927 message insert is ok
# 5347 1175248 message insert is ok
# 5347 1157874 message insert is ok
# 5347 1347074 message insert is ok
# 5347 1593361 message insert is ok
# 5347 387735 message insert is ok
# 5347 1594707 message insert is ok
# 5347 1577050 message insert is ok
# 5347 1580228 message insert is ok
# 5347 1658014 message insert is ok
# 5347 1175248 plans insert is ok
# 5347 1594707 plans insert is ok
# 5347 27413 plans insert is ok
# 5347 1347927 plans insert is ok
# 5347 1397643 plans insert is ok
# 5347 1092316 plans insert is ok
# 5347 7246 plans insert is ok
# 5347 7199 plans insert is ok
# 6824 7246 message insert is ok
# 6824 27413 message insert is ok
# 6824 1397643 message insert is ok
# 6824 1344887 message insert is ok
# 6824 1194178 message insert is ok
# 6824 7199 message insert is ok
# 6824 1092316 message insert is ok
# 6824 1473913 message insert is ok
# 6824 1331012 message insert is ok
# 6824 1347927 message insert is ok
# 6824 1175248 message insert is ok
# 6824 1157874 message insert is ok
# 6824 1347074 message insert is ok
# 6824 1593361 message insert is ok
# 6824 387735 message insert is ok
# 6824 1594707 message insert is ok
# 6824 1577050 message insert is ok
# 6824 1580228 message insert is ok
# 6824 1658014 message insert is ok
# 6824 1175248 plans insert is ok
# 6824 1397643 plans insert is ok
# 6824 27413 plans insert is ok
# 6824 1347927 plans insert is ok
# 6824 1594707 plans insert is ok
# 6824 387735 plans insert is ok
# 6824 1092316 plans insert is ok
# 6824 7246 plans insert is ok
# 6824 7199 plans insert is ok
# 5868 7246 message insert is ok
# 5868 27413 message insert is ok
# 5868 1397643 message insert is ok
# 5868 1344887 message insert is ok
# 5868 1194178 message insert is ok
# 5868 7199 message insert is ok
# 5868 1092316 message insert is ok
# 5868 1473913 message insert is ok
# 5868 1331012 message insert is ok
# 5868 1347927 message insert is ok
# 5868 1175248 message insert is ok
# 5868 1157874 message insert is ok
# 5868 1347074 message insert is ok
# 5868 1593361 message insert is ok
# 5868 387735 message insert is ok
# 5868 1594707 message insert is ok
# 5868 1577050 message insert is ok
# 5868 1580228 message insert is ok
# 5868 1658014 message insert is ok
# 5868 1594707 plans insert is ok
# 5868 27413 plans insert is ok
# 5868 1344887 plans insert is ok
# 5868 1397643 plans insert is ok
# 5868 1092316 plans insert is ok
# 5868 7246 plans insert is ok
# 5868 7199 plans insert is ok
# 1036 7246 message insert is ok
# 1036 27413 message insert is ok
# 1036 1397643 message insert is ok
# 1036 1344887 message insert is ok
# 1036 1194178 message insert is ok
# 1036 7199 message insert is ok
# 1036 1092316 message insert is ok
# 1036 1473913 message insert is ok
# 1036 1331012 message insert is ok
# 1036 1347927 message insert is ok
# 1036 1175248 message insert is ok
# 1036 1157874 message insert is ok
# 1036 1347074 message insert is ok
# 1036 1593361 message insert is ok
# 1036 387735 message insert is ok
# 1036 1594707 message insert is ok
# 1036 1577050 message insert is ok
# 1036 1580228 message insert is ok
# 1036 1658014 message insert is ok
# 1036 1175248 plans insert is ok
# 1036 1194178 plans insert is ok
# 1036 27413 plans insert is ok
# 1036 1347927 plans insert is ok
# 1036 1397643 plans insert is ok
# 1036 1092316 plans insert is ok
# 1036 7246 plans insert is ok
# 1036 7199 plans insert is ok
# 1038 7246 message insert is ok
# 1038 27413 message insert is ok
# 1038 1397643 message insert is ok
# 1038 1344887 message insert is ok
# 1038 1194178 message insert is ok
# 1038 7199 message insert is ok
# 1038 1092316 message insert is ok
# 1038 1473913 message insert is ok
# 1038 1331012 message insert is ok
# 1038 1347927 message insert is ok
# 1038 1175248 message insert is ok
# 1038 1157874 message insert is ok
# 1038 1347074 message insert is ok
# 1038 1593361 message insert is ok
# 1038 387735 message insert is ok
# 1038 1594707 message insert is ok
# 1038 1577050 message insert is ok
# 1038 1580228 message insert is ok
# 1038 1658014 message insert is ok
# 1038 1577050 plans insert is ok
# 1038 1594707 plans insert is ok
# 1038 7246 plans insert is ok
# 1038 7199 plans insert is ok
# 1039 7246 message insert is ok
# 1039 27413 message insert is ok
# 1039 1397643 message insert is ok
# 1039 1344887 message insert is ok
# 1039 1194178 message insert is ok
# 1039 7199 message insert is ok
# 1039 1092316 message insert is ok
# 1039 1473913 message insert is ok
# 1039 1331012 message insert is ok
# 1039 1347927 message insert is ok
# 1039 1175248 message insert is ok
# 1039 1157874 message insert is ok
# 1039 1347074 message insert is ok
# 1039 1593361 message insert is ok
# 1039 387735 message insert is ok
# 1039 1594707 message insert is ok
# 1039 1577050 message insert is ok
# 1039 1580228 message insert is ok
# 1039 1658014 message insert is ok
# 1039 1194178 plans insert is ok
# 1039 1397643 plans insert is ok
# 1039 1347074 plans insert is ok
# 1039 7246 plans insert is ok
# 1039 1347927 plans insert is ok
# 1039 1175248 plans insert is ok
# 1039 1593361 plans insert is ok
# 1039 1594707 plans insert is ok
# 1039 27413 plans insert is ok
# 1039 1344887 plans insert is ok
# 1039 1473913 plans insert is ok
# 1039 1092316 plans insert is ok
# 1039 1658014 plans insert is ok
# 1039 7199 plans insert is ok
# 5872 7246 message insert is ok
# 5872 27413 message insert is ok
# 5872 1397643 message insert is ok
# 5872 1344887 message insert is ok
# 5872 1194178 message insert is ok
# 5872 7199 message insert is ok
# 5872 1092316 message insert is ok
# 5872 1473913 message insert is ok
# 5872 1331012 message insert is ok
# 5872 1347927 message insert is ok
# 5872 1175248 message insert is ok
# 5872 1157874 message insert is ok
# 5872 1347074 message insert is ok
# 5872 1593361 message insert is ok
# 5872 387735 message insert is ok
# 5872 1594707 message insert is ok
# 5872 1577050 message insert is ok
# 5872 1580228 message insert is ok
# 5872 1658014 message insert is ok
# 5872 1594707 plans insert is ok
# 5872 27413 plans insert is ok
# 5872 1344887 plans insert is ok
# 5872 1397643 plans insert is ok
# 5872 1092316 plans insert is ok
# 5872 7246 plans insert is ok
# 5872 7199 plans insert is ok
# 7665 7246 message insert is ok
# 7665 27413 message insert is ok
# 7665 1397643 message insert is ok
# 7665 1344887 message insert is ok
# 7665 1194178 message insert is ok
# 7665 7199 message insert is ok
# 7665 1092316 message insert is ok
# 7665 1473913 message insert is ok
# 7665 1331012 message insert is ok
# 7665 1347927 message insert is ok
# 7665 1175248 message insert is ok
# 7665 1157874 message insert is ok
# 7665 1347074 message insert is ok
# 7665 1593361 message insert is ok
# 7665 387735 message insert is ok
# 7665 1594707 message insert is ok
# 7665 1577050 message insert is ok
# 7665 1580228 message insert is ok
# 7665 1658014 message insert is ok
# 7665 1593361 plans insert is ok
# 7665 1594707 plans insert is ok
# 7665 27413 plans insert is ok
# 7665 1344887 plans insert is ok
# 7665 1397643 plans insert is ok
# 7665 1092316 plans insert is ok
# 7665 7246 plans insert is ok
# 7665 7199 plans insert is ok
# 1043 7246 message insert is ok
# 1043 27413 message insert is ok
# 1043 1397643 message insert is ok
# 1043 1344887 message insert is ok
# 1043 1194178 message insert is ok
# 1043 7199 message insert is ok
# 1043 1092316 message insert is ok
# 1043 1473913 message insert is ok
# 1043 1331012 message insert is ok
# 1043 1347927 message insert is ok
# 1043 1175248 message insert is ok
# 1043 1157874 message insert is ok
# 1043 1347074 message insert is ok
# 1043 1593361 message insert is ok
# 1043 387735 message insert is ok
# 1043 1594707 message insert is ok
# 1043 1577050 message insert is ok
# 1043 1580228 message insert is ok
# 1043 1658014 message insert is ok
# 1043 1175248 plans insert is ok
# 1043 1347074 plans insert is ok
# 1043 1344887 plans insert is ok
# 1043 27413 plans insert is ok
# 1043 1347927 plans insert is ok
# 1043 1594707 plans insert is ok
# 1043 1397643 plans insert is ok
# 1043 1092316 plans insert is ok
# 1043 7246 plans insert is ok
# 1043 7199 plans insert is ok
# 6678 7246 message insert is ok
# 6678 27413 message insert is ok
# 6678 1397643 message insert is ok
# 6678 1344887 message insert is ok
# 6678 1194178 message insert is ok
# 6678 7199 message insert is ok
# 6678 1092316 message insert is ok
# 6678 1473913 message insert is ok
# 6678 1331012 message insert is ok
# 6678 1347927 message insert is ok
# 6678 1175248 message insert is ok
# 6678 1157874 message insert is ok
# 6678 1347074 message insert is ok
# 6678 1593361 message insert is ok
# 6678 387735 message insert is ok
# 6678 1594707 message insert is ok
# 6678 1577050 message insert is ok
# 6678 1580228 message insert is ok
# 6678 1658014 message insert is ok
# 6678 1594707 plans insert is ok
# 6678 1580228 plans insert is ok
# 6678 27413 plans insert is ok
# 6678 1347927 plans insert is ok
# 6678 1577050 plans insert is ok
# 6678 1397643 plans insert is ok
# 6678 7246 plans insert is ok
# 6678 7199 plans insert is ok
# 5783 7246 message insert is ok
# 5783 27413 message insert is ok
# 5783 1397643 message insert is ok
# 5783 1344887 message insert is ok
# 5783 1194178 message insert is ok
# 5783 7199 message insert is ok
# 5783 1092316 message insert is ok
# 5783 1473913 message insert is ok
# 5783 1331012 message insert is ok
# 5783 1347927 message insert is ok
# 5783 1175248 message insert is ok
# 5783 1157874 message insert is ok
# 5783 1347074 message insert is ok
# 5783 1593361 message insert is ok
# 5783 387735 message insert is ok
# 5783 1594707 message insert is ok
# 5783 1577050 message insert is ok
# 5783 1580228 message insert is ok
# 5783 1658014 message insert is ok
# 5783 1397643 plans insert is ok
# 5783 27413 plans insert is ok
# 5783 7246 plans insert is ok
# 5783 7199 plans insert is ok
# 2207 7246 message insert is ok
# 2207 27413 message insert is ok
# 2207 1397643 message insert is ok
# 2207 1344887 message insert is ok
# 2207 1194178 message insert is ok
# 2207 7199 message insert is ok
# 2207 1092316 message insert is ok
# 2207 1473913 message insert is ok
# 2207 1331012 message insert is ok
# 2207 1347927 message insert is ok
# 2207 1175248 message insert is ok
# 2207 1157874 message insert is ok
# 2207 1347074 message insert is ok
# 2207 1593361 message insert is ok
# 2207 387735 message insert is ok
# 2207 1594707 message insert is ok
# 2207 1577050 message insert is ok
# 2207 1580228 message insert is ok
# 2207 1658014 message insert is ok
# 2207 1344887 plans insert is ok
# 2207 27413 plans insert is ok
# 2207 1347927 plans insert is ok
# 2207 1397643 plans insert is ok
# 2207 7246 plans insert is ok
# 2207 7199 plans insert is ok
