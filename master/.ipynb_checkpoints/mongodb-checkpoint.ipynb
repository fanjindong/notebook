# %%
from pymongo import MongoClient, ReturnDocument,errors
from pprint import pprint
import traceback
import redis
import json
import re
import conf
from connection import ConnectionTask
import os
import time
class MyConnectionTask(ConnectionTask):
    @property
    def pro(self):
        return super().pmdb
    @property
    def stg(self):
        return super().smdb
    @property
    def dev(self):
        return super().dmdb
    @property
    def static(self):
        return super().static
    @property
    def rdb(self):
        return super().prdb_paym(2)
    @property
    def pprdb(self):
        return super().prdb_paym(1)
t=m=MyConnectionTask()
c=MyConnectionTask()
m.dev.order_waimai.find_one()==m.dmdb.order_waimai.find_one()
# Out:
# True

# %%
MongoClient("mongodb://root:Boluome123@mongo-m.localdomain,mongo-s1.localdomain,mongo-s2.localdomain/?authSource=admin&replicaSet=foba&readPreference=secondaryPreferred")['boluome']

# %%
mdb = MongoClient("mongodb://root:Boluome123@mongo-s1.localdomain,mongo-s2.localdomain/?authSource=admin&replicaSet=foba&readPreference=secondaryPreferred")['boluome']
start = time.mktime((2017,1,1,0,0,0,0,0,0))*1000
len(mdb.order_lite_list.distinct(
    "customerUserId",
    {"createdAt":{"$gt":start}}
))
# .dianying_cinema_mao.find_one()
# Out:
# 524130

# %%
mdb.city.count({ 'supplier.dianying.maoyan': { '$exists': 1 } })

# %%
result = c.smdb.dianying_cinema_mao.update_one({'cinemaId': 243410},{'$set':{'dis':'222','v':2,'v1':2}},upsert=True)

# %%
result.matched_count,result.modified_count

# %%
# for collection in c.static_ctrip.collection_names():
#     print(collection)
#     data_sync_by_mongo("static_ctrip","static_cluster_ctrip",collection,upsert=False)

# %%
data_sync_by_mongo("static","static_cluster","system.indexes",upsert=False)

# %%
for item in c.static_cluster_ctrip.system.indexes.find({}):
    print(item)

# %%
c.static_cluster_ctrip.system.indexes.find_one()

# %%
list(c.static_ctrip.collection_names())

# %%
list(c.stg.collection_names())

# %%
c['static_cluster'].dianying_film_mao.index_information()
# Out:
# {'__v_-1': {'key': [('__v', -1)], 'ns': 'boluome.dianying_film_mao', 'v': 2},
#  '_id_': {'key': [('_id', 1)], 'ns': 'boluome.dianying_film_mao', 'v': 2},
#  'cinemaId_1': {'key': [('cinemaId', 1)],
#   'ns': 'boluome.dianying_film_mao',
#   'v': 2},
#  'cityId_1': {'key': [('cityId', 1)],
#   'ns': 'boluome.dianying_film_mao',
#   'v': 2},
#  'filmId_1': {'key': [('filmId', 1)],
#   'ns': 'boluome.dianying_film_mao',
#   'v': 2},
#  'incrementVersion_-1': {'key': [('incrementVersion', -1)],
#   'ns': 'boluome.dianying_film_mao',
#   'v': 2}}

# %%
from pymongo import IndexModel
indexes=[]
for name,item in c['static_cluster'].dianying_film_mao.index_information().items():
#     if name=='_id_':
#         continue
    indexes.append(IndexModel(item['key'],name=name))

# %%
indexes
# Out:
# [<pymongo.operations.IndexModel at 0x7f432018bbe8>,
#  <pymongo.operations.IndexModel at 0x7f432018b648>,
#  <pymongo.operations.IndexModel at 0x7f432018bf48>,
#  <pymongo.operations.IndexModel at 0x7f432018b588>,
#  <pymongo.operations.IndexModel at 0x7f432018be28>,
#  <pymongo.operations.IndexModel at 0x7f432018be88>]

# %%
c['test'].dianying_film_mao.create_indexes(indexes)
# Out:
# ['_id_', 'cityId_1', '__v_-1', 'incrementVersion_-1', 'cinemaId_1', 'filmId_1']

# %%
c['static_cluster'].city.index_information().keys()==c['test'].city.index_information().keys()
# Out:
# True

# %% [markdown]
# ### 我要写一个数据同步的封装函数

# %%
for collection in ['city','dianying_cinema_mao','dianying_film_mao']:
    print(collection)
    if collection!="system.indexes":
        c['test'][collection].delete_many({})
    data_sync_by_mongo("static_cluster","test",collection,upsert=False)
    break
# Out:
# city
# >>>691/691

# %%
def data_sync_by_mongo(start, end, database, another_db=None, primary_key="id", upsert=True, query=None,total=None,__v=None):
    """
    将一个环境的数据同步至另一个环境
    Args:
        start(str): import environment[dev,stg,pro]
        end(str): export environment[dev,stg,pro]
        database(str): import mongo database name
        another_db(str): export mongo database name
        primary_key(str): primary key["id",...]
        upsert(bool): True or False
        query(dict): key-value
        total(int): data total number
    Returns:
        out: upsert data
    """
    assert isinstance(start, str)
    assert isinstance(end, str)
    assert isinstance(database, str)
    if another_db is None:
        another_db = database
    assert isinstance(another_db, str)
    if query is None:
        query = {}

    from pymongo import IndexModel
    indexes=[]
    for name,item in m[start][database].index_information().items():
        indexes.append(IndexModel(item['key'],name=name))        
    m[end][another_db].create_indexes(indexes)

    data = m[start][database].find(query, {"_id": 0}, no_cursor_timeout=True)
    total = total if total else data.count()
    count = 0
    for item in data:
        try:
            if upsert:
                m[end][another_db].update_one({primary_key: item.pop(primary_key)},
                                              {"$set": item,
                                               '$currentDate': {'lastUpdatedAt': True}},
                                              upsert=True)
            else:
                m[end][another_db].insert_one(item)
        except:
            traceback.print_exc()
        count += 1
        print(">>>{}/{}".format(count, total),end="\r")

# %%
with open('/data/logs/rainbow_city_data.json') as f:
    rainbow_city_json=json.load(f)

# %%
supplier={}
for item in rainbow_city_json['data']:
    for child in item['child']:
        supplier[child['name']]=child['id']
city_insert('socialSecurity','rainbow',supplier)

# %%
# 更新 waimai.ele 城市列表
with open('/data/ele_citys.json') as f:
    ele_citys=json.load(f)
city_insert('waimai','ele',ele_citys)

# %%
# 更新 piaowu.yongle 城市列表
with open('/data/logs/yongle_citys.json') as f:
    yongle_citys=json.load(f)
city_insert('piaowu','yongle',yongle_citys)

# %%
with open('/data/logs/maoyan_citys.json')as f:
    maoyan_citys = json.load(f)
city_insert('dianying','maoyan',maoyan_citys,clean=True)

# %%
# city.supplier add function 配置服务品类city
def city_insert(order_type,channel,city_data,clean=None):
    """
    配置服务品类city表。
    Args:
        order_type(str): "waimai"
        channel(str): "ele"
        city_data(dict): {'北京':value,'上海':value,...}
        clean(bool): True or False
    """
    del_str=['市','地区','区']
    supplier = 'supplier.{}.{}'.format(order_type,channel)
    if clean:
        c.static_cluster.city.update_many({supplier:{'$exists':True}},{'$unset':{supplier:''}})
    for key,value in city_data.items():
        name=key
        for ds in del_str:
            name=name.replace(ds,'') if ds in name else name
        data=c.static_cluster.city.find({'name':re.compile(name)})
        if data.count()==1:
            name=data[0]['name']
            c.static_cluster.city.update_one({'name':name},{'$set':{supplier:city_data[key]}})
        elif data.count()>1:
            data=c.static_cluster.city.find({'name':name}) 
            if data.count()==0:
                data=c.static_cluster.city.find({'name':re.compile('^'+name)})
            if data.count()==1:
                name=data[0]['name']
                c.static_cluster.city.update_one({'name':name},{'$set':{supplier:city_data[key]}})
            elif data.count()>1:
                print(key,name,'find many city(count>1)')
            elif data.count()<1:
                print(key,name,'find many city(count=0)')
                
        else:
            for item in c.static_cluster.city.find({}):
                if item['name'] in name:
                    c.static_cluster.city.update_one({'name':item['name']},{'$set':{supplier:city_data[key]}})
                    break

# %%
city_insert('home','happylifeplat',city_data,clean=None)

# %%
cityList = [
    {
        "citydata": [
            {
                "name": "阿拉善盟",
                "code": "1529"
            },
            {
                "name": "鞍山市",
                "code": "2103"
            },
            {
                "name": "安庆市",
                "code": "3408"
            },
            {
                "name": "安阳市",
                "code": "4105"
            },
            {
                "name": "阿坝藏族羌族自治州",
                "code": "5132"
            },
            {
                "name": "安顺市",
                "code": "5204"
            },
            {
                "name": "阿里地区",
                "code": "5425"
            },
            {
                "name": "安康市",
                "code": "6109"
            },
            {
                "name": "阿克苏地区",
                "code": "6529"
            },
            {
                "name": "阿勒泰地区",
                "code": "6543"
            },
            {
                "name": "阿拉尔市",
                "code": "659002"
            }
        ],
        "title": "A"
    },
    {
        "citydata": [
            {
                "name": "北京市",
                "code": "1101"
            },
            {
                "name": "保定市",
                "code": "1306"
            },
            {
                "name": "包头市",
                "code": "1502"
            },
            {
                "name": "巴彦淖尔市",
                "code": "1508"
            },
            {
                "name": "本溪市",
                "code": "2105"
            },
            {
                "name": "白山市",
                "code": "2206"
            },
            {
                "name": "白城市",
                "code": "2208"
            },
            {
                "name": "蚌埠市",
                "code": "3403"
            },
            {
                "name": "亳州市",
                "code": "3416"
            },
            {
                "name": "滨州市",
                "code": "3716"
            },
            {
                "name": "北海市",
                "code": "4505"
            },
            {
                "name": "百色市",
                "code": "4510"
            },
            {
                "name": "白沙黎族自治县",
                "code": "469025"
            },
            {
                "name": "保亭黎族苗族自治县",
                "code": "469029"
            },
            {
                "name": "巴中市",
                "code": "5119"
            },
            {
                "name": "毕节市",
                "code": "5205"
            },
            {
                "name": "保山市",
                "code": "5305"
            },
            {
                "name": "宝鸡市",
                "code": "6103"
            },
            {
                "name": "白银市",
                "code": "6204"
            },
            {
                "name": "博尔塔拉蒙古自治州",
                "code": "6527"
            },
            {
                "name": "巴音郭楞蒙古自治州",
                "code": "6528"
            },
            {
                "name": "北屯市",
                "code": "659005"
            }
        ],
        "title": "B"
    },
    {
        "citydata": [
            {
                "name": "承德市",
                "code": "1308"
            },
            {
                "name": "沧州市",
                "code": "1309"
            },
            {
                "name": "长治市",
                "code": "1404"
            },
            {
                "name": "赤峰市",
                "code": "1504"
            },
            {
                "name": "朝阳市",
                "code": "2113"
            },
            {
                "name": "长春市",
                "code": "2201"
            },
            {
                "name": "常州市",
                "code": "3204"
            },
            {
                "name": "滁州市",
                "code": "3411"
            },
            {
                "name": "池州市",
                "code": "3417"
            },
            {
                "name": "长沙市",
                "code": "4301"
            },
            {
                "name": "常德市",
                "code": "4307"
            },
            {
                "name": "郴州市",
                "code": "4310"
            },
            {
                "name": "潮州市",
                "code": "4451"
            },
            {
                "name": "崇左市",
                "code": "4514"
            },
            {
                "name": "澄迈县",
                "code": "469023"
            },
            {
                "name": "昌江黎族自治县",
                "code": "469026"
            },
            {
                "name": "重庆市",
                "code": "5001"
            },
            {
                "name": "重庆郊县",
                "code": "5002"
            },
            {
                "name": "成都市",
                "code": "5101"
            },
            {
                "name": "楚雄彝族自治州",
                "code": "5323"
            },
            {
                "name": "昌都市",
                "code": "5403"
            },
            {
                "name": "昌吉回族自治州",
                "code": "6523"
            }
        ],
        "title": "C"
    },
    {
        "citydata": [
            {
                "name": "大同市",
                "code": "1402"
            },
            {
                "name": "大连市",
                "code": "2102"
            },
            {
                "name": "丹东市",
                "code": "2106"
            },
            {
                "name": "大庆市",
                "code": "2306"
            },
            {
                "name": "大兴安岭地区",
                "code": "2327"
            },
            {
                "name": "东营市",
                "code": "3705"
            },
            {
                "name": "德州市",
                "code": "3714"
            },
            {
                "name": "东莞市",
                "code": "4419"
            },
            {
                "name": "东沙群岛",
                "code": "4421"
            },
            {
                "name": "儋州市",
                "code": "4604"
            },
            {
                "name": "东方市",
                "code": "469007"
            },
            {
                "name": "定安县",
                "code": "469021"
            },
            {
                "name": "德阳市",
                "code": "5106"
            },
            {
                "name": "达州市",
                "code": "5117"
            },
            {
                "name": "大理白族自治州",
                "code": "5329"
            },
            {
                "name": "德宏傣族景颇族自治州",
                "code": "5331"
            },
            {
                "name": "迪庆藏族自治州",
                "code": "5334"
            },
            {
                "name": "定西市",
                "code": "6211"
            }
        ],
        "title": "D"
    },
    {
        "citydata": [
            {
                "name": "鄂尔多斯市",
                "code": "1506"
            },
            {
                "name": "鄂州市",
                "code": "4207"
            },
            {
                "name": "恩施土家族苗族自治州",
                "code": "4228"
            }
        ],
        "title": "E"
    },
    {
        "citydata": [
            {
                "name": "抚顺市",
                "code": "2104"
            },
            {
                "name": "阜新市",
                "code": "2109"
            },
            {
                "name": "阜阳市",
                "code": "3412"
            },
            {
                "name": "福州市",
                "code": "3501"
            },
            {
                "name": "抚州市",
                "code": "3610"
            },
            {
                "name": "佛山市",
                "code": "4406"
            },
            {
                "name": "防城港市",
                "code": "4506"
            }
        ],
        "title": "F"
    },
    {
        "citydata": [
            {
                "name": "赣州市",
                "code": "3607"
            },
            {
                "name": "广州市",
                "code": "4401"
            },
            {
                "name": "桂林市",
                "code": "4503"
            },
            {
                "name": "贵港市",
                "code": "4508"
            },
            {
                "name": "广元市",
                "code": "5108"
            },
            {
                "name": "广安市",
                "code": "5116"
            },
            {
                "name": "甘孜藏族自治州",
                "code": "5133"
            },
            {
                "name": "贵阳市",
                "code": "5201"
            },
            {
                "name": "甘南藏族自治州",
                "code": "6230"
            },
            {
                "name": "果洛藏族自治州",
                "code": "6326"
            },
            {
                "name": "固原市",
                "code": "6404"
            }
        ],
        "title": "G"
    },
    {
        "citydata": [
            {
                "name": "邯郸市",
                "code": "1304"
            },
            {
                "name": "衡水市",
                "code": "1311"
            },
            {
                "name": "呼和浩特市",
                "code": "1501"
            },
            {
                "name": "呼伦贝尔市",
                "code": "1507"
            },
            {
                "name": "葫芦岛市",
                "code": "2114"
            },
            {
                "name": "哈尔滨市",
                "code": "2301"
            },
            {
                "name": "鹤岗市",
                "code": "2304"
            },
            {
                "name": "黑河市",
                "code": "2311"
            },
            {
                "name": "淮安市",
                "code": "3208"
            },
            {
                "name": "杭州市",
                "code": "3301"
            },
            {
                "name": "湖州市",
                "code": "3305"
            },
            {
                "name": "合肥市",
                "code": "3401"
            },
            {
                "name": "淮南市",
                "code": "3404"
            },
            {
                "name": "淮北市",
                "code": "3406"
            },
            {
                "name": "黄山市",
                "code": "3410"
            },
            {
                "name": "菏泽市",
                "code": "3717"
            },
            {
                "name": "鹤壁市",
                "code": "4106"
            },
            {
                "name": "黄石市",
                "code": "4202"
            },
            {
                "name": "黄冈市",
                "code": "4211"
            },
            {
                "name": "衡阳市",
                "code": "4304"
            },
            {
                "name": "怀化市",
                "code": "4312"
            },
            {
                "name": "惠州市",
                "code": "4413"
            },
            {
                "name": "河源市",
                "code": "4416"
            },
            {
                "name": "贺州市",
                "code": "4511"
            },
            {
                "name": "河池市",
                "code": "4512"
            },
            {
                "name": "海口市",
                "code": "4601"
            },
            {
                "name": "红河哈尼族彝族自治州",
                "code": "5325"
            },
            {
                "name": "汉中市",
                "code": "6107"
            },
            {
                "name": "海东市",
                "code": "6302"
            },
            {
                "name": "海北藏族自治州",
                "code": "6322"
            },
            {
                "name": "黄南藏族自治州",
                "code": "6323"
            },
            {
                "name": "海南藏族自治州",
                "code": "6325"
            },
            {
                "name": "海西蒙古族藏族自治州",
                "code": "6328"
            },
            {
                "name": "哈密市",
                "code": "6505"
            },
            {
                "name": "哈密地区",
                "code": "6522"
            },
            {
                "name": "和田地区",
                "code": "6532"
            }
        ],
        "title": "H"
    },
    {
        "citydata": [
            {
                "name": "晋城市",
                "code": "1405"
            },
            {
                "name": "晋中市",
                "code": "1407"
            },
            {
                "name": "锦州市",
                "code": "2107"
            },
            {
                "name": "吉林市",
                "code": "2202"
            },
            {
                "name": "鸡西市",
                "code": "2303"
            },
            {
                "name": "佳木斯市",
                "code": "2308"
            },
            {
                "name": "嘉兴市",
                "code": "3304"
            },
            {
                "name": "金华市",
                "code": "3307"
            },
            {
                "name": "景德镇市",
                "code": "3602"
            },
            {
                "name": "九江市",
                "code": "3604"
            },
            {
                "name": "吉安市",
                "code": "3608"
            },
            {
                "name": "济南市",
                "code": "3701"
            },
            {
                "name": "济宁市",
                "code": "3708"
            },
            {
                "name": "焦作市",
                "code": "4108"
            },
            {
                "name": "济源市",
                "code": "419001"
            },
            {
                "name": "荆门市",
                "code": "4208"
            },
            {
                "name": "荆州市",
                "code": "4210"
            },
            {
                "name": "江门市",
                "code": "4407"
            },
            {
                "name": "揭阳市",
                "code": "4452"
            },
            {
                "name": "嘉峪关市",
                "code": "6202"
            },
            {
                "name": "金昌市",
                "code": "6203"
            },
            {
                "name": "酒泉市",
                "code": "6209"
            }
        ],
        "title": "J"
    },
    {
        "citydata": [
            {
                "name": "开封市",
                "code": "4102"
            },
            {
                "name": "昆明市",
                "code": "5301"
            },
            {
                "name": "克拉玛依市",
                "code": "6502"
            },
            {
                "name": "克孜勒苏柯尔克孜自治州",
                "code": "6530"
            },
            {
                "name": "喀什地区",
                "code": "6531"
            },
            {
                "name": "可克达拉市",
                "code": "659008"
            },
            {
                "name": "昆玉市",
                "code": "659009"
            }
        ],
        "title": "K"
    },
    {
        "citydata": [
            {
                "name": "廊坊市",
                "code": "1310"
            },
            {
                "name": "临汾市",
                "code": "1410"
            },
            {
                "name": "吕梁市",
                "code": "1411"
            },
            {
                "name": "辽阳市",
                "code": "2110"
            },
            {
                "name": "辽源市",
                "code": "2204"
            },
            {
                "name": "连云港市",
                "code": "3207"
            },
            {
                "name": "丽水市",
                "code": "3311"
            },
            {
                "name": "六安市",
                "code": "3415"
            },
            {
                "name": "龙岩市",
                "code": "3508"
            },
            {
                "name": "莱芜市",
                "code": "3712"
            },
            {
                "name": "临沂市",
                "code": "3713"
            },
            {
                "name": "聊城市",
                "code": "3715"
            },
            {
                "name": "洛阳市",
                "code": "4103"
            },
            {
                "name": "漯河市",
                "code": "4111"
            },
            {
                "name": "娄底市",
                "code": "4313"
            },
            {
                "name": "柳州市",
                "code": "4502"
            },
            {
                "name": "来宾市",
                "code": "4513"
            },
            {
                "name": "临高县",
                "code": "469024"
            },
            {
                "name": "乐东黎族自治县",
                "code": "469027"
            },
            {
                "name": "陵水黎族自治县",
                "code": "469028"
            },
            {
                "name": "泸州市",
                "code": "5105"
            },
            {
                "name": "乐山市",
                "code": "5111"
            },
            {
                "name": "凉山彝族自治州",
                "code": "5134"
            },
            {
                "name": "六盘水市",
                "code": "5202"
            },
            {
                "name": "丽江市",
                "code": "5307"
            },
            {
                "name": "临沧市",
                "code": "5309"
            },
            {
                "name": "拉萨市",
                "code": "5401"
            },
            {
                "name": "林芝市",
                "code": "5404"
            },
            {
                "name": "兰州市",
                "code": "6201"
            },
            {
                "name": "陇南市",
                "code": "6212"
            },
            {
                "name": "临夏回族自治州",
                "code": "6229"
            }
        ],
        "title": "L"
    },
    {
        "citydata": [
            {
                "name": "牡丹江市",
                "code": "2310"
            },
            {
                "name": "马鞍山市",
                "code": "3405"
            },
            {
                "name": "茂名市",
                "code": "4409"
            },
            {
                "name": "梅州市",
                "code": "4414"
            },
            {
                "name": "绵阳市",
                "code": "5107"
            },
            {
                "name": "眉山市",
                "code": "5114"
            }
        ],
        "title": "M"
    },
    {
        "citydata": [
            {
                "name": "南京市",
                "code": "3201"
            },
            {
                "name": "南通市",
                "code": "3206"
            },
            {
                "name": "宁波市",
                "code": "3302"
            },
            {
                "name": "南平市",
                "code": "3507"
            },
            {
                "name": "宁德市",
                "code": "3509"
            },
            {
                "name": "南昌市",
                "code": "3601"
            },
            {
                "name": "南阳市",
                "code": "4113"
            },
            {
                "name": "南宁市",
                "code": "4501"
            },
            {
                "name": "内江市",
                "code": "5110"
            },
            {
                "name": "南充市",
                "code": "5113"
            },
            {
                "name": "怒江傈僳族自治州",
                "code": "5333"
            },
            {
                "name": "那曲地区",
                "code": "5424"
            }
        ],
        "title": "N"
    },
    {
        "citydata": [
            {
                "name": "盘锦市",
                "code": "2111"
            },
            {
                "name": "莆田市",
                "code": "3503"
            },
            {
                "name": "萍乡市",
                "code": "3603"
            },
            {
                "name": "平顶山市",
                "code": "4104"
            },
            {
                "name": "濮阳市",
                "code": "4109"
            },
            {
                "name": "攀枝花市",
                "code": "5104"
            },
            {
                "name": "普洱市",
                "code": "5308"
            },
            {
                "name": "平凉市",
                "code": "6208"
            }
        ],
        "title": "P"
    },
    {
        "citydata": [
            {
                "name": "秦皇岛市",
                "code": "1303"
            },
            {
                "name": "齐齐哈尔市",
                "code": "2302"
            },
            {
                "name": "七台河市",
                "code": "2309"
            },
            {
                "name": "衢州市",
                "code": "3308"
            },
            {
                "name": "泉州市",
                "code": "3505"
            },
            {
                "name": "青岛市",
                "code": "3702"
            },
            {
                "name": "潜江市",
                "code": "429005"
            },
            {
                "name": "清远市",
                "code": "4418"
            },
            {
                "name": "钦州市",
                "code": "4507"
            },
            {
                "name": "琼海市",
                "code": "469002"
            },
            {
                "name": "琼中黎族苗族自治县",
                "code": "46903"
            },
            {
                "name": "黔西南布依族苗族自治州",
                "code": "5223"
            },
            {
                "name": "黔东南苗族侗族自治州",
                "code": "5226"
            },
            {
                "name": "黔南布依族苗族自治州",
                "code": "5227"
            },
            {
                "name": "曲靖市",
                "code": "5303"
            },
            {
                "name": "庆阳市",
                "code": "6210"
            }
        ],
        "title": "Q"
    },
    {
        "citydata": [
            {
                "name": "日照市",
                "code": "3711"
            },
            {
                "name": "日喀则市",
                "code": "5402"
            }
        ],
        "title": "R"
    },
    {
        "citydata": [
            {
                "name": "石家庄市",
                "code": "1301"
            },
            {
                "name": "朔州市",
                "code": "1406"
            },
            {
                "name": "沈阳市",
                "code": "2101"
            },
            {
                "name": "四平市",
                "code": "2203"
            },
            {
                "name": "松原市",
                "code": "2207"
            },
            {
                "name": "双鸭山市",
                "code": "2305"
            },
            {
                "name": "绥化市",
                "code": "2312"
            },
            {
                "name": "上海市",
                "code": "3101"
            },
            {
                "name": "苏州市",
                "code": "3205"
            },
            {
                "name": "宿迁市",
                "code": "3213"
            },
            {
                "name": "绍兴市",
                "code": "3306"
            },
            {
                "name": "宿州市",
                "code": "3413"
            },
            {
                "name": "三明市",
                "code": "3504"
            },
            {
                "name": "上饶市",
                "code": "3611"
            },
            {
                "name": "三门峡市",
                "code": "4112"
            },
            {
                "name": "商丘市",
                "code": "4114"
            },
            {
                "name": "十堰市",
                "code": "4203"
            },
            {
                "name": "随州市",
                "code": "4213"
            },
            {
                "name": "神农架林区",
                "code": "429021"
            },
            {
                "name": "邵阳市",
                "code": "4305"
            },
            {
                "name": "韶关市",
                "code": "4402"
            },
            {
                "name": "深圳市",
                "code": "4403"
            },
            {
                "name": "汕头市",
                "code": "4405"
            },
            {
                "name": "汕尾市",
                "code": "4415"
            },
            {
                "name": "三亚市",
                "code": "4602"
            },
            {
                "name": "三沙市",
                "code": "4603"
            },
            {
                "name": "遂宁市",
                "code": "5109"
            },
            {
                "name": "山南市",
                "code": "5405"
            },
            {
                "name": "山南地区",
                "code": "5422"
            },
            {
                "name": "商洛市",
                "code": "6110"
            },
            {
                "name": "石嘴山市",
                "code": "6402"
            },
            {
                "name": "石河子市",
                "code": "659001"
            },
            {
                "name": "双河市",
                "code": "659007"
            }
        ],
        "title": "S"
    },
    {
        "citydata": [
            {
                "name": "天津市",
                "code": "1201"
            },
            {
                "name": "唐山市",
                "code": "1302"
            },
            {
                "name": "太原市",
                "code": "1401"
            },
            {
                "name": "通辽市",
                "code": "1505"
            },
            {
                "name": "铁岭市",
                "code": "2112"
            },
            {
                "name": "通化市",
                "code": "2205"
            },
            {
                "name": "泰州市",
                "code": "3212"
            },
            {
                "name": "台州市",
                "code": "3310"
            },
            {
                "name": "铜陵市",
                "code": "3407"
            },
            {
                "name": "泰安市",
                "code": "3709"
            },
            {
                "name": "天门市",
                "code": "429006"
            },
            {
                "name": "屯昌县",
                "code": "469022"
            },
            {
                "name": "铜仁市",
                "code": "5206"
            },
            {
                "name": "铜川市",
                "code": "6102"
            },
            {
                "name": "天水市",
                "code": "6205"
            },
            {
                "name": "吐鲁番市",
                "code": "6504"
            },
            {
                "name": "塔城地区",
                "code": "6542"
            },
            {
                "name": "图木舒克市",
                "code": "659003"
            },
            {
                "name": "铁门关市",
                "code": "659006"
            }
        ],
        "title": "T"
    },
    {
        "citydata": [
            {
                "name": "乌海市",
                "code": "1503"
            },
            {
                "name": "乌兰察布市",
                "code": "1509"
            },
            {
                "name": "无锡市",
                "code": "3202"
            },
            {
                "name": "温州市",
                "code": "3303"
            },
            {
                "name": "芜湖市",
                "code": "3402"
            },
            {
                "name": "潍坊市",
                "code": "3707"
            },
            {
                "name": "威海市",
                "code": "3710"
            },
            {
                "name": "武汉市",
                "code": "4201"
            },
            {
                "name": "梧州市",
                "code": "4504"
            },
            {
                "name": "五指山市",
                "code": "469001"
            },
            {
                "name": "文昌市",
                "code": "469005"
            },
            {
                "name": "万宁市",
                "code": "469006"
            },
            {
                "name": "文山壮族苗族自治州",
                "code": "5326"
            },
            {
                "name": "渭南市",
                "code": "6105"
            },
            {
                "name": "武威市",
                "code": "6206"
            },
            {
                "name": "吴忠市",
                "code": "6403"
            },
            {
                "name": "乌鲁木齐市",
                "code": "6501"
            },
            {
                "name": "五家渠市",
                "code": "659004"
            }
        ],
        "title": "W"
    },
    {
        "citydata": [
            {
                "name": "邢台市",
                "code": "1305"
            },
            {
                "name": "忻州市",
                "code": "1409"
            },
            {
                "name": "兴安盟",
                "code": "1522"
            },
            {
                "name": "锡林郭勒盟",
                "code": "1525"
            },
            {
                "name": "徐州市",
                "code": "3203"
            },
            {
                "name": "宣城市",
                "code": "3418"
            },
            {
                "name": "厦门市",
                "code": "3502"
            },
            {
                "name": "新余市",
                "code": "3605"
            },
            {
                "name": "新乡市",
                "code": "4107"
            },
            {
                "name": "许昌市",
                "code": "4110"
            },
            {
                "name": "信阳市",
                "code": "4115"
            },
            {
                "name": "襄阳市",
                "code": "4206"
            },
            {
                "name": "孝感市",
                "code": "4209"
            },
            {
                "name": "咸宁市",
                "code": "4212"
            },
            {
                "name": "仙桃市",
                "code": "429004"
            },
            {
                "name": "湘潭市",
                "code": "4303"
            },
            {
                "name": "湘西土家族苗族自治州",
                "code": "4331"
            },
            {
                "name": "西双版纳傣族自治州",
                "code": "5328"
            },
            {
                "name": "西安市",
                "code": "6101"
            },
            {
                "name": "咸阳市",
                "code": "6104"
            },
            {
                "name": "西宁市",
                "code": "6301"
            }
        ],
        "title": "X"
    },
    {
        "citydata": [
            {
                "name": "阳泉市",
                "code": "1403"
            },
            {
                "name": "运城市",
                "code": "1408"
            },
            {
                "name": "营口市",
                "code": "2108"
            },
            {
                "name": "延边朝鲜族自治州",
                "code": "2224"
            },
            {
                "name": "伊春市",
                "code": "2307"
            },
            {
                "name": "盐城市",
                "code": "3209"
            },
            {
                "name": "扬州市",
                "code": "3210"
            },
            {
                "name": "鹰潭市",
                "code": "3606"
            },
            {
                "name": "宜春市",
                "code": "3609"
            },
            {
                "name": "烟台市",
                "code": "3706"
            },
            {
                "name": "宜昌市",
                "code": "4205"
            },
            {
                "name": "岳阳市",
                "code": "4306"
            },
            {
                "name": "益阳市",
                "code": "4309"
            },
            {
                "name": "永州市",
                "code": "4311"
            },
            {
                "name": "阳江市",
                "code": "4417"
            },
            {
                "name": "云浮市",
                "code": "4453"
            },
            {
                "name": "玉林市",
                "code": "4509"
            },
            {
                "name": "宜宾市",
                "code": "5115"
            },
            {
                "name": "雅安市",
                "code": "5118"
            },
            {
                "name": "玉溪市",
                "code": "5304"
            },
            {
                "name": "延安市",
                "code": "6106"
            },
            {
                "name": "榆林市",
                "code": "6108"
            },
            {
                "name": "玉树藏族自治州",
                "code": "6327"
            },
            {
                "name": "银川市",
                "code": "6401"
            },
            {
                "name": "伊犁哈萨克自治州",
                "code": "6540"
            }
        ],
        "title": "Y"
    },
    {
        "citydata": [
            {
                "name": "张家口市",
                "code": "1307"
            },
            {
                "name": "镇江市",
                "code": "3211"
            },
            {
                "name": "舟山市",
                "code": "3309"
            },
            {
                "name": "漳州市",
                "code": "3506"
            },
            {
                "name": "淄博市",
                "code": "3703"
            },
            {
                "name": "枣庄市",
                "code": "3704"
            },
            {
                "name": "郑州市",
                "code": "4101"
            },
            {
                "name": "周口市",
                "code": "4116"
            },
            {
                "name": "驻马店市",
                "code": "4117"
            },
            {
                "name": "株洲市",
                "code": "4302"
            },
            {
                "name": "张家界市",
                "code": "4308"
            },
            {
                "name": "珠海市",
                "code": "4404"
            },
            {
                "name": "湛江市",
                "code": "4408"
            },
            {
                "name": "肇庆市",
                "code": "4412"
            },
            {
                "name": "中山市",
                "code": "4420"
            },
            {
                "name": "自贡市",
                "code": "5103"
            },
            {
                "name": "资阳市",
                "code": "5120"
            },
            {
                "name": "遵义市",
                "code": "5203"
            },
            {
                "name": "昭通市",
                "code": "5306"
            },
            {
                "name": "张掖市",
                "code": "6207"
            },
            {
                "name": "中卫市",
                "code": "6405"
            }
        ],
        "title": "Z"
    }
]

city_data = {}
for item in cityList:
    for keys in item['citydata']:
        name = keys['name']
        code = keys['code']
        city_data[name] = code
print(city_data)
# Out:
# {'阿拉善盟': '1529', '鞍山市': '2103', '安庆市': '3408', '安阳市': '4105', '阿坝藏族羌族自治州': '5132', '安顺市': '5204', '阿里地区': '5425', '安康市': '6109', '阿克苏地区': '6529', '阿勒泰地区': '6543', '阿拉尔市': '659002', '北京市': '1101', '保定市': '1306', '包头市': '1502', '巴彦淖尔市': '1508', '本溪市': '2105', '白山市': '2206', '白城市': '2208', '蚌埠市': '3403', '亳州市': '3416', '滨州市': '3716', '北海市': '4505', '百色市': '4510', '白沙黎族自治县': '469025', '保亭黎族苗族自治县': '469029', '巴中市': '5119', '毕节市': '5205', '保山市': '5305', '宝鸡市': '6103', '白银市': '6204', '博尔塔拉蒙古自治州': '6527', '巴音郭楞蒙古自治州': '6528', '北屯市': '659005', '承德市': '1308', '沧州市': '1309', '长治市': '1404', '赤峰市': '1504', '朝阳市': '2113', '长春市': '2201', '常州市': '3204', '滁州市': '3411', '池州市': '3417', '长沙市': '4301', '常德市': '4307', '郴州市': '4310', '潮州市': '4451', '崇左市': '4514', '澄迈县': '469023', '昌江黎族自治县': '469026', '重庆市': '5001', '重庆郊县': '5002', '成都市': '5101', '楚雄彝族自治州': '5323', '昌都市': '5403', '昌吉回族自治州': '6523', '大同市': '1402', '大连市': '2102', '丹东市': '2106', '大庆市': '2306', '大兴安岭地区': '2327', '东营市': '3705', '德州市': '3714', '东莞市': '4419', '东沙群岛': '4421', '儋州市': '4604', '东方市': '469007', '定安县': '469021', '德阳市': '5106', '达州市': '5117', '大理白族自治州': '5329', '德宏傣族景颇族自治州': '5331', '迪庆藏族自治州': '5334', '定西市': '6211', '鄂尔多斯市': '1506', '鄂州市': '4207', '恩施土家族苗族自治州': '4228', '抚顺市': '2104', '阜新市': '2109', '阜阳市': '3412', '福州市': '3501', '抚州市': '3610', '佛山市': '4406', '防城港市': '4506', '赣州市': '3607', '广州市': '4401', '桂林市': '4503', '贵港市': '4508', '广元市': '5108', '广安市': '5116', '甘孜藏族自治州': '5133', '贵阳市': '5201', '甘南藏族自治州': '6230', '果洛藏族自治州': '6326', '固原市': '6404', '邯郸市': '1304', '衡水市': '1311', '呼和浩特市': '1501', '呼伦贝尔市': '1507', '葫芦岛市': '2114', '哈尔滨市': '2301', '鹤岗市': '2304', '黑河市': '2311', '淮安市': '3208', '杭州市': '3301', '湖州市': '3305', '合肥市': '3401', '淮南市': '3404', '淮北市': '3406', '黄山市': '3410', '菏泽市': '3717', '鹤壁市': '4106', '黄石市': '4202', '黄冈市': '4211', '衡阳市': '4304', '怀化市': '4312', '惠州市': '4413', '河源市': '4416', '贺州市': '4511', '河池市': '4512', '海口市': '4601', '红河哈尼族彝族自治州': '5325', '汉中市': '6107', '海东市': '6302', '海北藏族自治州': '6322', '黄南藏族自治州': '6323', '海南藏族自治州': '6325', '海西蒙古族藏族自治州': '6328', '哈密市': '6505', '哈密地区': '6522', '和田地区': '6532', '晋城市': '1405', '晋中市': '1407', '锦州市': '2107', '吉林市': '2202', '鸡西市': '2303', '佳木斯市': '2308', '嘉兴市': '3304', '金华市': '3307', '景德镇市': '3602', '九江市': '3604', '吉安市': '3608', '济南市': '3701', '济宁市': '3708', '焦作市': '4108', '济源市': '419001', '荆门市': '4208', '荆州市': '4210', '江门市': '4407', '揭阳市': '4452', '嘉峪关市': '6202', '金昌市': '6203', '酒泉市': '6209', '开封市': '4102', '昆明市': '5301', '克拉玛依市': '6502', '克孜勒苏柯尔克孜自治州': '6530', '喀什地区': '6531', '可克达拉市': '659008', '昆玉市': '659009', '廊坊市': '1310', '临汾市': '1410', '吕梁市': '1411', '辽阳市': '2110', '辽源市': '2204', '连云港市': '3207', '丽水市': '3311', '六安市': '3415', '龙岩市': '3508', '莱芜市': '3712', '临沂市': '3713', '聊城市': '3715', '洛阳市': '4103', '漯河市': '4111', '娄底市': '4313', '柳州市': '4502', '来宾市': '4513', '临高县': '469024', '乐东黎族自治县': '469027', '陵水黎族自治县': '469028', '泸州市': '5105', '乐山市': '5111', '凉山彝族自治州': '5134', '六盘水市': '5202', '丽江市': '5307', '临沧市': '5309', '拉萨市': '5401', '林芝市': '5404', '兰州市': '6201', '陇南市': '6212', '临夏回族自治州': '6229', '牡丹江市': '2310', '马鞍山市': '3405', '茂名市': '4409', '梅州市': '4414', '绵阳市': '5107', '眉山市': '5114', '南京市': '3201', '南通市': '3206', '宁波市': '3302', '南平市': '3507', '宁德市': '3509', '南昌市': '3601', '南阳市': '4113', '南宁市': '4501', '内江市': '5110', '南充市': '5113', '怒江傈僳族自治州': '5333', '那曲地区': '5424', '盘锦市': '2111', '莆田市': '3503', '萍乡市': '3603', '平顶山市': '4104', '濮阳市': '4109', '攀枝花市': '5104', '普洱市': '5308', '平凉市': '6208', '秦皇岛市': '1303', '齐齐哈尔市': '2302', '七台河市': '2309', '衢州市': '3308', '泉州市': '3505', '青岛市': '3702', '潜江市': '429005', '清远市': '4418', '钦州市': '4507', '琼海市': '469002', '琼中黎族苗族自治县': '46903', '黔西南布依族苗族自治州': '5223', '黔东南苗族侗族自治州': '5226', '黔南布依族苗族自治州': '5227', '曲靖市': '5303', '庆阳市': '6210', '日照市': '3711', '日喀则市': '5402', '石家庄市': '1301', '朔州市': '1406', '沈阳市': '2101', '四平市': '2203', '松原市': '2207', '双鸭山市': '2305', '绥化市': '2312', '上海市': '3101', '苏州市': '3205', '宿迁市': '3213', '绍兴市': '3306', '宿州市': '3413', '三明市': '3504', '上饶市': '3611', '三门峡市': '4112', '商丘市': '4114', '十堰市': '420 ...

# %% [markdown]
# ## motor 使用

# %%
from motor.motor_asyncio import AsyncIOMotorClient
import asyncio
import conf
import pickle

def mdb_setup():
#     client = AsyncIOMotorClient('mongodb://root:Boluome123@192.168.0.7:27017,192.168.0.10:27017/?authSource=admin&replicaSet=foba')
#     client = AsyncIOMotorClient("mongodb://root:Boluome123@192.168.0.14")
#     client = AsyncIOMotorClient("mongodb://root:Boluome123@192.168.1.21,192.168.1.22/?replicaSet=foba&authSource=admin")
#     client = AsyncIOMotorClient("mongodb://root:Boluome123@192.168.1.6, 192.168.1.7/?replicaSet=foba&authSource=admin")
#     client = AsyncIOMotorClient('mongodb://root:Boluome123@mongo-m.localdomain,mongo-s.localdomain/?authSource=admin&replicaSet=foba')
    
    return client.ctrip
mdb=mdb_setup()

# %%
async def do_find_one():
#     resp_order = await mdb['jiudian_hotels_7'].find_one()
    resp_order = await mdb['city'].find_one({})
    print(resp_order)
    return resp_order
loop = asyncio.get_event_loop()
loop.run_until_complete(do_find_one())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-52b33a9ed064> in <module>()
#       5     return resp_order
#       6 loop = asyncio.get_event_loop()
# ----> 7 loop.run_until_complete(do_find_one())
#
# /usr/local/python3/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     452         future.add_done_callback(_run_until_complete_cb)
#     453         try:
# --> 454             self.run_forever()
#     455         except:
#     456             if new_task and future.done() and not future.cancelled():
#
# /usr/local/python3/lib/python3.6/asyncio/base_events.py in run_forever(self)
#     406         self._check_closed()
#     407         if self.is_running():
# --> 408             raise RuntimeError('This event loop is already running')
#     409         if events._get_running_loop() is not None:
#     410             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# None

# %% [markdown]
# ### 更新用户地址经纬度user_contact

# %%
import requests
import time
URL="http://api.map.baidu.com/cloudgc/v1?ak=9e3ReHPB78orvzAoBd8gz7VonILv4FqE&address={}"
err_id=[]
count=0
for item in m.pro.user_contact.find({'userSource':{'$exists':1}}):
    user_id=item['userId']
    count+=1
#     time.sleep(1)
    print(count,end='\r')
    try:
        for key,value in item.get('contacts',{}).items():
            address=value['province']+value['city']+value['county']+value['address']
#             print(key,address,URL.format(address))

            resp=requests.get(URL.format(address)).json()
            location=resp['result'][0]['location']
#             pprint(location)
            m.pro.user_contact.update_one({'userId':user_id},
                                          {'$set':{'contacts.{}.latitude'.format(key):location['lat'],
                                                  'contacts.{}.longitude'.format(key):location['lng']}})
    except Exception as why :
        err_id.append(user_id)
        print(resp)
print(err_id)

# %%
# 携程酒店市区，商圈及其经纬度存贮至redis
import json
import requests
import time
URL="http://api.map.baidu.com/cloudgc/v1?ak=9e3ReHPB78orvzAoBd8gz7VonILv4FqE&address={}"

with open('/data/ctrip/city.json') as f:
    ctrip_city=json.load(f)
city={}
count=0
for item in ctrip_city:
    city_name=item['CityName']
    city_code=item['CityCode']
    city[city_code]=city_name
    for district in item['Districts']:
        count+=1
        score=district['Id']
        address=city_name+'-'+district['Name']
        resp=requests.get(URL.format(address)).json()
        try:
            location=resp['result'][0]['location']
        except:
            print(resp)
        loc=[round(location['lng'],4),round(location['lat'],4)]
        c.srdb_new(0).zadd('ctrip_districts_map',int(score),address+'-'+ str(loc))
        print(count,end='\r')

# %%
# 携程酒店市区，商圈及其经纬度存贮至redis
with open('/data/ctrip/business_zone.json') as f:
    business_zone=json.load(f)
URL="http://api.map.baidu.com/cloudgc/v1?ak=9e3ReHPB78orvzAoBd8gz7VonILv4FqE&address={}"

count=0
for item in business_zone:
    count+=1
    zone_name=item['ZoneName']
    city_code=item['City']
    city_name=c.srdb_new(0).zrangebyscore('ctrip_districts_map',city_code,city_code)
    if not city_name:
#         print(city_code,city_name,zone_name)
        continue
    else:
        city_name=city_name[0]
    score=item['Zone']
#     print(city_name,score)
    city_name=city_name.split('-')
    city_name[-1]=zone_name
    address='-'.join(city_name)
    resp=requests.get(URL.format(address)).json()
    try:
        location=resp['result'][0]['location']
    except:
        print(resp['result'])
    loc=[round(location['lng'],4),round(location['lat'],4)]
    c.srdb_new(0).zadd('ctrip_business_zone_map',int(score),address+'-'+ str(loc))
    print(count,end='\r')

# %%
# 调用百度地图接口，获取经纬度，写入airport数据库
import requests
import time
URL="http://api.map.baidu.com/cloudgc/v1?ak=9e3ReHPB78orvzAoBd8gz7VonILv4FqE&address={}"
err_id=[]
count=0
for item in airport:
    count+=1
    print(count,end='\r')
    try:
        address=item['airport'] if item["city"] in item['airport'] else item['city']+item['airport']
        resp=requests.get(URL.format(address)).json()
        location=resp['result'][0]['location']
#         location["loc"]=location["lng"], location["lat"]
#         print(address,location)
        item['loc']=[location["lng"], location["lat"]]
        m.dev.airport.update_one({'airport':item['airport']},
                                 {'$set':item},
                                upsert=True)
    except Exception as why :
        err_id.append(address)
        print(resp)
#     break
print(err_id)

# %%
# 提取jiudian_hotels部分子字段到根目录
count=0
for item in m.static.jiudian_hotels.find({},
                                       {'awards.HotelStarRate':1,
                                       'awards.HotelStarLicence':1,
                                       'rooms':1,
                                       '_id':0,
                                       'id':1,
                                       'address':1}):
#     amentities=set()
#     for room in item.get('rooms',[]):
#         if 'amentities' not in room or not room.get('amentities',[]):
#             continue
#         for ament in room.get('amentities',[]):
#             if 'RoomAmenityCode' not in ament:
#                 continue
#             amentities.add(ament['RoomAmenityCode'])
    count+=1
    zoneCode=set()
    address=item.get('address',{}).get('Zone',[])
    if isinstance(address,dict):
        address=[address]
    for zone in address:
        if 'ZoneCode' not in zone:
            continue
        zoneCode.add(zone.get('ZoneCode',''))
    m.static.jiudian_hotels.update_one({'id':item['id']}, 
                                       {'$set':{
#                                            'starRate':item.get('awards',{}).get('HotelStarRate',''), 
#                                             'starLicence':item.get('awards',{}).get('HotelStarLicence',''),
#                                             'amentities':list(amentities),
                                            'zoneCode':list(zoneCode),
                                       }})
    print(count,end='\r')

# %%
# 清理jiudian_hotels.images字段
count=0
for item in c.static.jiudian_hotels.find({'images':{'$ne':[]}},{"_id":0,'id':1,'images':1}):
    images=[]
    for image in item['images']:
        if None in [image['category'],image['caption'],image['url'],image.get('InvBlockCode')]:
            continue
        else:
            images.append(image)
    if not images:
        count+=1
    if images==item['images']:
        continue
    c.static.jiudian_hotels.update_one({'id':item['id']},{'$set':{'images':images}})
    print(count,end='\r')
    if count==100000:
        break

# %%
#重构 weizhang_plateNum
import json
with open('/data/diandian.json') as f:
    diandian=json.load(f)
city_map={}
for province in diandian:
    for city in province['list']:
        city_map[city['city'].replace('市','')]={'cityId':city['cityId'],'cityName':city['city']}
# print(city_map)
city_set=set()
for item in c.smdb.weizhang_plateNum.find({}):
    if item.get('cityName') in [None,'null']:
        continue
    city_set.add(item['cityName'])
#     print(item['cityName'],city_map.get(item['cityName']))
for city in city_set:
    if city not in city_map:
        print(city,'不存在')
        continue
    print(city,city_map[city])
    c.smdb.weizhang_plateNum.update_many({'cityName':city},{'$set':city_map[city]})
#     break
# print(city_set)

# %%
user_id_set=set()
for item in c.smdb.weizhang_plateNum.find({}):
    user_id=item.get('customerUserId') or item.get('userId')
    if not user_id:
        print(item)
        continue
    if user_id in user_id_set:
        continue
    user_id_set.add(user_id) 
    resp=c.smdb.weizhang_plateNum.find({'$or':[{'userId':user_id},{'customerUserId':user_id}]},{'_id':0})
    
    c.smdb.weizhang_plateNum.insert_one({'__v':1,'customerUserId':user_id,'plateNumberList':list(resp)})
#     print(user_id)

# %%
user_id_set=set()
for item in c.smdb.weizhang_plateNum.find({}):
    user_list=set()
    customer_user_id=item.get('customerUserId')
    for plate_number in item.get('plateNumberList',[]):
        user_list.add(plate_number['userId']) if 'userId' in plate_number else 0
    print(customer_user_id,','.join(list(user_list)))
    c.smdb.weizhang_plateNum.update_one({'customerUserId':customer_user_id},{'$set':{'userId':','.join(list(user_list))}})

# %%
c.pmdb.weizhang_plateNum.update_many({},{"$rename":{"customerUserId":"user_id"}})
c.pmdb.weizhang_plateNum.update_many({},{"$rename":{"userId":"customerUserId"}})
c.pmdb.weizhang_plateNum.update_many({},{"$rename":{"user_id":"userId"}})

# %%
import redis
mongo_data=c.dmdb.order_huafei.find_one({'id':'bl001817612648448'},{'_id':0})
rrdb = redis.StrictRedis(host='192.168.0.6',port=16379,db=0,charset="UTF-8",decode_responses=True)
resp=rrdb.execute_command("jget", "o:bl001818776567827","/")
# mongo_data==json.loads(resp)
# json.loads(resp)

# %%
# # 酒店订单补cityId字段
# count=0
# for item in c.dmdb.order_jiudian.find({},{'_id':0,'id':1,'HotelId':1},sort=[('_id',-1)]):
#     resp=c.static.jiudian_hotels.find_one({'id':item['HotelId']},{'cityCode':1})
#     city_id=''
#     if resp:
#         city_id=resp['cityCode']
#     c.dmdb.order_jiudian.update_one({'id':item['id']},{'$set':{'cityId':city_id}})
#     print(item['id'])
# #     break

# %%
# qunar酒店分析: {city:[{name:,code}]
qunar_city_map={}
count=0
for item in c.static.jiudian_qunar_hotels.find(
    {'city':{'$exists':True},'district':{'$exists':True}},
    {'_id':0}):
    if not (item.get('city') and item.get('district')):
        continue
    qunar_city_map.setdefault(item['city'],[])
    value={'name':item['district'],'code':item['district']}
    if value in qunar_city_map[item['city']]:
        continue
    qunar_city_map[item['city']].append(value)
    count+=1
    print(count,end='\r')

qunar_city_map

# %%
with open('/data/qunar/qunar_city_map.json','w') as f:
    json.dump(qunar_city_map,f,ensure_ascii=False,indent=2)

# %%
import time
timestamp = time.mktime((2017,12,18,0,0,0,0,0,0))*1000

# %%
count=0
data=[]
order_id_list=[]
for item in c.pmdb.order_lite_list_backup.find({},{'_id':0}, no_cursor_timeout=True):
    data.append(item)
    order_id_list.append(item['id'])
    if len(data) == 100:
        c.pmdb.order_lite_list.insert_many(data)
        data=[]
        order_id_list=[]
        count+=100
        print(count,end='\r')
if data:
    c.pmdb.order_lite_list.insert_many(data)

# %%
len(data)

# %%
count=0
for item in c.pmdb.order_waimai.find({'createdAt':{'$lte':timestamp}},{'_id':0}):
    c.pmdb.order_waimai_backup.insert_one(item)
    c.pmdb.order_waimai.delete_one({'id':item['id']})
    count+=1
    print(count,end='\r')

# %%
from pymongo import MongoClient
mc = MongoClient('mongodb://root:Boluome123@192.168.0.7,192.168.0.10/?authSource=admin&replicaSet=foba&readPreference=secondaryPreferred')
database = mc['boluome']
mc = MongoClient('mongodb://root:Boluome123@staticmongo-m.localdomain,staticmongo-s1.localdomain,staticmongo-s2.localdomain/?authSource=admin&readPreference=secondaryPreferred')
database = mc['boluome']

# %%
database.order_waimai.find_one({})

# %%
import time
day_num=60
for order_lite in c.pmdb.order_lite_list.find({'status': {'$in': [2, 3, 12]},
                                                     'createdAt': {'$gte': (time.time() - 3600 * 24 * day_num) * 1000,
                                                                   '$lt': (time.time() - 3600) * 1000}},
                                                    {'id': 1, '_id': 0}):
    json_doc = c.prrdb(0).execute_command('JGET', 'o:{}'.format(order_lite['id']), '/')
    if not json_doc:
        print(order_lite['id'],'no jsonDoc')
        continue
    order_message = json.loads(json_doc)
    if 'paymentSerial' in order_message:
        payment_serial = order_message.get('paymentSerial')
    elif 'paidList' in order_message:
        payment_serial = order_message.get('paidList')[0]
    else:
        print(order_lite['id'],'no payment')
        continue
    if c.prdb_paym(0).hget('p:{}:{}'.format(order_message['appCode'], payment_serial), 'status') != 2:
        print(order_lite['id'],'paymentStatus no 2')
        continue
