# %%
# 测试环境 :
#     appKey：bb0b3ad64c9e5eb06c2fb6f163bf179e79051bd5c9b652fc45dc68a2b5dd23c6
#     secretKey ：4ed8b056c32939b9fd66987470b3e9fb720bdded02197e678e516bdcdf810833
#     渠道id：1200
#     测试环境地址：http://test1.thirdpart.kaolatest.netease.com/api/接口名称
# 接口文档地址：https://github.com/kaola-thirdpart/netease-kaola-thirdpart/wiki

# %%
import requests
import time
import json
import os
import urllib.parse
import hashlib
# 系统参数：

# 名称	类型	是否必须	描述
# timestamp	string	Y	时间戳，格式为yyyy-mm-dd HH:mm:ss，例如：2013-05-06 13:52:03。考拉API服务端允许客户端请求时间误差为6分钟。
# app_key	string	Y	分配给应用的AppKey ，创建应用时可获得
# v	string	Y	API协议版本，可选值:1.0。
# sign	string	Y	对 API 调用参数（除sign外）进行 md5 加密获得。获取方法参考如下1.4.1
# sign_method	string	Y	参数的加密方法选择，可选值是：md5

# test
# url = 'http://test1.thirdpart.kaolatest.netease.com/api/'
# channel_id = '1200'
# app_key = 'bb0b3ad64c9e5eb06c2fb6f163bf179e79051bd5c9b652fc45dc68a2b5dd23c6'
# secret_key = '4ed8b056c32939b9fd66987470b3e9fb720bdded02197e678e516bdcdf810833'

channel_id = '35195'
app_key = '1912cc049d1f66b2daf49451dfb351b48cf7ba9d72bf591fc1f294c451c94450'
secret_key = '5295226c17645d477c5f19bebd947c9949eb9e8c37595abf6d1a6081b8a59d37'
url = 'http://thirdpart.kaola.com/api/'

def concat_params(params):
    pairs = []
    for key in sorted(params):
        if key == 'sign':
            continue
        val = params[key]
        pairs.append("{}{}".format(key, val))
    return ''.join(pairs)
def gen_sign(params, consumer_secret):
    # 根据参数名称（除签名和图片）将所有请求参数按照字母先后顺序排序:key + value .... key + value
    # 例如：将foo=1,bar=2,baz=3 排序为bar=2,baz=3,foo=1，参数名和参数值链接后，得到拼装字符串bar2baz3foo1
    # 系统同时支持MD5加密方式: md5：将secretKey 拼接到参数字符串头、尾进行md5加密后，再转化成大写，
    # 格式是：byte2hex(md5(secretKeykey1value1key2value2...secretKey)) 
    # 注：hex为自定义方法，JAVA中MD5是对字节数组加密，加密结果是16字节，我们需要的是32位的大写字符串
    params = concat_params(params)
    to_hash = hashlib.md5(bytes('{consumer_secret}{params}{consumer_secret}'.format(params=params,consumer_secret=consumer_secret),'utf-8'))
    sign = to_hash.hexdigest()
    return sign.upper()

# %%
def query_order_status(data):
    """渠道订单状态查询，接口地址：queryOrderStatus"""
    # channelId	String	是	渠道商ID	
    # timestamp	String	是	时间戳	
    # v	String	是	Api版本	
    # sign_method	String	是	签名方法	
    # app_key	String	是	考拉分发的appKey	
    # sign	String	是	签名	
    # thirdPartOrderId	String	是	分销商订单ID
    body = {
        "channelId":channel_id,
        "timestamp":time.strftime("%Y-%m-%d %H:%M:%S"),
        "v":"1.0",
        "sign_method":"md5",
        "app_key":app_key,
        "sign":'',
        "thirdPartOrderId":data['orderId']
    }
    body['sign'] = gen_sign(body,secret_key)
    resp = requests.post(url+'queryOrderStatus',params=body)
    return resp.json()
query_order_status({"orderId":"me004232688699697"})
# Out:
# {'recCode': -200, 'recMeg': '获取订单信息异常'}

# %%
def query_all_goods_id():
    """获取商品skuid列表，查询自己渠道下所有的商品skuid列表。
    接口说明：
    渠道下所有商品id查询，接口地址：queryAllGoodsId"""
    
    # channelId	String	是	渠道商ID	
    # timestamp	String	是	时间戳	
    # v	String	是	Api版本	
    # sign_method	String	是	签名方法	
    # app_key	String	是	考拉分发的appKey	
    # sign	String	是	签名
    body = {
        "channelId":channel_id,
        "timestamp":time.strftime("%Y-%m-%d %H:%M:%S"),
        "v":"1.0",
        "sign_method":"md5",
        "app_key":app_key,
        "sign":'',
    }
    body['sign'] = gen_sign(body,secret_key)
    resp = requests.post(url+'queryAllGoodsId',params=body)
    return resp.json()
query_all_goods_id()
# Out:
# {'goodsInfo': ['00000020130',
#   '00000020140',
#   '00000022000',
#   '00000224270',
#   '00000224270',
#   '00000224270',
#   '00000224270',
#   '00000224270',
#   '00000224280',
#   '00000224280',
#   '00000224280',
#   '00000224280',
#   '00000224280',
#   '00000224290',
#   '00000224290',
#   '00000224290',
#   '00000224290',
#   '00000224290',
#   '00000282461',
#   '00000282461',
#   '00000282461',
#   '00000282461',
#   '00000282461',
#   '00000282461',
#   '00000282461',
#   '00000282461',
#   '00000282461',
#   '00000284391',
#   '00000284391',
#   '00000284391',
#   '00000284391',
#   '00000284391',
#   '00000284391',
#   '00000284391',
#   '00000284391',
#   '00000284391',
#   '00000298761',
#   '00000298761',
#   '00000298761',
#   '00000298761',
#   '00000298761',
#   '00000298761',
#   '00000298761',
#   '00000298761',
#   '00000298761',
#   '00000467120',
#   '00000467120',
#   '00000467120',
#   '00000467120',
#   '00000467130',
#   '00000467130',
#   '00000467130',
#   '00000467130',
#   '00000908650',
#   '00000908650',
#   '00000908660',
#   '00000908660',
#   '00000908670',
#   '00000908670',
#   '00000908680',
#   '00000908680',
#   '00001290361',
#   '00001290361',
#   '00001300001',
#   '00001300001',
#   '00001317221',
#   '00001317221',
#   '00001317221',
#   '00001317221',
#   '00001317221',
#   '00001317221',
#   '00001317261',
#   '00001317261',
#   '00001317261',
#   '00001317261',
#   '00001317261',
#   '00001317261',
#   '00001351961',
#   '00001351961',
#   '00001351961',
#   '00001351961',
#   '00001351961',
#   '00001351961',
#   '00001434851',
#   '00001434851',
#   '00001434851',
#   '00001434851',
#   '00001434851',
#   '00001434851',
#   '00001434851',
#   '00001434851',
#   '00001434851',
#   '00001434851',
#   '00001434851',
#   '00001552901',
#   '00001552901',
#   '00001552901',
#   '00001552901',
#   '00001552901',
#   '00001552901',
#   '00001552901',
#   '00001552901',
#   '00001552901',
#   '00001552901',
#   '00001560191',
#   '00001560191',
#   '00001560191',
#   '00001560191',
#   '00001560191',
#   '00001560191',
#   '00001560191',
#   '00001560191',
#   '00001563371',
#   '00001563371',
#   '00001563371',
#   '00001563371',
#   '00001563371',
#   '00001572521',
#   '00001572521',
#   '00001572521',
#   '00001572521',
#   '00001572521',
#   '00001572521',
#   '00001572521',
#   '00001572521',
#   '00001572521',
#   '00001572521',
#   '00001572521',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001587391',
#   '00001588351',
#   '00001588351',
#   '00001588351',
#   '00001588351',
#   '00001588351',
#   '00001588351',
#   '00001588351',
#   '00001588351',
#   '00001588351',
#   '00001588351',
#   '00001589581',
#   '00001589581',
#   '00001589581',
#   '00001589581',
#   '00001589581',
#   '00001589581',
#   '00001589581',
#   '00001589581',
#   '00001589581',
#   '00001589581',
#   '00001665181',
#   '00001665181',
#   '00001665181',
#   '00001665181',
#   '00001665181',
#   '00001665181',
#   '00001665181',
#   '00001667201',
#   '00001667201',
#   '00001667201',
#   '00001667201',
#   '00001667201',
#   '00001667201',
#   '00001667201',
#   '00001859570',
#   '00001859570',
#   '00001859570',
#   '00001862411',
#   '00001862411',
#   '00001862411',
#   '00001862411',
#   '00001862411',
#   '00001862411',
#   '00001862411',
#   '00001983401',
#   '00001983401',
#   '00001983401',
#   '00001983401',
#   '00001983401',
#   '00001983401',
#   '00001983401',
#   '00001983401',
#   '00001983401',
#   '00001983401',
#   '00001983781',
#   '00001983781',
#   '00001983781',
#   '00001983781',
#   '00001983781',
#   '00001983781',
#   '00001983781',
#   '00001983781',
#   '00001983781',
#   '00001983781',
#   '00001983781',
#   '00001989531',
#   '00001989531',
#   '00001989531',
#   '00001989531',
#   '00001989531',
#   '00001989531',
#   '00001989531',
#   '00001989531',
#   '00001989531',
#   '00001989531',
#   '00001989531',
#   '00001989891',
#   '00001989891',
#   '00001989891',
#   '00001989891',
#   '00001989891',
#   '00001989891',
#   '00001989891',
#   '00001989891',
#   '00001989891',
#   '00001989891',
#   '00002080561',
#   '00002080561',
#   '00002080561',
#   '00002080561',
#   '00002080561',
#   '00002080561',
#   '00002081531',
#   '00002081531',
#   '00002081531',
#   '00002081531',
#   '00002081531',
#   '00002101271',
#   '00002101271',
#   '00002101271',
#   '00002101271',
#   '00002101271',
#   '00002101271',
#   '00002155901',
#   '00002155901',
#   '00002155901',
#   '00002155901',
#   '00002155901',
#   '00002155901',
#   '00002155901',
#   '00002172091',
#   '00002172091',
#   '00002172091',
#   '00002172091',
#   '00002172091',
#   '00002172091',
#   '00002172091',
#   '00002172091',
#   '00002330521',
#   '00002330521',
#   '00002330521',
#   '00002330521',
#   '00002330521',
#   '00002331011',
#   '00002331011',
#   '00002331011',
#   '00002485681',
#   '00002612881',
#   '00002612881',
#   '00002612881',
#   '00002612881',
#   '00002612881',
#   '00002612881',
#   '00002612881',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002743091',
#   '00002774911',
#   '00002774911',
#   '00002774911',
#   '00002774911',
#   '00002774911',
#   '00002774911',
#   '00002774911',
#   '00002774911',
#   '00002774911',
#   '00002774911',
#   '00002806261',
#   '00002806261',
#   '00002806261',
#   '00002806261',
#   '00002806261',
#   '00002806261',
#   '00002806261',
#   '00002876691',
#   '00002876691',
#   '00002876691',
#   '00002876691',
#   '00002876691',
#   '00002876691',
#   '00002876691',
#   '00002876691',
#   '00002876691',
#   '00003121341',
#   '00003121341',
#   '00003121341',
#   '00003121341',
#   '00003121341',
#   '00003121341',
#   '00003121341',
#   '00003121341',
#   '00003121341',
#   '00003121741',
#   '00003121741',
#   '00003121741',
#   '00003121741',
#   '00003121741',
#   '00003121741',
#   '00003121741',
#   '00003121741',
#   '00003121741',
#   '00003121911',
#   '00003121911',
#   '00003121911',
#   '00003121911',
#   '00003121911',
#   '00003121911',
#   '00003121911',
#   '00003121911',
#   '00003121911',
#   '00003122011',
#   '00003122011',
#   '00003122011',
#   '00003122011',
#   '00003122011',
#   '00003122011',
#   '00003122011',
#   '00003122011',
#   '00003122011',
#   '00003122041',
#   '00003122041',
#   '00003122041',
#   '00003122041',
#   '00003122041',
#   '00003122041',
#   '00003122041',
#   '00003122041',
#   '00003122041',
#   '00003122051',
#   '00003122051',
#   '00003122051',
#   '00003122051',
#   '00003122051',
#   '00003122051',
#   '00003122051',
#   '00003122051',
#   '00003122051',
#   '00003133091',
#   '00003133091',
#   '00003133091',
#   '00003133091',
#   '00003133091',
#   '00003133091',
#   '00003133101',
#   '00003133101',
#   '00003133101',
#   '00003133101',
#   '00003133101',
#   '00003133101',
#   '00003133111',
#   '00003133111',
#   '00003133111',
#   '00003133111',
#   '00003133111',
#   '00003133111',
#   '00003133121',
#   '00003133121',
#   '00003133121',
#   '00003133121',
#   '00003133121',
#   '00003133121',
#   '00003133131',
#   '00003133131',
#   '00003133131',
#   '00003133131',
#   '00003133131',
#   '00003133131',
#   '00003133141',
#   '00003133141',
#   '00003133141',
#   '00003133141',
#   '00003133141',
#   '00003133141',
#   '00003133151',
#   '00003133151',
#   '00003133151',
#   '00003133151',
#   '00003133151',
#   '00003133151',
#   '00003133161',
#   '00003133161',
#   '00003133161',
#   '00003133161',
#   '00003133161',
#   '00003133161',
#   '00003133171',
#   '00003133171',
#   '00003133171',
#   '00003133171',
#   '00003133171',
#   '00003133171',
#   '00003133181',
#   '00003133181',
#   '00003133181',
#   '00003133181',
#   '00003133181',
#   '00003133181',
#   '00003135391',
#   '00003135391',
#   '00003135391',
#   '00003135391',
#   '00003240381',
#   '00003240381',
#   '00003240381',
#   '00003240381',
#   '00003240381',
#   '00003240381',
#   '00003240381',
#   '00003243561',
#   '00003243561',
#   '00003243561',
#   '00003243561',
#   '00003243561',
#   '00003243561',
#   '00003243561',
#   '00003243561',
#   '00003243561',
#   '00003243561',
#   '00003733161',
#   '00003733161',
#   '00003733161',
#   '00003733161',
#   '00003733161',
#   '00003733161',
#   '00003733161',
#   '00003934031',
#   '00003934031',
#   '00003934031',
#   '00003934031',
#   '00003934041',
#   '00003934041',
#   '00003934041',
#   '00003934041',
#   '00004140451',
#   '00004140451',
#   '00004140451',
#   '00004140451',
#   '00004140451',
#   '00004140451',
#   '00004140451',
#   '00004140451',
#   '00004144331',
#   '00004144331',
#   '00004144331',
#   '00004144331',
#   '00004144331',
#   '00004144331',
#   '00004144331',
#   '00004144331',
#   '00004144331',
#   '00004145421',
#   '00004145421',
#   '00004145421',
#   '00004145421',
#   '00004145421',
#   '00004145421',
#   '00004145421',
#   '00004145421',
#   '00004145421',
#   '00004145421',
#   '00004145851',
#   '00004145851',
#   '00004145851',
#   '00004145851',
#   '00004146131',
#   '00004146131',
#   '00004146131',
#   '00004146131',
#   '00004146131',
#   '00004146131',
#   '00004146131',
#   '00004146131',
#   '00004146131',
#   '00004149840',
#   '00004292211',
#   '00004292211',
#   '00004292211',
#   '00004292211',
#   '00004292211',
#   '00004293591',
#   '00004293591',
#   '00004293591',
#   '00004441791',
#   '00004441791',
#   '00004441791',
#   '00004441791',
#   '00004441791',
#   '00004441791',
#   '00004441791',
#   '00004441791',
#   '00004690361',
#   '00004690361',
#   '00004690361',
#   '00004690361',
#   '00004690361',
#   '00004690361',
#   '00004690361',
#   '00004690361',
#   '00004690361',
#   '00004699841',
#   '00004699841',
#   '00004699841',
#   '00004699841',
#   '00004699841',
#   '00004699841',
#   '00004699841',
#   '00004699841',
#   '00004699841',
#   '00004699841',
#   '00004700211',
#   '00004700211',
#   '00004700211',
#   '00004700211',
#   '00004700211',
#   '00004700211',
#   '00004700211',
#   '00004700211',
#   '00004700211',
#   '00004700211',
#   '00004731901',
#   '00004731901',
#   '00004731901',
#   '00004921521',
#   '00004921521',
#   '00004921521',
#   '00004921521',
#   '00004921521',
#   '00004921521',
#   '00004955871',
#   '00004955871',
#   '00004955871',
#   '00004955871',
#   '00004955871',
#   '00004955871',
#   '00005113961',
#   '00005113961',
#   '00005113961',
#   '00005113961',
#   '00005113961',
#   '00005113961',
#   '00005113961',
#   '00005113961',
#   '00005113961',
#   '00005113961',
#   '00005113961',
#   '00005142621',
#   '00005142621',
#   '00005142621',
#   '00005142621',
#   '00005142621',
#   '00005142621',
#   '00005142621',
#   '00005142621',
#   '00005142621',
#   '00005643781',
#   '00005643781',
#   '00005643781',
#   '00005643781',
#   '00005643781',
#   '00005643781',
#   '00005643781',
#   '00005643781',
#   '00005643781',
#   '00005643801',
#   '00005643801',
#   '00005643801',
#   '00005643801',
#   '00005643801',
#   '00005643801',
#   '00005643801',
#   '00005643801',
#   '00005643821',
#   '00005643821',
#   '00005643821',
#   '00005643821',
#   '00005643821',
#   '00005643821',
#   '00005643821',
#   '00005644051',
#   '00005644051',
#   '00005644051',
#   '00005644051',
#   '00005644051',
#   '00005644051',
#   '00005644101',
#   '00005644101',
#   '00005644101',
#   '00005644101',
#   '00005644101',
#   '00005644101',
#   '00005644101',
#   '00005644101',
#   '00005644101',
#   '00005644101',
#   '00005644101',
#   '00005658801',
#   '00005658801',
#   '00005658801',
#   '00005658801',
#   '00005658801',
#   '00005658801',
#   '00005658801',
#   '00005658801',
#   '00005658801',
#   '00005658801',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10157-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025297-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025297-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025297-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025297-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025297-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025297-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025297-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025297-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025297-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025894-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025894-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025894-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025894-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025894-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025894-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025894-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025894-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1025894-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10589-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10589-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10589-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10589-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10589-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10589-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10589-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10589-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10589-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10627-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10627-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10627-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10627-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10627-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10627-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10627-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10627-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10627-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10649-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10649-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10649-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10649-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10649-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10649-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10649-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10649-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10649-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10655-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10655-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10655-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10655-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10655-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10655-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10655-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10655-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10655-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10656-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10656-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10656-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10656-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10656-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10656-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10656-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10656-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10656-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10657-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10657-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10657-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10657-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10657-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10657-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10657-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10657-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10657-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10658-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10658-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10658-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10658-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10658-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10658-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10658-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10658-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10658-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10663-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10698-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10698-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10698-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10698-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10698-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10698-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10698-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10698-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '10698-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1075357-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1124291-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1124291-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1124291-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1124299-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1124299-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1124300-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1124300-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125415-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125425-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1125537-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1126523-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127245-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1127978-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128067-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128441-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128516-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1128562-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11308-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11308-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11308-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11375-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11375-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11381-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11381-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11381-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1142288-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1142288-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1142288-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1142288-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1142288-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1142288-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1142288-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1142288-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1142288-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '11439-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '12058-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '12058-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '12058-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '12060-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '12060-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '12060-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '12091-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '12091-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '12091-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1216112-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1216112-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1216112-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1216112-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1216112-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1216112-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1216112-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1216112-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1218034-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1218034-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1218034-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1218034-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229374-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229374-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229374-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229374-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229374-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229374-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229374-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229374-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229378-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229378-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229378-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229378-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229378-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229378-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229378-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229378-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229378-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229379-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229379-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229379-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229379-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229379-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229379-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229379-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229381-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229381-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229381-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229381-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229388-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229389-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   '1229390-68a3e5516d7a7dc21fbe0e7ee13bfc1c',
#   ...],
#  'recCode': 200,
#  'recMsg': '同步成功'}

# %%
resp.request.url,resp.json
# Out:
# ('http://test1.thirdpart.kaolatest.netease.com/api/queryAllGoodsId?channelId=1200&timestamp=2018-03-19+15%3A39%3A51&v=1.0&sign_method=md5&app_key=bb0b3ad64c9e5eb06c2fb6f163bf179e79051bd5c9b652fc45dc68a2b5dd23c6&sign=345944BD6BFD76EC5373BCB491D39F46',
#  <bound method Response.json of <Response [200]>>)

# %%
resp

# %%
# 单个商品详情查询
def query_goods_info_by_id(sku_id):
    """渠道下单个商品信息详情查询，接口地址：queryGoodsInfoById"""
    body = {
        "channelId":channel_id,
        "timestamp":time.strftime("%Y-%m-%d %H:%M:%S"),
        "v":"1.0",
        "sign_method":"md5",
        "app_key":app_key,
        "sign":'',
        "skuId":sku_id,
        "queryType":0, # 0表示返回全部信息、1表示只返回关键信息如：商品id、价格和库存
        "channelSalePrice":'1' # 回传税后价，仅支持保税、直邮、一般贸易（税率为0）模式、海淘模式；个人物品清关模式不返回
    }
    body['sign'] = gen_sign(body,secret_key)
    resp = requests.post(url+'queryGoodsInfoById',params=body)
    try:
        resp_data = resp.json()
    except:
        resp_data = resp.text
    return resp_data
query_goods_info_by_id('00001983401')
# Out:
# {'goodsInfo': {'IsPostageFree': False,
#   'afterTaxPrice': '1.12',
#   'brandCountryName': '韩国',
#   'brandId': 1106,
#   'brandName': 'MEDIHEAL 美迪恵尔',
#   'canReturnGoods': 1,
#   'category': '面膜/面膜粉 面部护肤 美容护肤 美容彩妆',
#   'detail': '<p style="text-align:center;"><img src="http://haitao.nos.netease.com/ce8008ff17c8458a9401980d37858eac1510319102434j9twzxsx14730.jpg" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/eae95bb491e54570ae9725c2021682e11520238856102jedyyopy10611.jpg?imageView&amp;quality=98&amp;crop=0_0_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/eae95bb491e54570ae9725c2021682e11520238856102jedyyopy10611.jpg?imageView&amp;quality=98&amp;crop=0_500_750_69" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_1000_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_1500_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_2000_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_2500_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_3000_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/f4ff30b30a6843339b78f5367c491fe51510321480453j9tyewp114819.jpg?imageView&amp;quality=98&amp;crop=0_0_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/f4ff30b30a6843339b78f5367c491fe51510321480453j9tyewp114819.jpg?imageView&amp;quality=98&amp;crop=0_500_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_4500_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_5000_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/a6271d6e626e47e888f62735b8cbc2201510321551761j9tygfpt14821.jpg?imageView&amp;quality=98&amp;crop=0_0_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_6000_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_6500_750_500" /></p> \n<p style="text-align:center;"><img src="http://haitao.nos.netease.com/1bl7kah9k26_750_7373.jpg?imageView&amp;quality=98&amp;crop=0_7000_750_373" /></p>',
#   'goodsId': 2070889,
#   'goodsImages': [{'goodsId': 0,
#     'imageType': 1,
#     'imageUrl': 'http://haitao.nos.netease.com/3050883495a34a1794475986be50f5511520238910743jedyzuml10612.jpg',
#     'imageUrlFor430': 'http://haitao.nos.netease.com/3050883495a34a1794475986be50f5511520238910743jedyzuml10612_430_430.jpg',
#     'imageUrlFor640490': 'http://haitao.nos.netease.com/3050883495a34a1794475986be50f5511520238910743jedyzuml10612_640_490.jpg',
#     'imageUrlFor70': 'http://haitao.nos.netease.com/3050883495a34a1794475986be50f5511520238910743jedyzuml10612_70_70.jpg',
#     'orderValue': 1},
#    {'goodsId': 0,
#     'imageType': 1,
#     'imageUrl': 'http://haitao.nos.netease.com/e5c049b11d9f4d5fa823147ee68e4b651510318842800j9twudg319229.jpg',
#     'imageUrlFor430': 'http://haitao.nos.netease.com/e5c049b11d9f4d5fa823147ee68e4b651510318842800j9twudg319229_430_430.jpg',
#     'imageUrlFor640490': 'http://haitao.nos.netease.com/e5c049b11d9f4d5fa823147ee68e4b651510318842800j9twudg319229_640_490.jpg',
#     'imageUrlFor70': 'http://haitao.nos.netease.com/e5c049b11d9f4d5fa823147ee68e4b651510318842800j9twudg319229_70_70.jpg',
#     'orderValue': 2},
#    {'goodsId': 0,
#     'imageType': 1,
#     'imageUrl': 'http://haitao.nos.netease.com/1bl7k9q2h18_800_800.jpg',
#     'imageUrlFor430': 'http://haitao.nos.netease.com/1bl7k9q2h18_800_800_430_430.jpg',
#     'imageUrlFor640490': 'http://haitao.nos.netease.com/1bl7k9q2h18_800_800_640_490.jpg',
#     'imageUrlFor70': 'http://haitao.nos.netease.com/1bl7k9q2h18_800_800_70_70.jpg',
#     'orderValue': 3},
#    {'goodsId': 0,
#     'imageType': 1,
#     'imageUrl': 'http://haitao.nos.netease.com/1bl7k9qpl80_800_800.jpg',
#     'imageUrlFor430': 'http://haitao.nos.netease.com/1bl7k9qpl80_800_800_430_430.jpg',
#     'imageUrlFor640490': 'http://haitao.nos.netease.com/1bl7k9qpl80_800_800_640_490.jpg',
#     'imageUrlFor70': 'http://haitao.nos.netease.com/1bl7k9qpl80_800_800_70_70.jpg',
#     'orderValue': 4},
#    {'goodsId': 0,
#     'imageType': 1,
#     'imageUrl': 'http://haitao.nos.netease.com/eea2e485cfe447d49ef8cab8a025f0081520236309682jedxg3v610530.jpg',
#     'imageUrlFor430': 'http://haitao.nos.netease.com/eea2e485cfe447d49ef8cab8a025f0081520236309682jedxg3v610530_430_430.jpg',
#     'imageUrlFor640490': 'http://haitao.nos.netease.com/eea2e485cfe447d49ef8cab8a025f0081520236309682jedxg3v610530_640_490.jpg',
#     'imageUrlFor70': 'http://haitao.nos.netease.com/eea2e485cfe447d49ef8cab8a025f0081520236309682jedxg3v610530_70_70.jpg',
#     'orderValue': 5},
#    {'goodsId': 0,
#     'imageType': 1,
#     'imageUrl': 'http://haitao.nos.netease.com/c33eec14d4fc49cb9f471828ddc3495f1520236309954jedxg42q10531.jpg',
#     'imageUrlFor430': 'http://haitao.nos.netease.com/c33eec14d4fc49cb9f471828ddc3495f1520236309954jedxg42q10531_430_430.jpg',
#     'imageUrlFor640490': 'http://haitao.nos.netease.com/c33eec14d4fc49cb9f471828ddc3495f1520236309954jedxg42q10531_640_490.jpg',
#     'imageUrlFor70': 'http://haitao.nos.netease.com/c33eec14d4fc49cb9f471828ddc3495f1520236309954jedxg42q10531_70_70.jpg',
#     'orderValue': 6},
#    {'goodsId': 0,
#     'imageType': 1,
#     'imageUrl': 'http://haitao.nos.netease.com/3673f3514e13449983709532ddbbba9a1520236310234jedxg4aq10532.jpg',
#     'imageUrlFor430': 'http://haitao.nos.netease.com/3673f3514e13449983709532ddbbba9a1520236310234jedxg4aq10532_430_430.jpg',
#     'imageUrlFor640490': 'http://haitao.nos.netease.com/3673f3514e13449983709532ddbbba9a1520236310234jedxg4aq10532_640_490.jpg',
#     'imageUrlFor70': 'http://haitao.nos.netease.com/3673f3514e13449983709532ddbbba9a1520236310234jedxg4aq10532_70_70.jpg',
#     'orderValue': 7}],
#   'goodsProperty': {'产品类型': ['贴片式'],
#    '产地': ['韩国'],
#    '保质期': ['3年'],
#    '功能': ['收敛毛孔'],
#    '品名': ['美迪恵尔 针剂水库保湿面膜 10片/盒*2+SNP海洋燕窝面膜*1'],
#    '规格': ['6-10片'],
#    '质地': ['其他'],
#    '适合肤质 ': ['任何肤质'],
#    '适用群体': ['女'],
#    '适用部位': ['面部']},
#   'imageUrl': 'http://haitao.nos.netease.com/3050883495a34a1794475986be50f5511520238910743jedyzuml10612.jpg',
#   'importType': 1,
#   'isFreeShipping': 0,
#   'isFreeTax': 0,
#   'isPresell': 0,
#   'isSelf': True,
#   'leafCategoryId': 564,
#   'logisticsProperty': {'editGoodsId': 2070889,
#    'goodsId': 2070889,
#    'height': None,
#    'length': None,
#    'size': 0,
#    'skuId': '00001983401',
#    'weight': 1.033,
#    'width': None},
#   'marketPrice': 537,
#   'memberCount': 0,
#   'onlineStatus': 1,
#   'price': 185.0,
#   'productId': 2070889,
#   'recommandStore': {'warehouseId': 3006,
#    'warehouseName': '重庆保税仓',
#    'warehouseStore': 0},
#   'shortTitle': '美迪恵尔 水库面膜 *2+SNP海洋燕窝面膜*1',
#   'skuId': '00001983401',
#   'skuProperty': [],
#   'storage': '重庆保税仓',
#   'store': 0,
#   'subTitle': '【品牌直采】补水网红，人人爱用！韩国MBS、KBS、SBS三大电视台共同推荐！销量超过1000万片！NMF天然保湿因子强力补水，每敷一片相当于做一次深层补水SPA。收缩毛孔，保湿锁水、晒后镇静，献给缺水的你。',
#   'suggestPrice': 195,
#   'taxFees': '0.12',
#   'taxRate': 0.119,
#   'taxRates': [0.119, 0.2635294118],
#   'thirdCategoryId': 542,
#   'thirdCategoryName': '美容护肤',
#   'title': '美迪恵尔 N.M.F针剂水库保湿面膜 10片/盒*2+SNP海洋燕窝面膜 10片/盒',
#   'warehouseStores': {'天津网仓保税仓': {'warehouseId': 3554,
#     'warehouseName': '天津网仓保税仓',
#     'warehouseStore': 0},
#    '宁波顺丰保税仓': {'warehouseId': 6,
#     'warehouseName': '宁波顺丰保税仓',
#     'warehouseStore': 0},
#    '杭州海仓科技有限公司东芝仓库': {'warehouseId': 46,
#     'warehouseName': '杭州海仓科技有限公司东芝仓库',
#     'warehouseStore': 0},
#    '杭州网仓仓库': {'warehouseId': 13,
#     'warehouseName': '杭州网仓仓库',
#     'warehouseStore': 0},
#    '深圳越海保税仓': {'warehouseId': 2153,
#     'warehouseName': '深圳越海保税仓',
#     'warehouseStore': 0},
#    '网易6号仓': {'warehouseId': 5, 'warehouseName': '网易6号仓', 'warehouseStore': 0},
#    '郑州保税2号仓': {'warehouseId': 8441,
#     'warehouseName': '郑州保税2号仓',
#     'warehouseStore': 0},
#    '郑州保税仓': {'warehouseId': 7, 'warehouseName': '郑州保税仓', 'warehouseStore': 0},
#    '重庆保税仓': {'warehouseId': 3006,
#     'warehouseName': '重庆保税仓',
#     'warehouseStore': 0},
#    '香港TC仓': {'warehouseId': 9521,
#     'warehouseName': '香港TC仓',
#     'warehouseStore': 0}}},
#  'recCode': 200,
#  'recMsg': '同步成功'}

# %%
# 商品详情批量查询
def query_goods_info_by_ids(sku_ids):
    """商品信息详情批量查询，接口地址：queryGoodsInfoByIds 由于http请求对响应时间有限制，现在默认一次只能查询20条，多于20条会返回错误码-103，详情见错误码说明"""
    body = {
        "channelId":channel_id,
        "timestamp":time.strftime("%Y-%m-%d %H:%M:%S"),
        "v":"1.0",
        "sign_method":"md5",
        "app_key":app_key,
        "sign":'',
        "skuIds":str(sku_ids),
        "queryType":0, # 0表示返回全部信息、1表示只返回关键信息如：商品id、价格和库存
        "channelSalePrices":str([1]*len(sku_ids)) # 回传税后价，仅支持保税、直邮、一般贸易（税率为0）模式、海淘模式；个人物品清关模式不返回
    }
    body['sign'] = gen_sign(body,secret_key)
    resp = requests.post(url+'queryGoodsInfoByIds',params=body)
    return resp.json()
query_goods_info_by_ids(['59070208-96359ea7676df2eea9ce9acf7c538005', '59076218-6f04aaa51ddfbe2aad2e5d139528bc95', '59077671-cdfe59eb911f5b727240c310df9fad57', '59077671-cdfe59eb911f5b727240c310df9fad57', '59083052-6f04aaa51ddfbe2aad2e5d139528bc95', '59086857-6f04aaa51ddfbe2aad2e5d139528bc95', '6014-e3d4f8c9df8d3ddf344d1d4ea1603b4a', '6024-d46389875f39726d27af6c3e81fdcf77', '6024-e3d4f8c9df8d3ddf344d1d4ea1603b4a', '6064-128010f98e698bb5365cc41a972e4b9f', '6626-bba69a3033db10d7908615a3dedeb6c5', '6720750-ecc4090b639c47f89b453980923afb8e', '6886-ecc4090b639c47f89b453980923afb8e', '7030302-ecc4090b639c47f89b453980923afb8e', '8979-3845321bfcf28ddc40b4cca6613834a3', '9017-fd619f0359020094b63a73656691297d', '9100-ecc4090b639c47f89b453980923afb8e'])
# Out:
# [{'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '美国',
#    'brandId': 1008,
#    'brandName': '三星111',
#    'category': '直冲 战网 游戏点卡 虚拟商品',
#    'detail': '123',
#    'goodsId': 59070208,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://pop.nosdn.127.net/02d2cb52-3a05-4f36-8f3d-10dabd524e8d',
#      'imageUrlFor430': 'http://pop.nosdn.127_430_430.net/02d2cb52-3a05-4f36-8f3d-10dabd524e8d',
#      'imageUrlFor640490': 'http://pop.nosdn.127_640_490.net/02d2cb52-3a05-4f36-8f3d-10dabd524e8d',
#      'imageUrlFor70': 'http://pop.nosdn.127_70_70.net/02d2cb52-3a05-4f36-8f3d-10dabd524e8d',
#      'orderValue': 1}],
#    'goodsProperty': {},
#    'imageUrl': 'http://pop.nosdn.127.net/02d2cb52-3a05-4f36-8f3d-10dabd524e8d',
#    'importType': 3,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 24656,
#    'logisticsProperty': None,
#    'marketPrice': 388,
#    'memberCount': 0,
#    'onlineStatus': 0,
#    'price': 388.0,
#    'productId': 59070208,
#    'recommandStore': {'warehouseId': 108,
#     'warehouseName': '造数据很辛苦—不要动它qaq仓库',
#     'warehouseStore': 10047},
#    'shortTitle': '战网点数',
#    'skuId': '59070208-96359ea7676df2eea9ce9acf7c538005',
#    'skuProperty': [{'imageUrl': None,
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '充值类型',
#      'propertyNameId': '3708',
#      'propertyValue': '通用点数',
#      'propertyValueIcon': None,
#      'propertyValueId': '1143423',
#      'showOrder': 0,
#      'skuid': None},
#     {'imageUrl': None,
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '充值点数',
#      'propertyNameId': '3709',
#      'propertyValue': '388',
#      'propertyValueIcon': None,
#      'propertyValueId': '1285527',
#      'showOrder': 11,
#      'skuid': None}],
#    'storage': '造数据很辛苦—不要动它qaq仓库',
#    'store': 10047,
#    'subTitle': '战网点数',
#    'suggestPrice': 388,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 24177,
#    'thirdCategoryName': '游戏点卡',
#    'title': '战网点数-分销',
#    'warehouseStores': {'造数据很辛苦—不要动它qaq仓库': {'warehouseId': 108,
#      'warehouseName': '造数据很辛苦—不要动它qaq仓库',
#      'warehouseStore': 10047}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.47',
#    'brandCountryName': '法国',
#    'brandId': 5599,
#    'brandName': '迪奥-auto-2016071210192729哈哈~~~',
#    'category': '香水 美容彩妆',
#    'detail': '保税商品-商品详情-20171114152642191 \n<img src="http://haitao.nos.netease.com/irh4nxwe40_800_800.jpg" style="text-align: center;" />',
#    'goodsId': 59076218,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/irgblckx76_800_800.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/irgblckx76_800_800_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/irgblckx76_800_800_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/irgblckx76_800_800_70_70.jpg',
#      'orderValue': 1}],
#    'goodsProperty': {'【勿动】销售属性': ['黑色']},
#    'imageUrl': 'http://haitao.nos.netease.com/irgblckx76_800_800.jpg',
#    'importType': 1,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 9437,
#    'logisticsProperty': None,
#    'marketPrice': 599,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 77.0,
#    'productId': 59076218,
#    'recommandStore': {'warehouseId': 9,
#     'warehouseName': '神码测试仓库1',
#     'warehouseStore': 945},
#    'shortTitle': '自动化生成商品',
#    'skuId': '59076218-6f04aaa51ddfbe2aad2e5d139528bc95',
#    'skuProperty': [{'imageUrl': 'http://haitao.nos.netease.com/1bss7csl761_800_800.jpg',
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '【勿动】销售属性',
#      'propertyNameId': '7919',
#      'propertyValue': '黑色',
#      'propertyValueIcon': None,
#      'propertyValueId': '1178959',
#      'showOrder': 111,
#      'skuid': None}],
#    'storage': '神码测试仓库1',
#    'store': 945,
#    'subTitle': '自动化生成1510644402191',
#    'suggestPrice': 77,
#    'taxFees': '0.47',
#    'taxRate': 0.47,
#    'taxRates': [0.47],
#    'thirdCategoryId': 9437,
#    'thirdCategoryName': '香水',
#    'title': '保税商品auto1510644402191',
#    'warehouseStores': {'神码测试仓库1': {'warehouseId': 9,
#      'warehouseName': '神码测试仓库1',
#      'warehouseStore': 945}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.12',
#    'brandCountryName': '西班牙',
#    'brandId': 983,
#    'brandName': '雅培哈哈哈',
#    'category': '蛋白质/氨基酸 营养保健 保健品哈哈哈哈',
#    'detail': 'cw-到货提醒-多skucw-到货提醒-多skucw-到货提醒-多skucw-到货提醒-多sku',
#    'goodsId': 59077671,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010_70_70.jpg',
#      'orderValue': 1},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/f81815ead9364a8d8578f98d137770ff1511317613080jaafhhjf10011.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/f81815ead9364a8d8578f98d137770ff1511317613080jaafhhjf10011_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/f81815ead9364a8d8578f98d137770ff1511317613080jaafhhjf10011_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/f81815ead9364a8d8578f98d137770ff1511317613080jaafhhjf10011_70_70.jpg',
#      'orderValue': 2},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/5b50b5f06c46425ea1a964f2c38c63ee1511317613634jaafhhym10012.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/5b50b5f06c46425ea1a964f2c38c63ee1511317613634jaafhhym10012_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/5b50b5f06c46425ea1a964f2c38c63ee1511317613634jaafhhym10012_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/5b50b5f06c46425ea1a964f2c38c63ee1511317613634jaafhhym10012_70_70.jpg',
#      'orderValue': 3},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/1593b521d89a49228682d5b4898638231511317613874jaafhi5g10013.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/1593b521d89a49228682d5b4898638231511317613874jaafhi5g10013_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/1593b521d89a49228682d5b4898638231511317613874jaafhi5g10013_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/1593b521d89a49228682d5b4898638231511317613874jaafhi5g10013_70_70.jpg',
#      'orderValue': 4},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/c2232975d70f4bcb8e6c56c694e5453d1511317614284jaafhigr10014.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/c2232975d70f4bcb8e6c56c694e5453d1511317614284jaafhigr10014_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/c2232975d70f4bcb8e6c56c694e5453d1511317614284jaafhigr10014_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/c2232975d70f4bcb8e6c56c694e5453d1511317614284jaafhigr10014_70_70.jpg',
#      'orderValue': 5},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/01a46ccb017645c396df8876104f1a2a1511317614932jaafhiyu10015.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/01a46ccb017645c396df8876104f1a2a1511317614932jaafhiyu10015_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/01a46ccb017645c396df8876104f1a2a1511317614932jaafhiyu10015_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/01a46ccb017645c396df8876104f1a2a1511317614932jaafhiyu10015_70_70.jpg',
#      'orderValue': 6}],
#    'goodsProperty': {'pop商品属性五': ['属性值1', '属性值7C', '属性值6CB']},
#    'imageUrl': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010.jpg',
#    'importType': 1,
#    'isFreeShipping': 0,
#    'isFreeTax': 1,
#    'isPresell': 0,
#    'leafCategoryId': 4011,
#    'logisticsProperty': None,
#    'marketPrice': 233,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 165.55,
#    'productId': 59077671,
#    'recommandStore': {'warehouseId': 9,
#     'warehouseName': '神码测试仓库1',
#     'warehouseStore': 49},
#    'shortTitle': 'cw-到货提醒-多sku',
#    'skuId': '59077671-cdfe59eb911f5b727240c310df9fad57',
#    'skuProperty': [{'imageUrl': None,
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '销售属性项合并2',
#      'propertyNameId': '10573',
#      'propertyValue': '黑',
#      'propertyValueIcon': None,
#      'propertyValueId': '1000769',
#      'showOrder': 0,
#      'skuid': None}],
#    'storage': '神码测试仓库1',
#    'store': 76,
#    'subTitle': None,
#    'suggestPrice': 166,
#    'taxFees': '0.12',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 3931,
#    'thirdCategoryName': '营养保健',
#    'title': 'cw-到货提醒-多sku-多仓',
#    'warehouseStores': {'下沙保税仓库': {'warehouseId': 2,
#      'warehouseName': '下沙保税仓库',
#      'warehouseStore': 27},
#     '神码测试仓库1': {'warehouseId': 9,
#      'warehouseName': '神码测试仓库1',
#      'warehouseStore': 49}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.12',
#    'brandCountryName': '西班牙',
#    'brandId': 983,
#    'brandName': '雅培哈哈哈',
#    'category': '蛋白质/氨基酸 营养保健 保健品哈哈哈哈',
#    'detail': 'cw-到货提醒-多skucw-到货提醒-多skucw-到货提醒-多skucw-到货提醒-多sku',
#    'goodsId': 59077671,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010_70_70.jpg',
#      'orderValue': 1},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/f81815ead9364a8d8578f98d137770ff1511317613080jaafhhjf10011.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/f81815ead9364a8d8578f98d137770ff1511317613080jaafhhjf10011_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/f81815ead9364a8d8578f98d137770ff1511317613080jaafhhjf10011_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/f81815ead9364a8d8578f98d137770ff1511317613080jaafhhjf10011_70_70.jpg',
#      'orderValue': 2},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/5b50b5f06c46425ea1a964f2c38c63ee1511317613634jaafhhym10012.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/5b50b5f06c46425ea1a964f2c38c63ee1511317613634jaafhhym10012_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/5b50b5f06c46425ea1a964f2c38c63ee1511317613634jaafhhym10012_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/5b50b5f06c46425ea1a964f2c38c63ee1511317613634jaafhhym10012_70_70.jpg',
#      'orderValue': 3},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/1593b521d89a49228682d5b4898638231511317613874jaafhi5g10013.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/1593b521d89a49228682d5b4898638231511317613874jaafhi5g10013_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/1593b521d89a49228682d5b4898638231511317613874jaafhi5g10013_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/1593b521d89a49228682d5b4898638231511317613874jaafhi5g10013_70_70.jpg',
#      'orderValue': 4},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/c2232975d70f4bcb8e6c56c694e5453d1511317614284jaafhigr10014.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/c2232975d70f4bcb8e6c56c694e5453d1511317614284jaafhigr10014_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/c2232975d70f4bcb8e6c56c694e5453d1511317614284jaafhigr10014_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/c2232975d70f4bcb8e6c56c694e5453d1511317614284jaafhigr10014_70_70.jpg',
#      'orderValue': 5},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/01a46ccb017645c396df8876104f1a2a1511317614932jaafhiyu10015.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/01a46ccb017645c396df8876104f1a2a1511317614932jaafhiyu10015_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/01a46ccb017645c396df8876104f1a2a1511317614932jaafhiyu10015_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/01a46ccb017645c396df8876104f1a2a1511317614932jaafhiyu10015_70_70.jpg',
#      'orderValue': 6}],
#    'goodsProperty': {'pop商品属性五': ['属性值1', '属性值7C', '属性值6CB']},
#    'imageUrl': 'http://haitao.nos.netease.com/6dcbb4d3dfd64190a037bd03c32a09281511317612728jaafhh9610010.jpg',
#    'importType': 1,
#    'isFreeShipping': 0,
#    'isFreeTax': 1,
#    'isPresell': 0,
#    'leafCategoryId': 4011,
#    'logisticsProperty': None,
#    'marketPrice': 233,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 165.55,
#    'productId': 59077671,
#    'recommandStore': {'warehouseId': 9,
#     'warehouseName': '神码测试仓库1',
#     'warehouseStore': 49},
#    'shortTitle': 'cw-到货提醒-多sku',
#    'skuId': '59077671-cdfe59eb911f5b727240c310df9fad57',
#    'skuProperty': [{'imageUrl': None,
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '销售属性项合并2',
#      'propertyNameId': '10573',
#      'propertyValue': '黑',
#      'propertyValueIcon': None,
#      'propertyValueId': '1000769',
#      'showOrder': 0,
#      'skuid': None}],
#    'storage': '神码测试仓库1',
#    'store': 76,
#    'subTitle': None,
#    'suggestPrice': 166,
#    'taxFees': '0.12',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 3931,
#    'thirdCategoryName': '营养保健',
#    'title': 'cw-到货提醒-多sku-多仓',
#    'warehouseStores': {'下沙保税仓库': {'warehouseId': 2,
#      'warehouseName': '下沙保税仓库',
#      'warehouseStore': 27},
#     '神码测试仓库1': {'warehouseId': 9,
#      'warehouseName': '神码测试仓库1',
#      'warehouseStore': 49}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '法国',
#    'brandId': 5599,
#    'brandName': '迪奥-auto-2016071210192729哈哈~~~',
#    'category': '香水 美容彩妆',
#    'detail': '【勿动】自动化海淘商品A-商品详情-20171226214349565 \n<img src="http://haitao.nos.netease.com/irh4nxwe40_800_800.jpg" style="text-align: center;" />',
#    'goodsId': 59083052,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nosdn4.127.net/irgbntuh54_800_800.jpg',
#      'imageUrlFor430': 'http://haitao.nosdn4.127.net/irgbntuh54_800_800_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nosdn4.127.net/irgbntuh54_800_800_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nosdn4.127.net/irgbntuh54_800_800_70_70.jpg',
#      'orderValue': 1}],
#    'goodsProperty': {'【勿动】销售属性': ['黑色']},
#    'imageUrl': 'http://haitao.nosdn4.127.net/irgbntuh54_800_800.jpg',
#    'importType': 2,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 9437,
#    'logisticsProperty': None,
#    'marketPrice': 599,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 69.8,
#    'productId': 59083052,
#    'recommandStore': {'warehouseId': 16,
#     'warehouseName': 'COE测试仓库1',
#     'warehouseStore': 10988},
#    'shortTitle': '自动化生成商品',
#    'skuId': '59083052-6f04aaa51ddfbe2aad2e5d139528bc95',
#    'skuProperty': [{'imageUrl': 'http://haitao.nos.netease.com/1bss7csl761_800_800.jpg',
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '【勿动】销售属性',
#      'propertyNameId': '7919',
#      'propertyValue': '黑色',
#      'propertyValueIcon': None,
#      'propertyValueId': '1178959',
#      'showOrder': 111,
#      'skuid': None}],
#    'storage': 'COE测试仓库1',
#    'store': 10988,
#    'subTitle': '自动化生成1514295829565',
#    'suggestPrice': 125.55,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 9437,
#    'thirdCategoryName': '香水',
#    'title': '【勿动】自动化海淘商品A',
#    'warehouseStores': {'COE测试仓库1': {'warehouseId': 16,
#      'warehouseName': 'COE测试仓库1',
#      'warehouseStore': 10988}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '法国',
#    'brandId': 5599,
#    'brandName': '迪奥-auto-2016071210192729哈哈~~~',
#    'category': '香水 美容彩妆',
#    'detail': '【勿动】合单一般贸易5-商品详情-20180118160821112 \n<img src="http://haitao.nos.netease.com/irh4nxwe40_800_800.jpg" style="text-align: center;" />',
#    'goodsId': 59086857,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nosdn3.127.net/irgbnfcq42_800_800.jpg',
#      'imageUrlFor430': 'http://haitao.nosdn3.127.net/irgbnfcq42_800_800_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nosdn3.127.net/irgbnfcq42_800_800_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nosdn3.127.net/irgbnfcq42_800_800_70_70.jpg',
#      'orderValue': 1}],
#    'goodsProperty': {'【勿动】销售属性': ['黑色']},
#    'imageUrl': 'http://haitao.nosdn3.127.net/irgbnfcq42_800_800.jpg',
#    'importType': 3,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 9437,
#    'logisticsProperty': None,
#    'marketPrice': 100,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 90.0,
#    'productId': 59086857,
#    'recommandStore': {'warehouseId': 14,
#     'warehouseName': '蜂巢测试仓库1',
#     'warehouseStore': 960},
#    'shortTitle': '自动化生成商品',
#    'skuId': '59086857-6f04aaa51ddfbe2aad2e5d139528bc95',
#    'skuProperty': [{'imageUrl': 'http://haitao.nos.netease.com/1bss7csl761_800_800.jpg',
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '【勿动】销售属性',
#      'propertyNameId': '7919',
#      'propertyValue': '黑色',
#      'propertyValueIcon': None,
#      'propertyValueId': '1178959',
#      'showOrder': 111,
#      'skuid': None}],
#    'storage': '蜂巢测试仓库1',
#    'store': 960,
#    'subTitle': '自动化生成1516262901112',
#    'suggestPrice': 100,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 9437,
#    'thirdCategoryName': '香水',
#    'title': '【勿动】合单一般贸易5',
#    'warehouseStores': {'蜂巢测试仓库1': {'warehouseId': 14,
#      'warehouseName': '蜂巢测试仓库1',
#      'warehouseStore': 960}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.12',
#    'brandCountryName': '工厂店',
#    'brandId': 1006,
#    'brandName': 'Aptamil abc',
#    'category': '手机 3C 买买买',
#    'detail': '<p>普通商品</p>',
#    'goodsId': 5227,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/testi71hegm310031.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/testi71hegm310031_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/testi71hegm310031_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/testi71hegm310031_70_70.jpg',
#      'orderValue': 1}],
#    'goodsProperty': {},
#    'imageUrl': 'http://haitao.nos.netease.com/testi71hegm310031.jpg',
#    'importType': 0,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 377,
#    'logisticsProperty': None,
#    'marketPrice': 900,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 500.0,
#    'productId': 6014,
#    'recommandStore': {'warehouseId': 7,
#     'warehouseName': '中外运测试仓库',
#     'warehouseStore': 99971},
#    'shortTitle': '直邮直邮',
#    'skuId': '6014-e3d4f8c9df8d3ddf344d1d4ea1603b4a',
#    'skuProperty': [{'imageUrl': 'http://haitao.nos.netease.com/testi719t08e10012.jpg',
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '网络制式',
#      'propertyNameId': '100221',
#      'propertyValue': '联通',
#      'propertyValueIcon': None,
#      'propertyValueId': '1001131',
#      'showOrder': 0,
#      'skuid': None}],
#    'storage': '中外运测试仓库',
#    'store': 99971,
#    'subTitle': None,
#    'suggestPrice': 500,
#    'taxFees': '0.12',
#    'taxRate': 0.119,
#    'taxRates': [0.119],
#    'thirdCategoryId': 373,
#    'thirdCategoryName': '3C',
#    'title': '312/14点秒抢商品',
#    'warehouseStores': {'中外运测试仓库': {'warehouseId': 7,
#      'warehouseName': '中外运测试仓库',
#      'warehouseStore': 99971}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '中国澳门',
#    'brandId': 982,
#    'brandName': '相宜本草666999',
#    'category': '手机 3C 买买买',
#    'detail': '<p>fff重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2<br></p>',
#    'goodsId': 5235,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://nos.netease.com/haitao/testi3r0r3yl10001.png',
#      'imageUrlFor430': 'http://nos.netease.com/haitao/testi3r0r3yl10001_430_430.png',
#      'imageUrlFor640490': 'http://nos.netease.com/haitao/testi3r0r3yl10001_640_490.png',
#      'imageUrlFor70': 'http://nos.netease.com/haitao/testi3r0r3yl10001_70_70.png',
#      'orderValue': 1},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/ih3hxa330_800_800.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/ih3hxa330_800_800_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/ih3hxa330_800_800_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/ih3hxa330_800_800_70_70.jpg',
#      'orderValue': 2}],
#    'goodsProperty': {'寄件人姓名': ['张三']},
#    'imageUrl': 'http://nos.netease.com/haitao/testi3r0r3yl10001.png',
#    'importType': 0,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 377,
#    'logisticsProperty': None,
#    'marketPrice': 50,
#    'memberCount': 0,
#    'onlineStatus': 0,
#    'price': 10.0,
#    'productId': 6024,
#    'recommandStore': {'warehouseId': 8,
#     'warehouseName': '中外运测试仓库2',
#     'warehouseStore': 2493},
#    'shortTitle': 'shortTitle',
#    'skuId': '6024-d46389875f39726d27af6c3e81fdcf77',
#    'skuProperty': [{'imageUrl': 'http://haitao.nosdn1.127.net/ih3hy5jx53_800_800.jpg',
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '网络制式',
#      'propertyNameId': '100221',
#      'propertyValue': '电信',
#      'propertyValueIcon': None,
#      'propertyValueId': '1001132',
#      'showOrder': 0,
#      'skuid': None}],
#    'storage': '中外运测试仓库2',
#    'store': 2493,
#    'subTitle': 'subTitle',
#    'suggestPrice': 15,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 373,
#    'thirdCategoryName': '3C',
#    'title': '重构测试2',
#    'warehouseStores': {'中外运测试仓库2': {'warehouseId': 8,
#      'warehouseName': '中外运测试仓库2',
#      'warehouseStore': 2493}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '中国澳门',
#    'brandId': 982,
#    'brandName': '相宜本草666999',
#    'category': '手机 3C 买买买',
#    'detail': '<p>fff重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2重构测试2<br></p>',
#    'goodsId': 5235,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://nos.netease.com/haitao/testi3r0r3yl10001.png',
#      'imageUrlFor430': 'http://nos.netease.com/haitao/testi3r0r3yl10001_430_430.png',
#      'imageUrlFor640490': 'http://nos.netease.com/haitao/testi3r0r3yl10001_640_490.png',
#      'imageUrlFor70': 'http://nos.netease.com/haitao/testi3r0r3yl10001_70_70.png',
#      'orderValue': 1},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/ih3hxa330_800_800.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/ih3hxa330_800_800_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/ih3hxa330_800_800_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/ih3hxa330_800_800_70_70.jpg',
#      'orderValue': 2}],
#    'goodsProperty': {'寄件人姓名': ['张三']},
#    'imageUrl': 'http://nos.netease.com/haitao/testi3r0r3yl10001.png',
#    'importType': 0,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 377,
#    'logisticsProperty': None,
#    'marketPrice': 30,
#    'memberCount': 0,
#    'onlineStatus': 0,
#    'price': 35.0,
#    'productId': 6024,
#    'recommandStore': {'warehouseId': 8,
#     'warehouseName': '中外运测试仓库2',
#     'warehouseStore': 3999},
#    'shortTitle': 'shortTitle',
#    'skuId': '6024-e3d4f8c9df8d3ddf344d1d4ea1603b4a',
#    'skuProperty': [{'imageUrl': 'http://nos.netease.com/haitao/testi3r0rfqi10002.png',
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '网络制式',
#      'propertyNameId': '100221',
#      'propertyValue': '联通',
#      'propertyValueIcon': None,
#      'propertyValueId': '1001131',
#      'showOrder': 0,
#      'skuid': None}],
#    'storage': '中外运测试仓库2',
#    'store': 3999,
#    'subTitle': 'subTitle',
#    'suggestPrice': 20,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 373,
#    'thirdCategoryName': '3C',
#    'title': '重构测试2',
#    'warehouseStores': {'中外运测试仓库2': {'warehouseId': 8,
#      'warehouseName': '中外运测试仓库2',
#      'warehouseStore': 3999}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'recCode': -102, 'recMsg': '该商品ID(5254)不能找到相关商品'},
#  {'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '荷兰',
#    'brandId': 1024,
#    'brandName': 'Nestle雀巢',
#    'category': '奶粉 环球购购购',
#    'detail': '<p><span style="color: rgb(51, 51, 51); font-family: &#39;Microsoft Yahei&#39;; line-height: 26.5599994659424px;  background-color: rgb(255, 255, 255);">真正改善疤痕印记肌肤！德国进口马油，利于皮肤渗透吸收，72h长效保湿！植物配方，安全修护肌肤！28天焕肤奇迹：淡化疤印、填平痘坑、长效润泽，从此爱上肌肤触感！</span></p>',
#    'goodsId': 5705,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/testibivb6c910072.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/testibivb6c910072_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/testibivb6c910072_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/testibivb6c910072_70_70.jpg',
#      'orderValue': 1},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/testibh9w2lm10002.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/testibh9w2lm10002_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/testibh9w2lm10002_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/testibh9w2lm10002_70_70.jpg',
#      'orderValue': 2},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/testibh9w0x410001.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/testibh9w0x410001_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/testibh9w0x410001_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/testibh9w0x410001_70_70.jpg',
#      'orderValue': 3},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/testibh9w3rv10003.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/testibh9w3rv10003_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/testibh9w3rv10003_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/testibh9w3rv10003_70_70.jpg',
#      'orderValue': 4},
#     {'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/testibh9winl10004.jpg',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/testibh9winl10004_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/testibh9winl10004_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/testibh9winl10004_70_70.jpg',
#      'orderValue': 5}],
#    'goodsProperty': {'dev勿动hq1': ['木门', '铁门'], 'sku物流': ['1kg']},
#    'imageUrl': 'http://haitao.nos.netease.com/testibivb6c910072.jpg',
#    'importType': 1,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 311,
#    'logisticsProperty': None,
#    'marketPrice': 300,
#    'memberCount': 0,
#    'onlineStatus': 0,
#    'price': 299.0,
#    'productId': 6626,
#    'recommandStore': {'warehouseId': 2,
#     'warehouseName': '下沙保税仓库',
#     'warehouseStore': 976},
#    'shortTitle': '3-4岁婴幼儿 500克*2 盒 ，中国好奶粉',
#    'skuId': '6626-bba69a3033db10d7908615a3dedeb6c5',
#    'skuProperty': [{'imageUrl': None,
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': 'sku颜色显示',
#      'propertyNameId': '100004',
#      'propertyValue': '绯红',
#      'propertyValueIcon': None,
#      'propertyValueId': '1000014',
#      'showOrder': 0,
#      'skuid': None},
#     {'imageUrl': None,
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': 'sku物流',
#      'propertyNameId': '100203',
#      'propertyValue': '1kg',
#      'propertyValueIcon': None,
#      'propertyValueId': '1000717',
#      'showOrder': 0,
#      'skuid': None},
#     {'imageUrl': None,
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': 'dev勿动hq1',
#      'propertyNameId': '5728',
#      'propertyValue': '木门',
#      'propertyValueIcon': None,
#      'propertyValueId': '1000777',
#      'showOrder': 1,
#      'skuid': None}],
#    'storage': '下沙保税仓库',
#    'store': 976,
#    'subTitle': None,
#    'suggestPrice': 299,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 311,
#    'thirdCategoryName': '奶粉',
#    'title': 'Guerisson奇迹马油霜',
#    'warehouseStores': {'下沙保税仓库': {'warehouseId': 2,
#      'warehouseName': '下沙保税仓库',
#      'warehouseStore': 976}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.12',
#    'brandCountryName': '工厂店',
#    'brandId': 962,
#    'brandName': '化妆品',
#    'category': ' MEDIHEAL 可莱丝 美容护肤',
#    'detail': '      <p style="text-align:center;"><img src="http://haitao.nosdn5.127.net/iigu72tl66_800_800.jpg"></p>',
#    'goodsId': 6720750,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nosdn4.127.net/iigu6xi662_800_800.jpg',
#      'imageUrlFor430': 'http://haitao.nosdn4.127.net/iigu6xi662_800_800_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nosdn4.127.net/iigu6xi662_800_800_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nosdn4.127.net/iigu6xi662_800_800_70_70.jpg',
#      'orderValue': 1}],
#    'goodsProperty': {},
#    'imageUrl': 'http://haitao.nosdn4.127.net/iigu6xi662_800_800.jpg',
#    'importType': 1,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 1,
#    'leafCategoryId': 3814,
#    'logisticsProperty': None,
#    'marketPrice': 119,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 28.0,
#    'productId': 6720750,
#    'recommandStore': {'warehouseId': 263,
#     'warehouseName': '宁波亚马逊保税仓',
#     'warehouseStore': 5},
#    'shortTitle': '产品性，一般贸易测试商品lalala',
#    'skuId': '6720750-ecc4090b639c47f89b453980923afb8e',
#    'skuProperty': [],
#    'storage': '宁波亚马逊保税仓',
#    'store': 5,
#    'subTitle': None,
#    'suggestPrice': 118,
#    'taxFees': '0.12',
#    'taxRate': 0.119,
#    'taxRates': [0.119],
#    'thirdCategoryId': 3814,
#    'thirdCategoryName': ' MEDIHEAL 可莱丝',
#    'title': 'DF-产品性，一般贸易测试商品22',
#    'warehouseStores': {'宁波亚马逊保税仓': {'warehouseId': 263,
#      'warehouseName': '宁波亚马逊保税仓',
#      'warehouseStore': 5}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.12',
#    'brandCountryName': '美国',
#    'brandId': 1162,
#    'brandName': '边一娟',
#    'category': '边三 边二 边一娟',
#    'detail': '<p>似懂非懂法国人态度和银监会银行金融交易</p>',
#    'goodsId': 5850,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nos.netease.com/testicbjic8x10003.JPG',
#      'imageUrlFor430': 'http://haitao.nos.netease.com/testicbjic8x10003_430_430.JPG',
#      'imageUrlFor640490': 'http://haitao.nos.netease.com/testicbjic8x10003_640_490.JPG',
#      'imageUrlFor70': 'http://haitao.nos.netease.com/testicbjic8x10003_70_70.JPG',
#      'orderValue': 1}],
#    'goodsProperty': {},
#    'imageUrl': 'http://haitao.nos.netease.com/testicbjic8x10003.JPG',
#    'importType': 0,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 960,
#    'logisticsProperty': None,
#    'marketPrice': 200,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 60.97,
#    'productId': 6886,
#    'recommandStore': {'warehouseId': 7,
#     'warehouseName': '中外运测试仓库',
#     'warehouseStore': 4307},
#    'shortTitle': '边特卖7边特卖7边特卖7边特卖7边特卖7边特卖7边特卖',
#    'skuId': '6886-ecc4090b639c47f89b453980923afb8e',
#    'skuProperty': [],
#    'storage': '中外运测试仓库',
#    'store': 4307,
#    'subTitle': None,
#    'suggestPrice': 58,
#    'taxFees': '0.12',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 955,
#    'thirdCategoryName': '边二',
#    'title': '边特卖7边特卖7边特卖7边特卖7边特卖7边特卖7边特卖7边特卖7边特卖7边',
#    'warehouseStores': {'中外运测试仓库': {'warehouseId': 7,
#      'warehouseName': '中外运测试仓库',
#      'warehouseStore': 4307}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '日本',
#    'brandId': 1004,
#    'brandName': '同仁堂',
#    'category': '蛋白质/氨基酸 营养保健 保健品哈哈哈哈',
#    'detail': 'FBI测试海淘转个人物品超过1000FBI测试海淘转个人物品超过1000FBI测试海淘转个人物品超过1000FBI测试海淘转个人物品超过1000FBI测试海淘转个人物品超过1000',
#    'goodsId': 7030302,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nosdn1.127.net/ipi41gwj72_800_800.jpg',
#      'imageUrlFor430': 'http://haitao.nosdn1.127.net/ipi41gwj72_800_800_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nosdn1.127.net/ipi41gwj72_800_800_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nosdn1.127.net/ipi41gwj72_800_800_70_70.jpg',
#      'orderValue': 1}],
#    'goodsProperty': {},
#    'imageUrl': 'http://haitao.nosdn1.127.net/ipi41gwj72_800_800.jpg',
#    'importType': 2,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 4011,
#    'logisticsProperty': None,
#    'marketPrice': 9000,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 167.0,
#    'productId': 7030302,
#    'recommandStore': {'warehouseId': 16,
#     'warehouseName': 'COE测试仓库1',
#     'warehouseStore': 2834},
#    'shortTitle': 'FBI测试海淘转个人物品税费小于50',
#    'skuId': '7030302-ecc4090b639c47f89b453980923afb8e',
#    'skuProperty': [],
#    'storage': 'COE测试仓库1',
#    'store': 2834,
#    'subTitle': None,
#    'suggestPrice': 333,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 3931,
#    'thirdCategoryName': '营养保健',
#    'title': 'FBI测试海淘转个人物品税费小于50',
#    'warehouseStores': {'COE测试仓库1': {'warehouseId': 16,
#      'warehouseName': 'COE测试仓库1',
#      'warehouseStore': 2834}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '中国香港',
#    'brandId': 1003,
#    'brandName': '碧生源好好好',
#    'category': '几木朵 酵素 保健品哈哈哈哈',
#    'detail': '<p><span style="color: rgb(51, 51, 51); font-family: arial, 宋体; font-size: 12px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 18px; orphans: auto; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(221, 221, 221);">012345678</span><span style="color: rgb(51, 51, 51); font-family: arial, 宋体; font-size: 12px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 18px; orphans: auto; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(221, 221, 221);">012345678</span><span style="color: rgb(51, 51, 51); font-family: arial, 宋体; font-size: 12px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 18px; orphans: auto; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(221, 221, 221);">012345678</span><span style="color: rgb(51, 51, 51); font-family: arial, 宋体; font-size: 12px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 18px; orphans: auto; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(221, 221, 221);">012345678</span><span style="color: rgb(51, 51, 51); font-family: arial, 宋体; font-size: 12px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 18px; orphans: auto; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(221, 221, 221);">012345678</span><span style="color: rgb(51, 51, 51); font-family: arial, 宋体; font-size: 12px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 18px; orphans: auto; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(221, 221, 221);">012345678</span></p>',
#    'goodsId': 8212,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nosdn1.127.net/testiepek53g10013.JPG',
#      'imageUrlFor430': 'http://haitao.nosdn1.127.net/testiepek53g10013_430_430.JPG',
#      'imageUrlFor640490': 'http://haitao.nosdn1.127.net/testiepek53g10013_640_490.JPG',
#      'imageUrlFor70': 'http://haitao.nosdn1.127.net/testiepek53g10013_70_70.JPG',
#      'orderValue': 1}],
#    'goodsProperty': {},
#    'imageUrl': 'http://haitao.nosdn1.127.net/testiepek53g10013.JPG',
#    'importType': 2,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 364,
#    'logisticsProperty': None,
#    'marketPrice': 10,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 9.0,
#    'productId': 8979,
#    'recommandStore': {'warehouseId': 17,
#     'warehouseName': 'COE测试仓库2',
#     'warehouseStore': 4769},
#    'shortTitle': 'cyd回归',
#    'skuId': '8979-3845321bfcf28ddc40b4cca6613834a3',
#    'skuProperty': [{'imageUrl': 'http://haitao.nosdn1.127.net/testiepeka0k10015.JPG',
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '新属性',
#      'propertyNameId': '345',
#      'propertyValue': '1',
#      'propertyValueIcon': None,
#      'propertyValueId': '47765',
#      'showOrder': 1,
#      'skuid': None}],
#    'storage': 'COE测试仓库2',
#    'store': 4769,
#    'subTitle': None,
#    'suggestPrice': 10,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 363,
#    'thirdCategoryName': '酵素',
#    'title': 'cyd回归',
#    'warehouseStores': {'COE测试仓库2': {'warehouseId': 17,
#      'warehouseName': 'COE测试仓库2',
#      'warehouseStore': 4769}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '中国',
#    'brandId': 1005,
#    'brandName': '初元zzz',
#    'category': '钙片产品迁移 保健品 买买买',
#    'detail': '<p><img src="http://haitao.nosdn1.127.net/testierygaym10012.JPG"/></p>',
#    'goodsId': 7907,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nosdn2.127.net/testieryg1ok10009.JPG',
#      'imageUrlFor430': 'http://haitao.nosdn2.127.net/testieryg1ok10009_430_430.JPG',
#      'imageUrlFor640490': 'http://haitao.nosdn2.127.net/testieryg1ok10009_640_490.JPG',
#      'imageUrlFor70': 'http://haitao.nosdn2.127.net/testieryg1ok10009_70_70.JPG',
#      'orderValue': 1}],
#    'goodsProperty': {},
#    'imageUrl': 'http://haitao.nosdn2.127.net/testieryg1ok10009.JPG',
#    'importType': 0,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'leafCategoryId': 9768,
#    'logisticsProperty': None,
#    'marketPrice': 600,
#    'memberCount': 0,
#    'onlineStatus': 0,
#    'price': 260.0,
#    'productId': 9017,
#    'recommandStore': {'warehouseId': 16,
#     'warehouseName': 'COE测试仓库1',
#     'warehouseStore': 58921},
#    'shortTitle': '边一娟测试商品3',
#    'skuId': '9017-fd619f0359020094b63a73656691297d',
#    'skuProperty': [{'imageUrl': 'http://haitao.nosdn4.127.net/testieryg5mc10011.JPG',
#      'isSysProperty': 1,
#      'nameAlias': None,
#      'propertyName': '测试',
#      'propertyNameId': '761',
#      'propertyValue': '测1',
#      'propertyValueIcon': None,
#      'propertyValueId': '49312',
#      'showOrder': 1,
#      'skuid': None}],
#    'storage': 'COE测试仓库1',
#    'store': 58921,
#    'subTitle': None,
#    'suggestPrice': 500,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': 374,
#    'thirdCategoryName': '保健品',
#    'title': '边一娟测试商品3',
#    'warehouseStores': {'COE测试仓库1': {'warehouseId': 16,
#      'warehouseName': 'COE测试仓库1',
#      'warehouseStore': 58921}}},
#   'recCode': 200,
#   'recMsg': '同步成功'},
#  {'goodsInfo': {'afterTaxPrice': '1.00',
#    'brandCountryName': '美国',
#    'brandId': 1162,
#    'brandName': '边一娟',
#    'category': '',
#    'detail': '<p><img src="http://haitao.nos.netease.com/testiev56c5810013.jpg"/></p>',
#    'goodsId': 7969,
#    'goodsImages': [{'goodsId': 0,
#      'imageType': 1,
#      'imageUrl': 'http://haitao.nosdn4.127.net/testiev561d810011.jpg',
#      'imageUrlFor430': 'http://haitao.nosdn4.127.net/testiev561d810011_430_430.jpg',
#      'imageUrlFor640490': 'http://haitao.nosdn4.127.net/testiev561d810011_640_490.jpg',
#      'imageUrlFor70': 'http://haitao.nosdn4.127.net/testiev561d810011_70_70.jpg',
#      'orderValue': 1}],
#    'goodsProperty': {},
#    'imageUrl': 'http://haitao.nosdn4.127.net/testiev561d810011.jpg',
#    'importType': 0,
#    'isFreeShipping': 0,
#    'isFreeTax': 0,
#    'isPresell': 0,
#    'logisticsProperty': None,
#    'marketPrice': 750,
#    'memberCount': 0,
#    'onlineStatus': 1,
#    'price': 400.0,
#    'productId': 9100,
#    'recommandStore': {'warehouseId': 16,
#     'warehouseName': 'COE测试仓库1',
#     'warehouseStore': 999995},
#    'shortTitle': 'byj-直邮数字编号3',
#    'skuId': '9100-ecc4090b639c47f89b453980923afb8e',
#    'skuProperty': [],
#    'storage': 'COE测试仓库1',
#    'store': 999995,
#    'subTitle': None,
#    'suggestPrice': 700,
#    'taxFees': '0.00',
#    'taxRate': 0,
#    'taxRates': [0],
#    'thirdCategoryId': '',
#    'thirdCategoryName': '',
#    'title': 'byj-直邮数字编号3',
#    'warehouseStores': {'COE测试仓库1': {'warehouseId': 16,
#      'warehouseName': 'COE测试仓库1',
#      'warehouseStore': 999995}}},
#   'recCode': 200,
#   'recMsg': '同步成功'}]

# %%
sku_ids = ['59070208-96359ea7676df2eea9ce9acf7c538005', '59076218-6f04aaa51ddfbe2aad2e5d139528bc95', '59077671-cdfe59eb911f5b727240c310df9fad57', '59077671-cdfe59eb911f5b727240c310df9fad57', '59083052-6f04aaa51ddfbe2aad2e5d139528bc95', '59086857-6f04aaa51ddfbe2aad2e5d139528bc95', '6014-e3d4f8c9df8d3ddf344d1d4ea1603b4a', '6024-d46389875f39726d27af6c3e81fdcf77', '6024-e3d4f8c9df8d3ddf344d1d4ea1603b4a', '6064-128010f98e698bb5365cc41a972e4b9f', '6626-bba69a3033db10d7908615a3dedeb6c5', '6720750-ecc4090b639c47f89b453980923afb8e', '6886-ecc4090b639c47f89b453980923afb8e', '7030302-ecc4090b639c47f89b453980923afb8e', '8979-3845321bfcf28ddc40b4cca6613834a3', '9017-fd619f0359020094b63a73656691297d', '9100-ecc4090b639c47f89b453980923afb8e']

# %%
sku_ids[5]
# Out:
# '59086857-6f04aaa51ddfbe2aad2e5d139528bc95'

# %%
# 商品信息增量更新接口（性能待优化）
def query_changed_goods_info():
    """根据时间戳的商品信息更新接口 queryChangedGoodsInfo;该接口限制只能查询30天之内的数据;"""
    body = {
        "source":channel_id,
        "timestamp":time.strftime("%Y-%m-%d %H:%M:%S"),
        "v":"1.0",
        "sign_method":"md5",
        "app_key":app_key,
        "sign":'',
        "startTime":int(time.time())*1000,
        "endTime":int(time.time()+86400*24)*1000
    }
    body['sign'] = gen_sign(body,secret_key)
    resp = requests.post(url+'queryChangedGoodsInfo',params=body)
    return resp.json()
query_changed_goods_info()
# Out:
# {'recCode': 200, 'recMeg': '查询成功', 'result': []}

# %%
def query_comment_info():
    """查询goodsId下面指定时间段内所有的评论信息；默认查询间隔不得大于三个月(90天);接口地址queryCommentInfo;"""
    body = {
        "source":channel_id,
        "timestamp":time.strftime("%Y-%m-%d %H:%M:%S"),
        "v":"1.0",
        "sign_method":"md5",
        "app_key":app_key,
        "sign":'',
        "startTime":int(time.time())*1000,
        "endTime":int(time.time()+86400*24)*1000,
        "goodsId":59070208
    }
    body['sign'] = gen_sign(body,secret_key)
    resp = requests.post(url+'queryChangedGoodsInfo',params=body)
    return resp.json()
query_comment_info()
# Out:
# {'recCode': 200, 'recMeg': '查询成功', 'result': []}

# %%
# 一、获取分类categoryId 和  title
category_list = []
brand_list = []

for item in requests.get('https://sp.kaola.com/api/category?V330').json()['body']['categoryTreeMenuList']:
    if 'categoryId' not in item:
        continue
    resp = requests.get(f'https://sp.kaola.com/api/category/frontCategory?V330&categoryId={item["categoryId"]}').json()['body']
    # 'brandList', 'level2CategoryList'
    category_tree = {'categoryId': item['categoryId'], 'categoryName': item['title'],'childCategoryViewList':resp['level2CategoryList']}
    pprint(item)
    category_list.append(category_tree)
with open('kaola_category_tree.json','w') as f:
    f.write(json.dumps(category_list,indent=2,ensure_ascii=False))
# Out:
# {'categoryId': 8171, 'title': '美容彩妆', 'type': 2}
# {'categoryId': 8181, 'title': '奶粉纸尿裤', 'type': 2}
# {'categoryId': 8182, 'title': '母婴专区', 'type': 2}
# {'categoryId': 8183, 'title': '轻奢', 'type': 2}
# {'categoryId': 8185, 'title': '营养保健', 'type': 2}
# {'categoryId': 8184, 'title': '个人洗护', 'type': 2}
# {'categoryId': 8187, 'title': '手表配饰', 'type': 2}
# {'categoryId': 8188, 'title': '数码家电', 'type': 2}
# {'categoryId': 8190, 'title': '运动户外', 'type': 2}
# {'categoryId': 15413, 'title': '家居生活', 'type': 2}
# {'categoryId': 8189, 'title': '环球美食', 'type': 2}
# {'categoryId': 8186, 'title': '服饰鞋靴', 'type': 2}
# {'categoryId': 17236, 'title': '全球工厂店', 'type': 2}
# {'categoryId': 15424, 'title': '网易严选', 'type': 2}
# {'categoryId': 8191, 'title': '生鲜', 'type': 2}
# {'categoryId': 14757, 'title': '宠物生活', 'type': 2}
# {'categoryId': 14048, 'title': '考拉超市', 'type': 2}

# %%
import tablib
url = "http://dpp.boluome.com/https/generate"
tab_data = tablib.Dataset(headers=['一级分类','二级分类','三级分类','iconUrl'])
for category_1 in category_list:
    for category_2 in category_1['childCategoryViewList']:
        for category_3 in category_2['childCategoryViewList']:
            icon = category_3['iconUrl']
            os.system("wget {} -P /data/kaola/ -q".format(icon))
            new_icon = 'https://f1.otosaas.com/img/icon/kaola/'+ icon.split('/')[-1]
            response = requests.post(url,data={"https": new_icon},
                                     files={"image": open(f"/data/kaola/{icon.split('/')[-1]}", 'rb')}).json()

            tab_data.append([category_1['categoryName'],category_2['categoryName'],category_3['categoryName'],response['https']])
with open('kaola_category_tree.xlsx','wb') as f:
    f.write(tab_data.xlsx)

# %%
goods_info = {
        "goodsId": 28539, 
        "detail": """<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_0_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_500_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_1000_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_1500_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_2000_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_2500_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_3000_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_3500_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_4000_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_4500_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_5000_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_5500_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_6000_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_6500_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_7000_750_500\" /></p>
<p style=\"text-align:center;\"><img src=\"http://haitao.nos.netease.com/ff8b608f24c44dd592b3c1dc405752061515046612878jc03mw7i10358.jpg?imageView&quality=98&crop=0_7500_750_291\" /></p>""", 
        "store": 9007, 
        "imageUrl": "http://haitao.nos.netease.com/onlineia666tz711682.jpg", 
        "warehouseStores": {
            "深圳前海保税仓": {
                "warehouseName": "深圳前海保税仓", 
                "warehouseId": 2153, 
                "warehouseStore": 0
            }, 
            "杭州网仓仓库": {
                "warehouseName": "杭州网仓仓库", 
                "warehouseId": 13, 
                "warehouseStore": 9007
            }, 
            "宁波顺丰保税仓": {
                "warehouseName": "宁波顺丰保税仓", 
                "warehouseId": 6, 
                "warehouseStore": 0
            }, 
            "天津网仓保税仓": {
                "warehouseName": "天津网仓保税仓", 
                "warehouseId": 3554, 
                "warehouseStore": 0
            }, 
            "郑州保税仓": {
                "warehouseName": "郑州保税仓", 
                "warehouseId": 7, 
                "warehouseStore": 0
            }, 
            "杭州海仓科技有限公司东芝仓库": {
                "warehouseName": "杭州海仓科技有限公司东芝仓库", 
                "warehouseId": 46, 
                "warehouseStore": 0
            }, 
            "广州南沙保税仓": {
                "warehouseName": "广州南沙保税仓", 
                "warehouseId": 9001, 
                "warehouseStore": 0
            }, 
            "网易考拉杭州来福士直提店": {
                "warehouseName": "网易考拉杭州来福士直提店", 
                "warehouseId": 9281, 
                "warehouseStore": 0
            }, 
            "网易6号仓": {
                "warehouseName": "网易6号仓", 
                "warehouseId": 5, 
                "warehouseStore": 0
            }, 
            "重庆保税仓": {
                "warehouseName": "重庆保税仓", 
                "warehouseId": 3006, 
                "warehouseStore": 0
            }
        }, 
        "isFreeShipping": 1, 
        "onlineStatus": 1, 
        "brandId": 2052, 
        "brandName": "Aptamil 爱他美（澳洲）", 
        "subTitle": "爱他美白金版奶粉，在促进婴儿免疫系统、大脑发育和新陈代谢方面比爱他美普通版系列更优。而且奶粉无添加香料，不会造成宝宝口味的依赖。", 
        "recommandStore": {
            "warehouseName": "杭州网仓仓库", 
            "warehouseId": 13, 
            "warehouseStore": 9007
        }, 
        "title": "Aptamil 澳洲爱他美 Profutura 白金版婴儿奶粉 1段 900克/罐 2罐装", 
        "IsPostageFree": false, 
        "suggestPrice": 396, 
        "thirdCategoryName": "婴幼儿奶粉", 
        "logisticsProperty": null, 
        "skuId": "36938-68a3e5516d7a7dc21fbe0e7ee13bfc1c", 
        "goodsProperty": {
            "奶粉种类": [
                "牛奶粉"
            ], 
            "产地": [
                "新西兰"
            ], 
            "净含量": [
                "1-2千克"
            ], 
            "包装": [
                "罐装", 
                "组合装"
            ], 
            "存储方式": [
                "干燥通风处保存"
            ], 
            "适用阶段": [
                "一段"
            ], 
            "版本": [
                "澳洲白金版"
            ]
        }, 
        "isSelf": true, 
        "leafCategoryId": 626, 
        "isPresell": 0, 
        "marketPrice": 398, 
        "taxRate": 0.119, 
        "canReturnGoods": 0, 
        "taxRates": [
            0.119
        ], 
        "memberCount": 2, 
        "productId": 36938, 
        "brandCountryName": "新西兰", 
        "importType": 1, 
        "category": "婴幼儿牛奶粉 婴幼儿牛奶粉 婴幼儿奶粉 母婴", 
        "price": XXXXXX, 
        "skuProperty": [ ], 
        "shortTitle": "澳洲爱他美Profutura 白金版婴儿奶粉1段900克/罐2罐", 
        "goodsImages": [
            {
                "goodsId": 0, 
                "imageUrl": "http://haitao.nos.netease.com/onlineia666tz711682.jpg", 
                "imageType": 1, 
                "orderValue": 1, 
                "imageUrlFor70": "http://haitao.nos.netease.com/onlineia666tz711682_70_70.jpg", 
                "imageUrlFor430": "http://haitao.nos.netease.com/onlineia666tz711682_430_430.jpg", 
                "imageUrlFor640490": "http://haitao.nos.netease.com/onlineia666tz711682_640_490.jpg"
            }, 
            {
                "goodsId": 0, 
                "imageUrl": "http://haitao.nosdn5.127.net/iofbjdv011_800_800.jpg", 
                "imageType": 1, 
                "orderValue": 2, 
                "imageUrlFor70": "http://haitao.nosdn5.127.net/iofbjdv011_800_800_70_70.jpg", 
                "imageUrlFor430": "http://haitao.nosdn5.127.net/iofbjdv011_800_800_430_430.jpg", 
                "imageUrlFor640490": "http://haitao.nosdn5.127.net/iofbjdv011_800_800_640_490.jpg"
            }, 
            {
                "goodsId": 0, 
                "imageUrl": "http://haitao.nosdn2.127.net/iofbjekd54_800_800.jpg", 
                "imageType": 1, 
                "orderValue": 3, 
                "imageUrlFor70": "http://haitao.nosdn2.127.net/iofbjekd54_800_800_70_70.jpg", 
                "imageUrlFor430": "http://haitao.nosdn2.127.net/iofbjekd54_800_800_430_430.jpg", 
                "imageUrlFor640490": "http://haitao.nosdn2.127.net/iofbjekd54_800_800_640_490.jpg"
            }, 
            {
                "goodsId": 0, 
                "imageUrl": "http://haitao.nos.netease.com/iofbje2c82_800_800.jpg", 
                "imageType": 1, 
                "orderValue": 4, 
                "imageUrlFor70": "http://haitao.nos.netease.com/iofbje2c82_800_800_70_70.jpg", 
                "imageUrlFor430": "http://haitao.nos.netease.com/iofbje2c82_800_800_430_430.jpg", 
                "imageUrlFor640490": "http://haitao.nos.netease.com/iofbje2c82_800_800_640_490.jpg"
            }, 
            {
                "goodsId": 0, 
                "imageUrl": "http://haitao.nosdn5.127.net/iofbje7p64_800_800.jpg", 
                "imageType": 1, 
                "orderValue": 5, 
                "imageUrlFor70": "http://haitao.nosdn5.127.net/iofbje7p64_800_800_70_70.jpg", 
                "imageUrlFor430": "http://haitao.nosdn5.127.net/iofbje7p64_800_800_430_430.jpg", 
                "imageUrlFor640490": "http://haitao.nosdn5.127.net/iofbje7p64_800_800_640_490.jpg"
            }, 
            {
                "goodsId": 0, 
                "imageUrl": "http://haitao.nosdn3.127.net/iofbjec728_800_800.jpg", 
                "imageType": 1, 
                "orderValue": 6, 
                "imageUrlFor70": "http://haitao.nosdn3.127.net/iofbjec728_800_800_70_70.jpg", 
                "imageUrlFor430": "http://haitao.nosdn3.127.net/iofbjec728_800_800_430_430.jpg", 
                "imageUrlFor640490": "http://haitao.nosdn3.127.net/iofbjec728_800_800_640_490.jpg"
            }
        ], 
        "storage": "杭州网仓仓库", 
        "isFreeTax": 1, 
        "thirdCategoryId": 4891
    }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1e68f3081a23> in <module>()
#      82         },
#      83         "title": "Aptamil 澳洲爱他美 Profutura 白金版婴儿奶粉 1段 900克/罐 2罐装",
# ---> 84         "IsPostageFree": false,
#      85         "suggestPrice": 396,
#      86         "thirdCategoryName": "婴幼儿奶粉",
#
# NameError: name 'false' is not defined

# %%
from connection import ConnectionTask
c = ConnectionTask()
rdb = c.dpprdb(0)

# %%
old_sku_id_set = rdb.get('dpp:shopping:kaola:goodsIdSet')
print(old_sku_id_set)
# Out:
# {'1602474', '1541761', '1234523', '1407106', '18218', '1569054', '1623313', '1465921', '20011234961', '00003243561', '158919', '1305439', '1373028', '1486232', '157866', '1440379', '1804940', '00001862411', '1420272', '279240', '1885279', '22784', '279179', '00001983401', '1579651', '1833482', '1494232', '271696', '18406', '00003133091', '1374444', '1488767', '1956754', '1634783', '17749', '20548', '1875242', '2025855', '22483', '1313536', '1267051', '22513', '13828', '1811932', '1485286', '295552', '1477575', '2024277', '1508476', '158897', '1970243', '1801780', '1263134', '1545350', '28626', '20011234681', '00001983781', '20011234381', '1479110', '43394', '1790446', '1233971', '1558288', '1416149', '18548', '1577666', '00005643781', '1820268', '13884', '1376644', '1649390', '1511943', '1645188', '256350', '1454093', '18977', '283462', '1834473', '1894160', '1980845', '18347', '156983', '1579707', '143938', '749368', '00002101271', '274033', '1399394', '1231232', '1572342', '1634789', '1624756', '271672', '2031433', '157044', '1925063', '157094', '1957395', '00003133141', '1600051', '1925213', '1792711', '1126516', '30157', '1556707', '1977981', '1922357', '2025658', '1862428', '158926', '158526', '26695', '1928594', '1310356', '14132', '158528', '1235117', '1317212', '343799', '1229378', '10657', '1390689', '00004921521', '258616', '00002331011', '1235472', '156179', '1545590', '1838174', '2002523', '1978699', '1423526', '1381094', '1400586', '1967037', '1301605', '7818', '1234299', '1566801', '1912142', '9712', '1234078', '1644189', '276251', '1895039', '1793410', '295723', '279358', '19678', '1973763', '157788', '1953978', '1827483', '999364', '1838872', '1402263', '1511940', '00001588351', '1395418', '1377995', '279395', '1233180', '157143', '1566796', '1407956', '2022890', '26363', '140519', '9242', '1452309', '1545151', '9253', '1318923', '1488783', '1588126', '1443593', '25735', '1946801', '1891751', '303826', '1601805', '1412295', '20011233201', '2029358', '1476702', '1838557', '1946781', '1452314', '1606043', '1491983', '1541754', '1511916', '7824', '1398031', '1794842', '1623343', '1633196', '1572359', '17472', '1600919', '23768', '1547589', '1820252', '158293', '1565997', '1315577', '1569709', '1577223', '1366771', '1257668', '1485146', '1473131', '1842518', '143943', '1878008', '1566791', '1374419', '1602360', '158884', '157375', '1888350', '1316514', '1234316', '1407949', '1761261', '1306858', '22047', '8533', '1648435', '1556409', '1545676', '157787', '256426', '1908771', '945462', '1851129', '1837999', '1606092', '1075357', '1396046', '1541319', '1337931', '1422243', '1790689', '1505398', '14129', '1565913', '290832', '1790527', '43382', '1498043', '1978798', '19173', '00003121341', '17624', '157114', '1235466', '1387214', '1761739', '990869', '9251', '157841', '1539097', '1559663', '17752', '1420726', '1790691', '1545666', '157107', '00004146131', '1379429', '1569045', '00004149840', '1641001', '1624976', '1566026', '1378010', '1485960', '1572348', '1572357', '1837890', '1955930', '2027886', '156881', '1476755', '1612317', '1991232', '295509', '1617993', '2027867', '1401392', '1242651', '1125537', '00002081531', '22421', '1434833', '1395350', '152770', '324915', '1837974', '1421164', '1485969', '1833488', '1541304', '279296', '1410947', '13141', '1374168', '158731', '1836565', '273764', '1961017', '2031431', '1583533', '20005805031', '1422478', '1260599', '1894436', '21712', '43354', '1566894', '271526', '1484241', '2002362', '157955', '1453141', '20011241081', '1624428', '1483355', '1941874', '1546617', '1614408', '19148', '157931', '2008085', '1953682', '1506660', '17255', '27056', '144355', '1541317', '1872974', '157953', '158932', '157054', '1376513', '23367', '1431046', '1546796', '1835900', '1614641', '18426', '5384', '1535342', '00001989891', '1481780', '673846', '00004955871', '1573040', '29333', '1380417', '1326647', '156010', '1380522', '36905', '271036', '1986745', '1797239', '295679', '1381774', '1 ...

# %%
old_goods_id_set = ast.literal_eval(old_goods_id_set) if old_goods_id_set else set()
new_goods_id_set = set(goods_sku_tree.keys())
remove_goods_id_set = old_goods_id_set - new_goods_id_set
self.rdb.set('dpp:shopping:kaola:goodsIdSet', new_goods_id_set)
