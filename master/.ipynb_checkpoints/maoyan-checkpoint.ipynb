# %%
import requests
from connection import ConnectionTask as ConnectTask
import time
import hashlib
import json
from pprint import pprint
c=ConnectTask()

# %%
# 测试环境地址：http://movie.test.maoyan.com
# 渠道id：1000014
# 渠道key：A013F70DB97834C0A5492378BD76C53A
# ID="1000014"
# KEY="A013F70DB97834C0A5492378BD76C53A"
# url_head="http://movie.test.maoyan.com"
ID = "1000058"
KEY = "cw8jhcd1lld0b5c3szq890wgxrq376cc"
url_head = "http://open.maoyan.com/api/"

# %% [markdown]
# ### 2.1 查询影院列表 s

# %%
url_tail="/sync/gateway"
api_name="gateway.sync.cinemas"
data={
    "merCode":ID,
     "timestamp":int(time.time()),
     "version":"1.0",
     "signType":"MD5",
     "api":api_name}
md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
data["signMsg"]=sign

resp_data=requests.post(url=url_head+url_tail,data=data).json()
resp_data
# pprint(resp_data)
# for item in resp_data['data']['data']:
#     cinema_id=item.pop("cinemaId")
#     c.dev.dianying_cinema_mao.update_one({"cinemaId":cinema_id},
#                                  {"$set":item},upsert=True)
# Out:
# {'api': 'gateway.sync.cinemas',
#  'code': '0',
#  'data': {'bizCode': '0',
#   'bizMsg': 'SUCCESS',
#   'data': [{'areaName': '西湖区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '余杭塘路与崇仁路交叉口西溪银泰城A座3层',
#     'cinemaId': 24341,
#     'cinemaName': '博纳国际影城(西溪IMAX店)',
#     'cityId': '50',
#     'cityName': '杭州',
#     'dis': '',
#     'districtId': '59',
#     'features': [],
#     'latitude': '30.293697',
#     'locationId': '330106',
#     'longitude': '120.075325',
#     'note': '',
#     'stdCinemaCode': '33018631',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0571-28282898'},
#    {'areaName': '密云区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '滨河路178号万象汇购物中心4层',
#     'cinemaId': 24340,
#     'cinemaName': '博纳国际影城(密云店)',
#     'cityId': '1',
#     'cityName': '北京',
#     'dis': '',
#     'districtId': '2074',
#     'features': [{'featureDesc': '3D眼镜免费领用，另有自费3D眼镜售卖。',
#       'featureName': '3D眼镜：'},
#      {'featureDesc': '地下车库24小时免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1米以下儿童不建议观看4d影片，1米以上儿童需购票', 'featureName': '儿童优惠：'}],
#     'latitude': '40.356377',
#     'locationId': '110228',
#     'longitude': '116.836586',
#     'note': 'MX4D观影不适合以下人群：老人、孕妇、1米以下儿童、心脏病患者、头、颈、背、腿受伤人士、较难保持平衡、站立、行走的人群、以及对气味或雾特效过敏的人士。',
#     'stdCinemaCode': '11171291',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '010-53951168'},
#    {'areaName': '岳阳楼区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '青年东路沃尔玛广场4楼',
#     'cinemaId': 24317,
#     'cinemaName': '金逸巨幕影城(岳阳店)',
#     'cityId': '267',
#     'cityName': '岳阳',
#     'dis': '',
#     'districtId': '3514',
#     'features': [],
#     'latitude': '29.365065',
#     'locationId': '430602',
#     'longitude': '113.16916',
#     'note': '',
#     'stdCinemaCode': '43063101',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0730-2991630'},
#    {'areaName': '丰台区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '南四环西路76号北京花乡奥莱村第十三号楼三层四层',
#     'cinemaId': 24263,
#     'cinemaName': '耀莱成龙国际影城(花乡店)',
#     'cityId': '1',
#     'cityName': '北京',
#     'dis': '',
#     'districtId': '20',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '花乡奥莱村免费停车楼', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下儿童观看2D、3D及杜比全景声影片免费，4DX影片半价.',
#       'featureName': '儿童优惠：'}],
#     'latitude': '39.82602',
#     'locationId': '110106',
#     'longitude': '116.3231',
#     'note': '4DX影厅温馨提示：孕妇、心血管疾病患者、老弱残者、易晕眩者、4岁以下及1.3米以下儿童均不适合观看。<br/>会员政策：<br/>银卡：300元起充，享受全天40元观影（特殊影厅除外），每场限购6张，卖品单品9折优惠，周三会员日25元通看（特殊影厅除外）。<br/>钻卡：500元起充，享受全天35元观影（特殊影厅除外），每场限购6张，卖品单品9折优惠，周三会员日25元通看（特殊影厅除外）。<br/>优惠活动：<br/>周一女神日：非会员女士购票享受门市半价优惠<br/>周二半价日：非会员购票享受门市半价优惠<br/>周四男神日：非会员男士购票享受门市半价优惠',
#     'stdCinemaCode': '11071271',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '010-83711556'},
#    {'areaName': '吴中区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '工业园区苏州中心商场南区6楼14号CGV影城',
#     'cinemaId': 24234,
#     'cinemaName': 'CGV影城(苏州中心IMAX店)',
#     'cityId': '80',
#     'cityName': '苏州',
#     'dis': '',
#     'districtId': '71',
#     'features': [{'featureDesc': '影城提供3D眼镜，不收费，免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '12月31日前苏州中心商场免费停车，观影建议停至南区P4停车场', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下儿童观看普通厅免费无座，需家长陪同，每名成人可免费携带一名儿童，观看IMAX厅、GOLD CLASS厅、4DX厅需购票。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '31.314896',
#     'locationId': '320506',
#     'longitude': '120.6773',
#     'note': '温馨提示：<br/>1、10:00前、22:00后观影请从商场南S7门（星巴克臻选店向南约30米）乘直梯进入影城，或将车停放在南区停车场P4，乘直梯进入影城。<br/>2、苏州中心商场南区、北区停车场不互通，夜间观影建议将您的车辆停至苏州中心商场南区P4停车场。<br/>3、如有疑问请播客服电话 0512-69881886',
#     'stdCinemaCode': '32029591',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0512-69881886'},
#    {'areaName': '江阴市',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '云亭街道银桂路29号美嘉城4楼',
#     'cinemaId': 24195,
#     'cinemaName': '金逸影城(美嘉城IMAX店)',
#     'cityId': '52',
#     'cityName': '无锡',
#     'dis': '',
#     'districtId': '895',
#     'features': [],
#     'latitude': '31.887695',
#     'locationId': '320281',
#     'longitude': '120.332306',
#     'note': '',
#     'stdCinemaCode': '32039151',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0510-86158666'},
#    {'areaName': '海安县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '雅周镇世纪路11号',
#     'cinemaId': 24191,
#     'cinemaName': '幸福蓝海国际影城(雅周店)',
#     'cityId': '82',
#     'cityName': '南通',
#     'dis': '',
#     'districtId': '2764',
#     'features': [{'featureDesc': '5元/副', 'featureName': '3D眼镜：'},
#      {'featureDesc': '门口免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1号厅   2号厅  3号厅  都 有情侣座', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.2米以下儿童观看2D影片免票，须家长陪同', 'featureName': '儿童优惠：'}],
#     'latitude': '32.39996',
#     'locationId': '320621',
#     'longitude': '120.33264',
#     'note': '',
#     'stdCinemaCode': '32108911',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '18944315668'},
#    {'areaName': '昆山市',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '张浦镇新吴街1100号',
#     'cinemaId': 24172,
#     'cinemaName': '保利国际影城(张浦文化广场店)',
#     'cityId': '80',
#     'cityName': '苏州',
#     'dis': '',
#     'districtId': '5229',
#     'features': [{'featureDesc': '免费提供3D眼镜，未购票儿童不提供', 'featureName': '3D眼镜：'},
#      {'featureDesc': '地面及地下停车场，全时段免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '一名购票观众可携带一名1.3米以下儿童免费观影，免费观影儿童不占座',
#       'featureName': '儿童优惠：'}],
#     'latitude': '31.283012',
#     'locationId': '320583',
#     'longitude': '120.931984',
#     'note': '',
#     'stdCinemaCode': '32029581',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0512-57225566'},
#    {'areaName': '大理市',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 5,
#     'cinemaAddr': '下关镇建设东路31号时代天街4层',
#     'cinemaId': 24151,
#     'cinemaName': '博纳IMAX国际影城(大理店)',
#     'cityId': '341',
#     'cityName': '大理',
#     'dis': '',
#     'districtId': '8015',
#     'features': [],
#     'latitude': '25.585632',
#     'locationId': '532901',
#     'longitude': '100.22855',
#     'note': '禁止外带食品',
#     'stdCinemaCode': '53293701',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0872-2535999'},
#    {'areaName': '黄岛区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '海景路777号隆和福朋喜来登酒店南',
#     'cinemaId': 24150,
#     'cinemaName': '博纳国际影城(青岛店)',
#     'cityId': '60',
#     'cityName': '青岛',
#     'dis': '',
#     'districtId': '137',
#     'features': [{'featureDesc': '免费停车', 'featureName': '可停车：'}],
#     'latitude': '35.874687',
#     'locationId': '370211',
#     'longitude': '120.05466',
#     'note': '',
#     'stdCinemaCode': '37037311',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0532-86615577'},
#    {'areaName': '翔安区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '鼓锣一里61号119号闽篮城市广场三楼之一',
#     'cinemaId': 24133,
#     'cinemaName': '金逸影城(洋塘店)',
#     'cityId': '62',
#     'cityName': '厦门',
#     'dis': '',
#     'districtId': '105',
#     'features': [{'featureDesc': '普通3D眼镜3元一副，夹片12元一副', 'featureName': '3D眼镜：'},
#      {'featureDesc': '凭两张当日电影票根免费停车4小时', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下儿童无需购票，一位成人可携带一名儿童进场', 'featureName': '儿童优惠：'}],
#     'latitude': '24.575035',
#     'locationId': '350213',
#     'longitude': '118.24506',
#     'note': '6号厅为杜比全景声厅，182个座位<br/>8号厅为VIP厅，22个座位',
#     'stdCinemaCode': '35023871',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0592-7278811 0592-7278812'},
#    {'areaName': '蔡甸区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '蔡甸街新福路新福茂中央广场第四层',
#     'cinemaId': 24109,
#     'cinemaName': '金逸影城(蔡甸IMAX店)',
#     'cityId': '57',
#     'cityName': '武汉',
#     'dis': '',
#     'districtId': '3402',
#     'features': [{'featureDesc': '3D眼镜需要自备或到影院购买', 'featureName': '3D眼镜：'},
#      {'featureDesc': '本商场免费停车2小时', 'featureName': '可停车：'},
#      {'featureDesc': '1.3以下儿童观看普通2D、3D影片免票，无眼镜（需家长陪同，每一位家长限带一名儿童）：观看IMAX3D影片大人小孩均需购票',
#       'featureName': '儿童优惠：'}],
#     'latitude': '30.580269',
#     'locationId': '420114',
#     'longitude': '114.03184',
#     'note': '亲爱的观众，为了保护您的眼部健康，感受高品质的观影体验，自2017年6月起，本影城不再提供公用3D眼镜，建议您自备3D眼镜或至影院5元起购（IMAX厅除外），一次购买，多次使用！',
#     'stdCinemaCode': '42019411',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '027-69114689'},
#    {'areaName': '港口镇',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '港口大道19号保利广场四层401号',
#     'cinemaId': 24108,
#     'cinemaName': '保利国际影城(中山港口店)',
#     'cityId': '113',
#     'cityName': '中山',
#     'dis': '',
#     'districtId': '5766',
#     'features': [{'featureDesc': '5元/副', 'featureName': '3D眼镜：'},
#      {'featureDesc': '免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下儿童观看2D影片免票无座，需家长陪同，观看3D影片需购全票',
#       'featureName': '儿童优惠：'}],
#     'latitude': '22.58145',
#     'locationId': '4420017',
#     'longitude': '113.39321',
#     'note': '周二现场购票半价，周三会员购票半价',
#     'stdCinemaCode': '44116301',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0760-88513888'},
#    {'areaName': '滨江区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '江汉路1515号龙湖滨江天街5楼',
#     'cinemaId': 24082,
#     'cinemaName': 'CGV影城(滨江天街IMAX店)',
#     'cityId': '50',
#     'cityName': '杭州',
#     'dis': '',
#     'districtId': '60',
#     'features': [{'featureDesc': '影院免费提供3D眼镜', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.3以下儿童普通厅观影需家长陪同无座免票，IMAX厅，4DX厅，SphereX厅儿童均需购买影票',
#       'featureName': '儿童优惠：'}],
#     'latitude': '30.202332',
#     'locationId': '330108',
#     'longitude': '120.20426',
#     'note': '',
#     'stdCinemaCode': '33018591',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0571-87751515'},
#    {'areaName': '沙坪坝区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '大学城北路97号购物广场第2、3、4、5层',
#     'cinemaId': 24052,
#     'cinemaName': 'CGV影城(U城IMAX店)',
#     'cityId': '45',
#     'cityName': '重庆',
#     'dis': '',
#     'districtId': '41',
#     'features': [],
#     'latitude': '29.60643',
#     'locationId': '500106',
#     'longitude': '106.29336',
#     'note': '',
#     'stdCinemaCode': '50060161',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '023-67120022'},
#    {'areaName': '龙岗区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '葵涌街道葵新北路东侧农贸综合市场2﹟3楼',
#     'cinemaId': 24018,
#     'cinemaName': '卡思国际影城',
#     'cityId': '30',
#     'cityName': '深圳',
#     'dis': '',
#     'districtId': '33',
#     'features': [{'featureDesc': '3D眼镜需自带或到前台购买', 'featureName': '3D眼镜：'},
#      {'featureDesc': '凭票根免费停车3小时，3小时后参考物业收费信息', 'featureName': '可停车：'},
#      {'featureDesc': '1._3m(不含）以下儿童观看__2D/3D__影片免票（3D不免费提供眼镜）一名成人只限携带一名儿童',
#       'featureName': '儿童优惠：'}],
#     'latitude': '22.63386',
#     'locationId': '440307',
#     'longitude': '114.4204',
#     'note': '',
#     'stdCinemaCode': '44012391',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0755-89458802'},
#    {'areaName': '和县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 5,
#     'cinemaAddr': '郑蒲港新区镇淮中路803号',
#     'cinemaId': 24017,
#     'cinemaName': '中影国际影城(郑蒲港店)',
#     'cityId': '194',
#     'cityName': '马鞍山',
#     'dis': '',
#     'districtId': '7426',
#     'features': [],
#     'latitude': '31.623524',
#     'locationId': '340523',
#     'longitude': '118.33198',
#     'note': '3D眼镜免押金<br/>提供免费WiFi<br/>1.3米以下儿童免票，需在家长陪同（无座）<br/>商场地下车库免费停车<br/>影城VIP会员卡，观影5折优惠，卖品8.8折优惠，会员生日当天可免费观影1次',
#     'stdCinemaCode': '34052501',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0555-5513666'},
#    {'areaName': '东湖区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '阳明东路66号投资大厦商业裙楼四楼',
#     'cinemaId': 23997,
#     'cinemaName': '聚丰主题影城(央央春天店)',
#     'cityId': '83',
#     'cityName': '南昌',
#     'dis': '',
#     'districtId': '173',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '停车场在负二楼。', 'featureName': '可停车：'},
#      {'featureDesc': '1.3m以下儿童观看2D影片免费无座。', 'featureName': '儿童优惠：'},
#      {'featureDesc': '影院免费提供WiFi。', 'featureName': 'WiFi：'}],
#     'latitude': '28.686892',
#     'locationId': '360102',
#     'longitude': '115.9046',
#     'note': '',
#     'stdCinemaCode': '36016501',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0791-87398189'},
#    {'areaName': '闵行区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '莲花南路1388弄7号3层L3-01铺位',
#     'cinemaId': 23986,
#     'cinemaName': '博纳国际影城(新荟城店)',
#     'cityId': '10',
#     'cityName': '上海',
#     'dis': '',
#     'districtId': '12',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '凭票根免费停3小时', 'featureName': '可停车：'},
#      {'featureDesc': '1.2米以下儿童免票无座，需成人陪同观影', 'featureName': '儿童优惠：'}],
#     'latitude': '31.100668',
#     'locationId': '310112',
#     'longitude': '121.411835',
#     'note': '',
#     'stdCinemaCode': '31115901',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '021-33509965'},
#    {'areaName': '清河门区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '大商天林百货五楼',
#     'cinemaId': 23981,
#     'cinemaName': '乐娱影城',
#     'cityId': '156',
#     'cityName': '阜新',
#     'dis': '',
#     'districtId': '2465',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '41.786392',
#     'locationId': '210905',
#     'longitude': '121.413704',
#     'note': '',
#     'stdCinemaCode': '21090081',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0418-6222100'},
#    {'areaName': '右江区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 5,
#     'cinemaAddr': '中山二路森林中心城1楼',
#     'cinemaId': 23953,
#     'cinemaName': '星星国际影城(森林公园店)',
#     'cityId': '297',
#     'cityName': '百色',
#     'dis': '',
#     'districtId': '3768',
#     'features': [],
#     'latitude': '23.89605',
#     'locationId': '451002',
#     'longitude': '106.61554',
#     'note': '',
#     'stdCinemaCode': '45080171',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0776-8880020'},
#    {'areaName': '荆州区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '楚源路与荆楚大道交汇处恒大影城三层',
#     'cinemaId': 23951,
#     'cinemaName': '恒大影城(名都店)',
#     'cityId': '257',
#     'cityName': '荆州',
#     'dis': '',
#     'districtId': '3461',
#     'features': [],
#     'latitude': '30.359692',
#     'locationId': '421003',
#     'longitude': '112.21475',
#     'note': '',
#     'stdCinemaCode': '42033501',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0716-8200555'},
#    {'areaName': '濂溪区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '前进东路九江新天地五楼',
#     'cinemaId': 23949,
#     'cinemaName': '耀莱成龙国际影城(学院店)',
#     'cityId': '115',
#     'cityName': '九江',
#     'dis': '',
#     'districtId': '3031',
#     'features': [],
#     'latitude': '29.67472',
#     'locationId': '360402',
#     'longitude': '116.00602',
#     'note': '',
#     'stdCinemaCode': '36045001',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0792-8820011'},
#    {'areaName': '二七区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '航海路与兴华南街西南角新龙汇时代广场2层',
#     'cinemaId': 23948,
#     'cinemaName': '溯时光奥斯卡影城',
#     'cityId': '73',
#     'cityName': '郑州',
#     'dis': '',
#     'districtId': '167',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '详询商家', 'featureName': '可停车：'},
#      {'featureDesc': '1.3m以下儿童观看2D普通电影免票，每个成年人仅限带一名儿童。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '34.71985',
#     'locationId': '410103',
#     'longitude': '113.63196',
#     'note': '周二会员日半价优惠',
#     'stdCinemaCode': '41019701',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0371-55010007 0371-56048777'},
#    {'areaName': '蚌山区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 2,
#     'cinemaAddr': '淮河路981号百大购物中心2栋10楼',
#     'cinemaId': 23947,
#     'cinemaName': '蚌埠中影凯得利影城',
#     'cityId': '88',
#     'cityName': '蚌埠',
#     'dis': '',
#     'districtId': '2876',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '32.94496',
#     'locationId': '340303',
#     'longitude': '117.36464',
#     'note': '',
#     'stdCinemaCode': '34032401',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0552-2050286'},
#    {'areaName': '渝中区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 1,
#     'cinemaAddr': '邹容路68号大都会东方广场第6层L622号',
#     'cinemaId': 23946,
#     'cinemaName': '越界影城(解放碑店)',
#     'cityId': '45',
#     'cityName': '重庆',
#     'dis': '',
#     'districtId': '40',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '130cm以下儿童免票，无座', 'featureName': '儿童优惠：'}],
#     'latitude': '29.55785',
#     'locationId': '500103',
#     'longitude': '106.578674',
#     'note': '',
#     'stdCinemaCode': '50030261',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '023-63006500'},
#    {'areaName': '宛城区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '孔明路与独山大道交叉口建业凯旋广场四层',
#     'cinemaId': 23945,
#     'cinemaName': '耀莱成龙国际影城(孔明南路店)',
#     'cityId': '244',
#     'cityName': '南阳',
#     'dis': '',
#     'districtId': '3359',
#     'features': [],
#     'latitude': '32.99503',
#     'locationId': '411302',
#     'longitude': '112.57648',
#     'note': '',
#     'stdCinemaCode': '41134401',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0377-60679666'},
#    {'areaName': '瑶海区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '武里山天街A区4层',
#     'cinemaId': 23944,
#     'cinemaName': '华谊兄弟影院(武里山天街店)',
#     'cityId': '56',
#     'cityName': '合肥',
#     'dis': '',
#     'districtId': '197',
#     'features': [{'featureDesc': '武里山天街地下停车场1000个', 'featureName': '可停车：'},
#      {'featureDesc': '1.3m以下儿童免票无座观影（每位顾客限带1名1.3m以下儿童，VIP厅除外）',
#       'featureName': '儿童优惠：'}],
#     'latitude': '31.899094',
#     'locationId': '340102',
#     'longitude': '117.32067',
#     'note': '',
#     'stdCinemaCode': '34018201',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0551-66019990'},
#    {'areaName': '泰兴市',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 1,
#     'cinemaAddr': '阳江中路9号碧云商业广场B2商业楼3楼',
#     'cinemaId': 23943,
#     'cinemaName': '永乐国际影城(泰兴店)',
#     'cityId': '183',
#     'cityName': '泰州',
#     'dis': '',
#     'districtId': '2754',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '免费停车', 'featureName': '可停车：'}],
#     'latitude': '32.19626',
#     'locationId': '321283',
#     'longitude': '120.0242',
#     'note': '4K巨幕杜比全景声厅、儿童特色影厅',
#     'stdCinemaCode': '32134911',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0523-87368686'},
#    {'areaName': '南关区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '临河街与南三环交汇南行100米',
#     'cinemaId': 23942,
#     'cinemaName': '中影touch影城',
#     'cityId': '116',
#     'cityName': '长春',
#     'dis': '',
#     'districtId': '156',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.3米以下儿童观影免费，需家长陪同', 'featureName': '儿童优惠：'}],
#     'latitude': '43.817913',
#     'locationId': '220102',
#     'longitude': '125.36414',
#     'note': '',
#     'stdCinemaCode': '22115701',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0431-82537878'},
#    {'areaName': '钟楼区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 5,
#     'cinemaAddr': '北大街2-8号常州新世纪商城B座12、13楼',
#     'cinemaId': 23941,
#     'cinemaName': '中影国际影城(新世纪店)',
#     'cityId': '89',
#     'cityName': '常州',
#     'dis': '',
#     'districtId': '2771',
#     'features': [{'featureDesc': '免费提供', 'featureName': '3D眼镜：'},
#      {'featureDesc': '成人电影1.3米以下儿童无需购票（1号厅和3号厅除外），动画片儿童需购票，半价。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '31.780216',
#     'locationId': '320404',
#     'longitude': '119.95558',
#     'note': '',
#     'stdCinemaCode': '32045411',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0519-68207788'},
#    {'areaName': '长清区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '长清大学科技园数娱广场A座一层西侧',
#     'cinemaId': 23940,
#     'cinemaName': '新世纪电影城(数娱广场店)',
#     'cityId': '96',
#     'cityName': '济南',
#     'dis': '',
#     'districtId': '144',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '户外停车场，可免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1.3m以下儿童观看电影免票，每个成年人仅限带一名儿童', 'featureName': '儿童优惠：'},
#      {'featureDesc': '影院提供免费WIFI', 'featureName': 'WiFi：'}],
#     'latitude': '36.55496',
#     'locationId': '370113',
#     'longitude': '116.819336',
#     'note': '',
#     'stdCinemaCode': '37027261',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0531-66585858'},
#    {'areaName': '惠山区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '石澄路新盛百邻广场四楼',
#     'cinemaId': 23939,
#     'cinemaName': '耀莱成龙国际影城(石澄路店)',
#     'cityId': '52',
#     'cityName': '无锡',
#     'dis': '',
#     'districtId': '88',
#     'features': [{'featureDesc': '无需押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '地下停车场免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下儿童观影免票无座，需家长陪同', 'featureName': '儿童优惠：'}],
#     'latitude': '31.628271',
#     'locationId': '320206',
#     'longitude': '120.28854',
#     'note': '每周二全天现金半价日，会员无折上折',
#     'stdCinemaCode': '32039131',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0510-83750996'},
#    {'areaName': '陇县',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '宝平路北50米',
#     'cinemaId': 23938,
#     'cinemaName': '美得亨环球影院',
#     'cityId': '353',
#     'cityName': '宝鸡',
#     'dis': '',
#     'districtId': '4307',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '34.88763',
#     'locationId': '610327',
#     'longitude': '106.854294',
#     'note': '',
#     'stdCinemaCode': '61032501',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0917-4609222'},
#    {'areaName': '江东区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '宁穿路1462号宏泰广场北区2幢F408商铺',
#     'cinemaId': 23937,
#     'cinemaName': '博纳国际影城(宏泰店)',
#     'cityId': '51',
#     'cityName': '宁波',
#     'dis': '',
#     'districtId': '78',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '', 'featureName': '可停车：'},
#      {'featureDesc': '一号厅最后一排', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.2（含）米以下免坐无票，需成人陪同，每位成人限带一名儿童',
#       'featureName': '儿童优惠：'}],
#     'latitude': '29.860172',
#     'locationId': '330204',
#     'longitude': '121.61368',
#     'note': '',
#     'stdCinemaCode': '33049801',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0574-81879677'},
#    {'areaName': '成华区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '洪山路28号1栋1单元401—408号',
#     'cinemaId': 23935,
#     'cinemaName': '中影ul城市影院',
#     'cityId': '59',
#     'cityName': '成都',
#     'dis': '',
#     'districtId': '37',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '免费wifi', 'featureName': 'WiFi：'}],
#     'latitude': '30.705332',
#     'locationId': '510108',
#     'longitude': '104.09501',
#     'note': '',
#     'stdCinemaCode': '51015871',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '02883250181'},
#    {'areaName': '望城区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 1,
#     'cinemaAddr': '正荣财富中心三层',
#     'cinemaId': 23934,
#     'cinemaName': '大地影院(正荣财富中心店)',
#     'cityId': '70',
#     'cityName': '长沙',
#     'dis': '',
#     'districtId': '3493',
#     'features': [{'featureDesc': '免费提供3D眼镜，夹片眼镜，儿童眼镜', 'featureName': '3D眼镜：'},
#      {'featureDesc': '地下停车场免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下免费', 'featureName': '儿童优惠：'}],
#     'latitude': '28.349789',
#     'locationId': '430112',
#     'longitude': '112.830956',
#     'note': '',
#     'stdCinemaCode': '43019901',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0731-88329563'},
#    {'areaName': '汉川市',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '马口镇惠丰广场3楼',
#     'cinemaId': 23933,
#     'cinemaName': '华夏国际影城马口店',
#     'cityId': '256',
#     'cityName': '孝感',
#     'dis': '',
#     'districtId': '3431',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '30.565565',
#     'locationId': '420984',
#     'longitude': '113.83782',
#     'note': '',
#     'stdCinemaCode': '42072601',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '13329901182'},
#    {'areaName': '二七区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 3,
#     'cinemaAddr': '五彩路•民主路华润万象城5楼西',
#     'cinemaId': 23931,
#     'cinemaName': '建业艾米1895电影街万象城店',
#     'cityId': '73',
#     'cityName': '郑州',
#     'dis': '',
#     'districtId': '167',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.3米以下儿童免费（不占座）3D眼镜免费提供（凭票免费提供，免票儿童不提供，需自带或自购）',
#       'featureName': '儿童优惠：'},
#      {'featureDesc': '影院提供免费WIFI', 'featureName': 'WiFi：'}],
#     'latitude': '34.75488',
#     'locationId': '410103',
#     'longitude': '113.6618',
#     'note': '',
#     'stdCinemaCode': '41019601',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0371-56161895'},
#    {'areaName': '兴山县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '昭君路10号',
#     'cinemaId': 23929,
#     'cinemaName': '兴山和美影院',
#     'cityId': '252',
#     'cityName': '宜昌',
#     'dis': '',
#     'districtId': '3477',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '门前广场可停车', 'featureName': '可停车：'}],
#     'latitude': '31.347702',
#     'locationId': '420526',
#     'longitude': '110.7514',
#     'note': '',
#     'stdCinemaCode': '42053201',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0717-2582885'},
#    {'areaName': '顺德区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '北滘镇人昌路美的新都荟广场二楼',
#     'cinemaId': 23928,
#     'cinemaName': '艺达国际影城(北滘店)',
#     'cityId': '92',
#     'cityName': '佛山',
#     'dis': '',
#     'districtId': '185',
#     'features': [{'featureDesc': '免费提供3D眼镜', 'featureName': '3D眼镜：'},
#      {'featureDesc': '凭当天影票可免费停车3小时', 'featureName': '可停车：'},
#      {'featureDesc': '1.3m儿童观影免票无座', 'featureName': '儿童优惠：'}],
#     'latitude': '22.929447',
#     'locationId': '440606',
#     'longitude': '113.217705',
#     'note': '',
#     'stdCinemaCode': '44131201',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0757-26669989'},
#    {'areaName': '兰山区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '柳青街道济南路中段南侧齐鲁园广场8楼801',
#     'cinemaId': 23923,
#     'cinemaName': '中影星美国际影城(齐鲁园店)',
#     'cityId': '230',
#     'cityName': '临沂',
#     'dis': '',
#     'districtId': '3195',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '商场地上周围及地下停车场凭电影票免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1.3m以下儿童观看2D普通电影免票，每个成年人仅限带一名儿童。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '35.112885',
#     'locationId': '371302',
#     'longitude': '118.35642',
#     'note': '',
#     'stdCinemaCode': '37087241',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0539-8601806'},
#    {'areaName': '江汉区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '江汉路187号M+购物广场6楼',
#     'cinemaId': 23922,
#     'cinemaName': '橙天嘉禾影城(M+购物广场店)',
#     'cityId': '57',
#     'cityName': '武汉',
#     'dis': '',
#     'districtId': '108',
#     'features': [],
#     'latitude': '30.584036',
#     'locationId': '420103',
#     'longitude': '114.28623',
#     'note': '',
#     'stdCinemaCode': '42019351',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '027-59300093'},
#    {'areaName': '南山区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '前海路泛海城市广场1栋227号',
#     'cinemaId': 23921,
#     'cinemaName': '泛海国际影城',
#     'cityId': '30',
#     'cityName': '深圳',
#     'dis': '',
#     'districtId': '30',
#     'features': [{'featureDesc': '自费购买, 5.0元每副', 'featureName': '3D眼镜：'},
#      {'featureDesc': '商场地下一层有停车场', 'featureName': '可停车：'},
#      {'featureDesc': '3号厅为VIP-情侣厅', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.3m以下儿童可免费观影，无座位，每个成年人仅限带一名儿童。',
#       'featureName': '儿童优惠：'},
#      {'featureDesc': '影院提供免费WIFI', 'featureName': 'WiFi：'}],
#     'latitude': '22.493893',
#     'locationId': '440305',
#     'longitude': '113.89228',
#     'note': '为了保证您的个人卫生及健康，享受更高品质的观影体验，观看3D影片时，请自备或在影城选购3D眼镜。',
#     'stdCinemaCode': '44012261',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0755-23882332'},
#    {'areaName': '华龙区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 5,
#     'cinemaAddr': '人民路与开州路交汇处铜锣湾北门',
#     'cinemaId': 23920,
#     'cinemaName': '濮阳奥斯卡兴隆影城铜锣湾店',
#     'cityId': '240',
#     'cityName': '濮阳',
#     'dis': '',
#     'districtId': '3312',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '铜锣湾广场有免费停车位', 'featureName': '可停车：'},
#      {'featureDesc': '2厅激光杜比全景声厅', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.3m以下儿童观看2D及3D影片免票，每个成年人仅限带一名儿童。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '35.76295',
#     'locationId': '410902',
#     'longitude': '115.02521',
#     'note': '',
#     'stdCinemaCode': '41092601',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0393-8995571'},
#    {'areaName': '义乌市',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '工人西路9号义乌之心6楼保利国际影城',
#     'cinemaId': 23919,
#     'cinemaName': '保利国际影城(义乌之心店)',
#     'cityId': '188',
#     'cityName': '金华',
#     'dis': '',
#     'districtId': '2818',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '凭电影票可以免费停车3小时', 'featureName': '可停车：'},
#      {'featureDesc': '1号2号3号5号6号7号8号10号11号厅最后一排为情侣座', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.3m以下儿童观看2D普通电影免票，每个成年人仅限带一名儿童。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '29.308558',
#     'locationId': '330782',
#     'longitude': '120.07345',
#     'note': '会员卡顾客享受影城会员价',
#     'stdCinemaCode': '33096801',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '15057802866'},
#    {'areaName': '向阳区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 1,
#     'cinemaAddr': '59委（胜利路南、通江街东）佳大尚都广场一楼南区',
#     'cinemaId': 23917,
#     'cinemaName': '大地影院(佳大尚都广场店)',
#     'cityId': '173',
#     'cityName': '佳木斯',
#     'dis': '',
#     'districtId': '2660',
#     'features': [],
#     'latitude': '46.79138',
#     'locationId': '230803',
#     'longitude': '130.37361',
#     'note': '',
#     'stdCinemaCode': '23042221',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0454-8856667'},
#    {'areaName': '福田区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '福强路益田地铁站A出口益田大厦3楼',
#     'cinemaId': 23915,
#     'cinemaName': '中影万国国际影城(益田村店)',
#     'cityId': '30',
#     'cityName': '深圳',
#     'dis': '',
#     'districtId': '28',
#     'features': [{'featureDesc': '为了您的用眼健康，本影城不提供免费3D眼镜，请自备或前台购买/副，感谢您的配合',
#       'featureName': '3D眼镜：'},
#      {'featureDesc': '', 'featureName': '可停车：'},
#      {'featureDesc': '每位成人可携带一名1.3米以下儿童，无座不提供3D眼镜', 'featureName': '儿童优惠：'}],
#     'latitude': '22.515589',
#     'locationId': '440304',
#     'longitude': '114.05104',
#     'note': '',
#     'stdCinemaCode': '44012381',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0755-82888268'},
#    {'areaName': '蜀山区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '长江西路乐客来生活馆3楼',
#     'cinemaId': 23914,
#     'cinemaName': '丁丁影城',
#     'cityId': '56',
#     'cityName': '合肥',
#     'dis': '',
#     'districtId': '5732',
#     'features': [{'featureDesc': '免费提供3D眼镜', 'featureName': '3D眼镜：'},
#      {'featureDesc': '停车场位于乐客来家居广场生活馆停车场，可免费停车至晚24:00', 'featureName': '可停车：'},
#      {'featureDesc': '5号欢乐厅 一家3口齐欢笑 70元让你愉快一整天（一场电影）', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.3以下儿童观看电影免费，每名儿童需一名大人陪同', 'featureName': '儿童优惠：'}],
#     'latitude': '31.852453',
#     'locationId': '340104',
#     'longitude': '117.17106',
#     'note': '5号欢乐厅，让你感受不一样的观影体验 价格超乎想象的优惠<br/>每周二会员观影日<br/>积分兑换小礼品',
#     'stdCinemaCode': '34018101',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0551-62633966'},
#    {'areaName': '金州区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 1,
#     'cinemaAddr': '开发区金马路银帆购物广场4楼',
#     'cinemaId': 23913,
#     'cinemaName': '中影星美银帆影城',
#     'cityId': '65',
#     'cityName': '大连',
#     'dis': '',
#     'districtId': '1163',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '周边千余宽敞的免费停车位', 'featureName': '可停车：'},
#      {'featureDesc': '1.3m以下儿童观看2D免票无座', 'featureName': '儿童优惠：'}],
#     'latitude': '39.0249',
#     'locationId': '210213',
#     'longitude': '121.80051',
#     'note': '激光放映！',
#     'stdCinemaCode': '21020721',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0411-39259822'},
#    {'areaName': '红安县',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '北街天亿文化广场3楼',
#     'cinemaId': 23911,
#     'cinemaName': '雅图影院(天亿店)',
#     'cityId': '258',
#     'cityName': '黄冈',
#     'dis': '',
#     'districtId': '3438',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '31.287312',
#     'locationId': '421122',
#     'longitude': '114.61957',
#     'note': '',
#     'stdCinemaCode': '42063201',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0713-5288507'},
#    {'areaName': '大理市',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '下关建设路21号昆百大泰业城5楼西侧',
#     'cinemaId': 23910,
#     'cinemaName': '横店电影城(昆百大泰业城店)',
#     'cityId': '341',
#     'cityName': '大理',
#     'dis': '',
#     'districtId': '8015',
#     'features': [{'featureDesc': '3D眼镜自带或购买（办理会员有赠送）',
#       'featureName': '3D眼镜：'}],
#     'latitude': '25.585386',
#     'locationId': '532901',
#     'longitude': '100.226234',
#     'note': '',
#     'stdCinemaCode': '53293601',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0872-2358111'},
#    {'areaName': '信州区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '凤凰东大道（恒基城市广场3楼）',
#     'cinemaId': 23909,
#     'cinemaName': '横店电影城(恒基广场店)',
#     'cityId': '221',
#     'cityName': '上饶',
#     'dis': '',
#     'districtId': '3074',
#     'features': [],
#     'latitude': '28.46242',
#     'locationId': '361102',
#     'longitude': '117.98133',
#     'note': '',
#     'stdCinemaCode': '36114501',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0793-8085010'},
#    {'areaName': '台安县',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '金山都市汇四楼',
#     'cinemaId': 23908,
#     'cinemaName': '台安中影超达影城',
#     'cityId': '151',
#     'cityName': '鞍山',
#     'dis': '',
#     'districtId': '2501',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '门前免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1.0m以下儿童观看2D、3D普通电影免票，限带1名儿童', 'featureName': '儿童优惠：'}],
#     'latitude': '41.387646',
#     'locationId': '210321',
#     'longitude': '122.42878',
#     'note': '会员卡周二半价日',
#     'stdCinemaCode': '21030261',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0412-4868886'},
#    {'areaName': '江宁区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 5,
#     'cinemaAddr': '将军大道9号109幢4楼',
#     'cinemaId': 23906,
#     'cinemaName': '中影星美国际影城(托乐嘉越城汇店)',
#     'cityId': '55',
#     'cityName': '南京',
#     'dis': '',
#     'districtId': '273',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.2米以下儿童观影免费。', 'featureName': '儿童优惠：'},
#      {'featureDesc': '影院提供免费WIFI', 'featureName': 'WiFi：'}],
#     'latitude': '31.943356',
#     'locationId': '320115',
#     'longitude': '118.78598',
#     'note': '',
#     'stdCinemaCode': '32019111',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '025-52288634'},
#    {'areaName': '宽城区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '凯旋街道九台北路中东奥特莱斯三层',
#     'cinemaId': 23905,
#     'cinemaName': '耀莱成龙国际影城(宽城店)',
#     'cityId': '116',
#     'cityName': '长春',
#     'dis': '',
#     'districtId': '157',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '43.946827',
#     'locationId': '220103',
#     'longitude': '125.32654',
#     'note': '',
#     'stdCinemaCode': '22115601',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0431-82614555'},
#    {'areaName': '钦南区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '扬帆北大道39号',
#     'cinemaId': 23904,
#     'cinemaName': '恒大影城(御景半岛店)',
#     'cityId': '294',
#     'cityName': '钦州',
#     'dis': '',
#     'districtId': '3756',
#     'features': [{'featureDesc': '免费提供，散场归还，损坏赔付10元/副',
#       'featureName': '3D眼镜：'},
#      {'featureDesc': '影城免费停车，车位有限', 'featureName': '可停车：'},
#      {'featureDesc': '普通厅1.3米以下儿童免票，需一名大人陪同。巨幕厅VIP厅儿童需要购票',
#       'featureName': '儿童优惠：'}],
#     'latitude': '21.972095',
#     'locationId': '450702',
#     'longitude': '108.64498',
#     'note': '影城谢绝外带任何食品，不便之处，敬请谅解！',
#     'stdCinemaCode': '45070111',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0777-3888989'},
#    {'areaName': '镇平县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '石佛寺镇新兴南路润德姆超市二楼奥斯卡影城',
#     'cinemaId': 23903,
#     'cinemaName': '玉城奥斯卡',
#     'cityId': '244',
#     'cityName': '南阳',
#     'dis': '',
#     'districtId': '3364',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.2米以下儿童免票，需家长陪同，每名家长限带一名', 'featureName': '儿童优惠：'}],
#     'latitude': '33.07393',
#     'locationId': '411324',
#     'longitude': '112.16594',
#     'note': '',
#     'stdCinemaCode': '41134101',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0377-65833368'},
#    {'areaName': '榕江县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 10,
#     'cinemaAddr': '古州镇汇龙商业广场三楼',
#     'cinemaId': 23902,
#     'cinemaName': '华夏国际影城',
#     'cityId': '328',
#     'cityName': '黔东南',
#     'dis': '',
#     'districtId': '4028',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.3米以下的儿童观看2D电影免费但无座须家长陪同、3D及动画片半价',
#       'featureName': '儿童优惠：'}],
#     'latitude': '25.935648',
#     'locationId': '522632',
#     'longitude': '108.523994',
#     'note': '每周二男士到店享受半价、每周三除会员日女士到店享受半价、每周五学生到店凭学生证享受半价',
#     'stdCinemaCode': '52262601',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0855-6659333'},
#    {'areaName': '朝阳区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '林萃西里16号楼华创生活广场F1层',
#     'cinemaId': 23901,
#     'cinemaName': '百誉朗克影城',
#     'cityId': '1',
#     'cityName': '北京',
#     'dis': '',
#     'districtId': '14',
#     'features': [{'featureDesc': '免押金（免费提供成人眼镜无押金/特殊眼镜外：近视夹片，儿童眼镜需自行购买）',
#       'featureName': '3D眼镜：'},
#      {'featureDesc': '1.2m一下儿童2D,3D免票', 'featureName': '儿童优惠：'}],
#     'latitude': '40.010098',
#     'locationId': '110105',
#     'longitude': '116.372604',
#     'note': '',
#     'stdCinemaCode': '11051221',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '010-57761726'},
#    {'areaName': '海州区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '通灌中路62号苏宁广场对面3楼',
#     'cinemaId': 23899,
#     'cinemaName': '蓝海国际影城(通灌路店)',
#     'cityId': '179',
#     'cityName': '连云港',
#     'dis': '',
#     'districtId': '2723',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '附近有大型停车场', 'featureName': '可停车：'},
#      {'featureDesc': '1.3m以下儿童在大人陪同下免票', 'featureName': '儿童优惠：'},
#      {'featureDesc': '影城免费提供wifi', 'featureName': 'WiFi：'}],
#     'latitude': '34.599586',
#     'locationId': '320706',
#     'longitude': '119.18441',
#     'note': '',
#     'stdCinemaCode': '32112211',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0518-85202666'},
#    {'areaName': '企石镇',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '铁炉坑村润升百货优一城一楼',
#     'cinemaId': 23898,
#     'cinemaName': '橙天国际巨幕影城',
#     'cityId': '91',
#     'cityName': '东莞',
#     'dis': '',
#     'districtId': '7041',
#     'features': [{'featureDesc': '自费购买, 5.0元每副', 'featureName': '3D眼镜：'},
#      {'featureDesc': '免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下免费，每个成年带一个儿童', 'featureName': '儿童优惠：'},
#      {'featureDesc': '影院提供免费WIFI', 'featureName': 'WiFi：'}],
#     'latitude': '23.067003',
#     'locationId': '4419008',
#     'longitude': '114.01699',
#     'note': '',
#     'stdCinemaCode': '44101321',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0769-86661567'},
#    {'areaName': '江陵县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '郝穴镇荆江路中央金街三楼',
#     'cinemaId': 23896,
#     'cinemaName': '江陵县华纳影城',
#     'cityId': '257',
#     'cityName': '荆州',
#     'dis': '',
#     'districtId': '3465',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '近百个车位的停车位', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下的儿童免费观影，无座，且需要家长陪同。', 'featureName': '儿童优惠：'}],
#     'latitude': '30.045824',
#     'locationId': '421024',
#     'longitude': '112.4285',
#     'note': '',
#     'stdCinemaCode': '42033401',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '17707165981'},
#    {'areaName': '钦南区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '材东大街8号奥林财富中心二楼',
#     'cinemaId': 23894,
#     'cinemaName': '嘉莱国际影城',
#     'cityId': '294',
#     'cityName': '钦州',
#     'dis': '',
#     'districtId': '3756',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '21.964281',
#     'locationId': '450702',
#     'longitude': '108.64162',
#     'note': '',
#     'stdCinemaCode': '45070121',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0777-5512356'},
#    {'areaName': '闻喜县',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '体育公园综合体育馆（闻喜县城南大街体育馆5-6楼）',
#     'cinemaId': 23892,
#     'cinemaName': '横店电影城(闻喜店)',
#     'cityId': '135',
#     'cityName': '运城',
#     'dis': '',
#     'districtId': '5746',
#     'features': [{'featureDesc': '为了您的健康本影城不免费提供公用眼睛请您自己携带或至影城卖品部购买',
#       'featureName': '3D眼镜：'},
#      {'featureDesc': '提供停车位', 'featureName': '可停车：'},
#      {'featureDesc': '2D电影1.3m免票和大人同座，3D电影1.1m以下免票和大人同座。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '35.35391',
#     'locationId': '140823',
#     'longitude': '111.234924',
#     'note': '本影城谢绝外带食品',
#     'stdCinemaCode': '14083541',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0359-2350006'},
#    {'areaName': '明山区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '华程路36-2栋本溪电视台1楼',
#     'cinemaId': 23891,
#     'cinemaName': '新时代MZC影城',
#     'cityId': '153',
#     'cityName': '本溪',
#     'dis': '',
#     'districtId': '2485',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '41.30997',
#     'locationId': '210504',
#     'longitude': '123.820724',
#     'note': '',
#     'stdCinemaCode': '21050121',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '024-43967777'},
#    {'areaName': '涪城区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 2,
#     'cinemaAddr': '高新区虹苑路阳光西雅图（火炬大厦斜对面）',
#     'cinemaId': 23890,
#     'cinemaName': '中环影城(悦影绘店)',
#     'cityId': '306',
#     'cityName': '绵阳',
#     'dis': '',
#     'districtId': '3816',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '影城所在广场可停车', 'featureName': '可停车：'},
#      {'featureDesc': '免费wifi', 'featureName': 'WiFi：'}],
#     'latitude': '31.46272',
#     'locationId': '510703',
#     'longitude': '104.681595',
#     'note': '',
#     'stdCinemaCode': '51029621',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0816-2589899'},
#    {'areaName': '松江区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '车墩镇南乐路456号4幢4层',
#     'cinemaId': 23889,
#     'cinemaName': '珠影沪亚国际影城(松江店)',
#     'cityId': '10',
#     'cityName': '上海',
#     'dis': '',
#     'districtId': '4737',
#     'features': [{'featureDesc': '3元一幅（可保留下次观影使用）', 'featureName': '3D眼镜：'},
#      {'featureDesc': '商场地下室有免费停车场', 'featureName': '可停车：'},
#      {'featureDesc': '2号厅、4号厅、6号厅、设有情侣坐', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.3米（不含）以下2D3D免费，每位成人只能携带一名免费儿童，1.3米（含）以上儿童观影半价',
#       'featureName': '儿童优惠：'}],
#     'latitude': '31.024763',
#     'locationId': '310117',
#     'longitude': '121.29571',
#     'note': '我们影院有4K60帧激光放映，巨幕杜比全景声即在2号厅',
#     'stdCinemaCode': '31164901',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '021-33550055'},
#    {'areaName': '红安县',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '将军城中央大街4楼',
#     'cinemaId': 23887,
#     'cinemaName': '横店激光电影城(红安店)',
#     'cityId': '258',
#     'cityName': '黄冈',
#     'dis': '',
#     'districtId': '3438',
#     'features': [{'featureDesc': '凭电影票，免费停车两小时', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下免费。观看3D电影凭票领取眼镜，一张票一副眼镜。1.3米儿童无眼镜发放。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '31.286736',
#     'locationId': '421122',
#     'longitude': '114.6126',
#     'note': '',
#     'stdCinemaCode': '42063101',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0713-5207096'},
#    {'areaName': '朝阳区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '工人体育场北路盈科中心B座1层',
#     'cinemaId': 23886,
#     'cinemaName': '三克影院(三里屯盈科店)',
#     'cityId': '1',
#     'cityName': '北京',
#     'dis': '',
#     'districtId': '14',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.2米以下免费', 'featureName': '儿童优惠：'}],
#     'latitude': '39.93304',
#     'locationId': '110105',
#     'longitude': '116.459206',
#     'note': '',
#     'stdCinemaCode': '11051231',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '010-65392868'},
#    {'areaName': '汉寿县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 3,
#     'cinemaAddr': '辰阳南路233号有美小镇7栋2层',
#     'cinemaId': 23885,
#     'cinemaName': '有美影院',
#     'cityId': '268',
#     'cityName': '常德',
#     'dis': '',
#     'districtId': '3503',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '28.892635',
#     'locationId': '430722',
#     'longitude': '111.97096',
#     'note': '',
#     'stdCinemaCode': '43084001',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '07362090888'},
#    {'areaName': '龙岗区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '同乐社区人人购物广场2楼',
#     'cinemaId': 23884,
#     'cinemaName': '君胜国际影城(深圳同乐店)',
#     'cityId': '30',
#     'cityName': '深圳',
#     'dis': '',
#     'districtId': '33',
#     'features': [{'featureDesc': '自费购买, 5.0元每副', 'featureName': '3D眼镜：'}],
#     'latitude': '22.713375',
#     'locationId': '440307',
#     'longitude': '114.31509',
#     'note': '',
#     'stdCinemaCode': '44012371',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0755-89453989'},
#    {'areaName': '花都区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '凤凰南路88号汇丰水产市场第四栋喜盟生活荟4楼',
#     'cinemaId': 23883,
#     'cinemaName': '喜盟国际影城(花都DMAX店)',
#     'cityId': '20',
#     'cityName': '广州',
#     'dis': '',
#     'districtId': '738',
#     'features': [{'featureDesc': '自费购买, 5.0元每副', 'featureName': '3D眼镜：'},
#      {'featureDesc': '免费停车，2000个免费停车位', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下儿童免票无座，一个购票家长最多带一名儿童', 'featureName': '儿童优惠：'}],
#     'latitude': '23.385328',
#     'locationId': '440114',
#     'longitude': '113.239716',
#     'note': '周三会员半价，免费停车，2000个免费停车位。',
#     'stdCinemaCode': '44001701',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '020-86888859 020-86888895'},
#    {'areaName': '平坝区',
#     'buyNumLimit': 4,
# ...
#      {'featureDesc': '1.3m（含）以下儿童观影免票无座，需1名家长陪同（家长需购票，限带一名儿童）',
#       'featureName': '儿童优惠：'}],
#     'latitude': '31.171024',
#     'locationId': '310115',
#     'longitude': '121.48828',
#     'note': 'DFC影城长清店位于浦东新区长清路92号新路达生活广场3楼，总投资超千万元，影院规模达3000余平方米，按照全国一线影院标准建设，影院内部采用经典的工业loft风格进行装修，处处散发着浪漫的气息；影城主打全激光放映，比一般3D放映亮度提高3倍以上，画面更鲜亮生动、色彩饱和、对比度柔和，全面提升观影舒适度，为您带来精彩的观影享受。影城大厅还设有VR游戏区，游戏定期更新，只为分享更多乐趣。',
#     'stdCinemaCode': '31128701',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '021-58890880'},
#    {'areaName': '金山区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 5,
#     'cinemaAddr': '海汇街500号11号楼401室',
#     'cinemaId': 16616,
#     'cinemaName': 'DFC影城金山店',
#     'cityId': '10',
#     'cityName': '上海',
#     'dis': '',
#     'districtId': '665',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '30.753157',
#     'locationId': '310116',
#     'longitude': '121.33842',
#     'note': '',
#     'stdCinemaCode': '31152801',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '021-67296656'},
#    {'areaName': '浦东新区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 5,
#     'cinemaAddr': '北艾路1786号',
#     'cinemaId': 16613,
#     'cinemaName': 'DFC影城北艾店',
#     'cityId': '10',
#     'cityName': '上海',
#     'dis': '',
#     'districtId': '5',
#     'features': [{'featureDesc': '免费提供', 'featureName': '3D眼镜：'},
#      {'featureDesc': '停车场 8元/小时', 'featureName': '可停车：'},
#      {'featureDesc': '3-10号厅设有情侣座', 'featureName': '有情侣座：'},
#      {'featureDesc': '每位观影用户可免费携带一名1.3米（含1.3米）以下儿童与大人同座观影，每名大人只可携带一名儿童，VIP厅除外。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '31.179804',
#     'locationId': '310115',
#     'longitude': '121.52311',
#     'note': '',
#     'stdCinemaCode': '31128601',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '021-50832805'},
#    {'areaName': '白云区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 10,
#     'cinemaAddr': '棠景街沙涌北大街新乐嘉商业广场A1区二楼',
#     'cinemaId': 16612,
#     'cinemaName': '粤骏电影城',
#     'cityId': '20',
#     'cityName': '广州',
#     'dis': '',
#     'districtId': '26',
#     'features': [{'featureDesc': '5元/副', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.2.3.4号厅都有情侣座', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.2米以下儿童免费，同时带两个或两个以上1.2米以下的儿童需购票（两个1.2米以下儿童一张票）',
#       'featureName': '儿童优惠：'}],
#     'latitude': '23.166864',
#     'locationId': '440111',
#     'longitude': '113.256096',
#     'note': '',
#     'stdCinemaCode': '44001521',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '020-62667770'},
#    {'areaName': '秀山土家族苗族自治县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 10,
#     'cinemaAddr': '中和镇九点利四楼',
#     'cinemaId': 16611,
#     'cinemaName': '棚烨影城',
#     'cityId': '45',
#     'cityName': '重庆',
#     'dis': '',
#     'districtId': '4612',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '28.445372',
#     'locationId': '500241',
#     'longitude': '108.99375',
#     'note': '',
#     'stdCinemaCode': '50410031',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '023-81555666'},
#    {'areaName': '罗源县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 1,
#     'cinemaAddr': '凤山镇东外路16号东方新城商业楼F3号',
#     'cinemaId': 16610,
#     'cinemaName': '罗源东方国际影城',
#     'cityId': '44',
#     'cityName': '福州',
#     'dis': '',
#     'districtId': '2957',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '26.48646',
#     'locationId': '350123',
#     'longitude': '119.56745',
#     'note': '',
#     'stdCinemaCode': '35014901',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0591-62576999'},
#    {'areaName': '仓山区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 3,
#     'cinemaAddr': '建新大道路南侧盘屿路东侧奥体阳光天地广场2楼2019号',
#     'cinemaId': 16609,
#     'cinemaName': '观者国际影城(奥体阳光店)',
#     'cityId': '44',
#     'cityName': '福州',
#     'dis': '',
#     'districtId': '98',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '依商场收费为准。', 'featureName': '可停车：'},
#      {'featureDesc': '1.3m以下儿童观看普通2D电影免票无座。', 'featureName': '儿童优惠：'}],
#     'latitude': '26.017876',
#     'locationId': '350104',
#     'longitude': '119.27837',
#     'note': '',
#     'stdCinemaCode': '35014731',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0591-63111878'},
#    {'areaName': '台江区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '台江路95号东百元洪城5楼',
#     'cinemaId': 16606,
#     'cinemaName': '中影星汇电影城',
#     'cityId': '44',
#     'cityName': '福州',
#     'dis': '',
#     'districtId': '97',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '影院提供免费Wi-Fi', 'featureName': 'WiFi：'}],
#     'latitude': '26.05219',
#     'locationId': '350103',
#     'longitude': '119.31628',
#     'note': '',
#     'stdCinemaCode': '35014950',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0591-83377999'},
#    {'areaName': '东城区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '东打磨厂街7号新活馆B1层',
#     'cinemaId': 16605,
#     'cinemaName': '传奇奢华影城',
#     'cityId': '1',
#     'cityName': '北京',
#     'dis': '',
#     'districtId': '15',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '商场地下二层、三层收费停车场', 'featureName': '可停车：'},
#      {'featureDesc': '1.2m以下儿童——2D影片，免票无座位；3D影片，选购买儿童票',
#       'featureName': '儿童优惠：'}],
#     'latitude': '39.89956',
#     'locationId': '110101',
#     'longitude': '116.41363',
#     'note': '本影城为双人沙发座椅，购票时如有疑问请致电，谢谢合作！',
#     'stdCinemaCode': '',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '010-67086545'},
#    {'areaName': '包河区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 1,
#     'cinemaAddr': '滨湖新区庐州大道与紫云路交口悦方中心广场四、五楼',
#     'cinemaId': 16604,
#     'cinemaName': '自由人影城(悦方IDMALL店)',
#     'cityId': '56',
#     'cityName': '合肥',
#     'dis': '',
#     'districtId': '200',
#     'features': [],
#     'latitude': '31.740318',
#     'locationId': '340111',
#     'longitude': '117.304214',
#     'note': '',
#     'stdCinemaCode': '34017101',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0551-65870233'},
#    {'areaName': '鹿城区',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '黎明中路96号',
#     'cinemaId': 16603,
#     'cinemaName': '龙幕杜比全景声双巨幕(花园店)',
#     'cityId': '112',
#     'cityName': '温州',
#     'dis': '',
#     'districtId': '2832',
#     'features': [{'featureDesc': '10', 'featureName': '3D眼镜：'},
#      {'featureDesc': '园区内设有专用停车位', 'featureName': '可停车：'},
#      {'featureDesc': '7号8号厅设有情侣座', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.2米以下儿童可在家长陪同下无座观看普通影片，观看儿童片可享受优惠购票',
#       'featureName': '儿童优惠：'}],
#     'latitude': '28.011604',
#     'locationId': '330302',
#     'longitude': '120.68971',
#     'note': '',
#     'stdCinemaCode': '33078601',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0577-56966555'},
#    {'areaName': '攸县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '联星街道胜利社区望云国际广场步步高4楼',
#     'cinemaId': 16602,
#     'cinemaName': '中影星嘉国际影城',
#     'cityId': '263',
#     'cityName': '株洲',
#     'dis': '',
#     'districtId': '3529',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '凭电影票可免费停车三小时', 'featureName': '可停车：'}],
#     'latitude': '26.99978',
#     'locationId': '430223',
#     'longitude': '113.34513',
#     'note': '步步高购物中心营业结束后请由正门右侧内街道直达电梯进出影城',
#     'stdCinemaCode': '43022201',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0731-22151999'},
#    {'areaName': '潜江市',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 15,
#     'cinemaAddr': '广华油田总医院旁',
#     'cinemaId': 16601,
#     'cinemaName': '潜江时光印象影城(广华店)',
#     'cityId': '550',
#     'cityName': '潜江',
#     'dis': '',
#     'districtId': '14028',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.3米以下儿童在持票观众的陪同下可免费观影（限1人）', 'featureName': '儿童优惠：'},
#      {'featureDesc': '影院提供免费WIFI', 'featureName': 'WiFi：'}],
#     'latitude': '30.43816',
#     'locationId': '429005',
#     'longitude': '112.70093',
#     'note': '',
#     'stdCinemaCode': '42121201',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '13307228056'},
#    {'areaName': '莞城街道',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '东纵路2号地王广场三楼304-312室',
#     'cinemaId': 16600,
#     'cinemaName': '中影南方国际影城(地王广场店)',
#     'cityId': '91',
#     'cityName': '东莞',
#     'dis': '',
#     'districtId': '218',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '凭当天电影票可免费3小时停车', 'featureName': '可停车：'},
#      {'featureDesc': '一位成年观众可免费带一位不超过1.3米的小孩，没有座位', 'featureName': '儿童优惠：'}],
#     'latitude': '23.038795',
#     'locationId': '4419000',
#     'longitude': '113.76512',
#     'note': '',
#     'stdCinemaCode': '44101091',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0769-28683939'},
#    {'areaName': '滨江区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '信诚路857号乐缤纷世茂中心5楼',
#     'cinemaId': 16599,
#     'cinemaName': '悦江新远影城',
#     'cityId': '50',
#     'cityName': '杭州',
#     'dis': '',
#     'districtId': '60',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '凭当日影票免费停车3小时', 'featureName': '可停车：'},
#      {'featureDesc': '1号厅、2号厅、4号厅、5号厅、IMAX厅', 'featureName': '有情侣座：'},
#      {'featureDesc': '儿童1.2米以下免费，提供儿童3D眼镜', 'featureName': '儿童优惠：'}],
#     'latitude': '30.19426',
#     'locationId': '330108',
#     'longitude': '120.16942',
#     'note': '',
#     'stdCinemaCode': '33018341',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0571-87705558'},
#    {'areaName': '武清区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '泉发路与前进道交汇亚平宁广场3楼',
#     'cinemaId': 16598,
#     'cinemaName': '横店电影城(武清亚平宁广场店)',
#     'cityId': '40',
#     'cityName': '天津',
#     'dis': '',
#     'districtId': '2080',
#     'features': [{'featureDesc': '提供免费眼镜', 'featureName': '3D眼镜：'},
#      {'featureDesc': '凭电影票免费停车两小时。', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下儿童可免费观影，无座每位成年人可带一名儿童。', 'featureName': '儿童优惠：'}],
#     'latitude': '39.368576',
#     'locationId': '120114',
#     'longitude': '117.03242',
#     'note': '每周二，周四为现金购票半价日，1.3米以下儿童可免费观影，无座每位成年人可带一名儿童。',
#     'stdCinemaCode': '12140851',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '022-59666355'},
#    {'areaName': '南山区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '南头街道艺园东路缤纷年华家园商业裙楼301A-2号',
#     'cinemaId': 16597,
#     'cinemaName': '中影德金影城(南山店)',
#     'cityId': '30',
#     'cityName': '深圳',
#     'dis': '',
#     'districtId': '30',
#     'features': [{'featureDesc': '顾客可以自带3D眼睛或者前往影城前台购买，5元/副',
#       'featureName': '3D眼镜：'},
#      {'featureDesc': '1.2米以下儿童免费观影，需家长陪同', 'featureName': '儿童优惠：'}],
#     'latitude': '22.542507',
#     'locationId': '440305',
#     'longitude': '113.928375',
#     'note': '',
#     'stdCinemaCode': '44012031',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0755-27333318'},
#    {'areaName': '嘉善县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 10,
#     'cinemaAddr': '世纪大道与农商路交叉口万联城4楼',
#     'cinemaId': 16596,
#     'cinemaName': '中影星美国际影城(万联城店)',
#     'cityId': '185',
#     'cityName': '嘉兴',
#     'dis': '',
#     'districtId': '2795',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '地下停车位，免费约2000个左右', 'featureName': '可停车：'},
#      {'featureDesc': '3号激光厅，6号杜比全景声厅设有情侣座', 'featureName': '有情侣座：'},
#      {'featureDesc': '1.3米以下儿童-2D电影免票且无座需家长陪同，每位成人可携带一名儿童，3D电影需正常购票',
#       'featureName': '儿童优惠：'}],
#     'latitude': '30.81965',
#     'locationId': '330421',
#     'longitude': '120.93205',
#     'note': '6号厅杜比全景声',
#     'stdCinemaCode': '33034901',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0573-84583888'},
#    {'areaName': '密云区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '鼓楼南大街10号瑞嘉商场4层',
#     'cinemaId': 16595,
#     'cinemaName': '米瑞酷影城(密云店)',
#     'cityId': '1',
#     'cityName': '北京',
#     'dis': '',
#     'districtId': '2074',
#     'features': [{'featureDesc': '免押金,提供普通3D眼镜', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1.3m以下儿童观看2D普通电影免票，每个成年人仅限带一名儿童。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '40.374863',
#     'locationId': '110228',
#     'longitude': '116.84608',
#     'note': '',
#     'stdCinemaCode': '11171021',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '010-61090321'},
#    {'areaName': '南昌县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 3,
#     'cinemaAddr': '紫阳大道奥体天虹988号',
#     'cinemaId': 16594,
#     'cinemaName': '潇湘国际影城(天虹酷加店)',
#     'cityId': '83',
#     'cityName': '南昌',
#     'dis': '',
#     'districtId': '3026',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'}],
#     'latitude': '28.67417',
#     'locationId': '360121',
#     'longitude': '116.02239',
#     'note': '',
#     'stdCinemaCode': '36016201',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0791-88202022'},
#    {'areaName': '长乐市',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 3,
#     'cinemaAddr': '航城街道广场南路888号永荣广场四楼',
#     'cinemaId': 16593,
#     'cinemaName': '长乐CC影城(永荣IMAX店)',
#     'cityId': '44',
#     'cityName': '福州',
#     'dis': '',
#     'districtId': '2954',
#     'features': [{'featureDesc': '自费购买, 3.0元每副', 'featureName': '3D眼镜：'},
#      {'featureDesc': '地下一层停车场免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1.3米以下儿童观看普通厅免费，一个大人仅限一个小孩，无座。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '25.942268',
#     'locationId': '350182',
#     'longitude': '119.494804',
#     'note': '2017年1月1日起不再提供免费公用3D眼镜。可至影城前台购买，原价20元／副，现仅需3元。',
#     'stdCinemaCode': '35014871',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内自助取票机或影院前台',
#     'tel': '0591-28110255'},
#    {'areaName': '闽清县',
#     'buyNumLimit': 4,
#     'buyTimeLimit': 1,
#     'cinemaAddr': '梅城镇梅溪南路1号百荣新天地6#商业综合体四层',
#     'cinemaId': 16592,
#     'cinemaName': '百荣国际影城',
#     'cityId': '44',
#     'cityName': '福州',
#     'dis': '',
#     'districtId': '2958',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '影院免费提供Wi-Fi', 'featureName': 'WiFi：'}],
#     'latitude': '26.2176',
#     'locationId': '350124',
#     'longitude': '118.85636',
#     'note': '',
#     'stdCinemaCode': '35014741',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0591-22355188'},
#    {'areaName': '龙华区',
#     'buyNumLimit': 5,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '明珠路8号宜欣城4楼',
#     'cinemaId': 16591,
#     'cinemaName': 'USM宜欣全景声激光巨幕影城 (宜欣城旗舰店)',
#     'cityId': '94',
#     'cityName': '海口',
#     'dis': '',
#     'districtId': '5312',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '1名大人仅限带1名1.3米以下儿童，无座，激光巨幕厅，vip厅除外。',
#       'featureName': '儿童优惠：'}],
#     'latitude': '20.02489',
#     'locationId': '460106',
#     'longitude': '110.31244',
#     'note': '',
#     'stdCinemaCode': '46022001',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0898-66781506'},
#    {'areaName': '婺城区',
#     'buyNumLimit': 6,
#     'buyTimeLimit': 0,
#     'cinemaAddr': '宾虹西路2999号',
#     'cinemaId': 16590,
#     'cinemaName': '天艺影城',
#     'cityId': '188',
#     'cityName': '金华',
#     'dis': '',
#     'districtId': '2814',
#     'features': [{'featureDesc': '免押金', 'featureName': '3D眼镜：'},
#      {'featureDesc': '免费停车', 'featureName': '可停车：'},
#      {'featureDesc': '1号厅、2号厅、3号厅、4号厅、5号厅、7号厅最后一排有情侣座。',
#       'featureName': '有情侣座：'},
#      {'featureDesc': '1.3米以下儿童观看电影无票无座，需成人陪同。', 'featureName': '儿童优惠：'},
#      {'featureDesc': '影城提供免费WIFI', 'featureName': 'WiFi：'}],
#     'latitude': '29.080906',
#     'locationId': '330702',
#     'longitude': '119.569565',
#     'note': '无',
#     'stdCinemaCode': '33095501',
#     'subway': '',
#     'supportQR': 1,
#     'takeTicketPlace': '影院内猫眼取票机',
#     'tel': '0579-82220955'},
#    ...]},
#  'msg': 'SUCCESS',
#  'version': '1.0'}

# %%
len(resp_data['data']['data'])
{item['cinemaName']:item['cityName'] for item in resp_data['data']['data'] if '万达' in item['cinemaName']}

# %%
maoyan_citys = {item['cityName']:item['cityId'] for item in resp_data['data']['data']}
with open('/data/logs/maoyan_citys.json','w')as f:
    json.dump(maoyan_citys,f)

# %%
import tablib
tab_data = tablib.Dataset(headers=["城市名称","城市ID"])
for city_name,city_id in maoyan_citys.items():
    tab_data.append([city_name,city_id])
with open("/root/notebook/Master/猫眼支持城市列表.xlsx","wb") as f:
    f.write(tab_data.xlsx)
# Out:
# /usr/local/python3/lib/python3.6/site-packages/openpyxl/worksheet/worksheet.py:303: UserWarning: Using a coordinate with ws.cell is deprecated. Use ws[coordinate] instead
#   warn("Using a coordinate with ws.cell is deprecated. Use ws[coordinate] instead")

# %%
len(maoyan_citys)
# Out:
# 330

# %% [markdown]
# ### 2.2 查询影厅列表

# %%
cinema_id=11
url_tail="/sync/gateway"
api_name="gateway.sync.halls"
data={
    "merCode":ID,
     "timestamp":int(time.time()),
     "version":"1.0",
     "signType":"MD5",
     "api":api_name,
     "bizData":json.dumps({"cinemaId":cinema_id})}
md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
data["signMsg"]=sign

requests.post(url=url_head+url_tail,data=data).json()

# %% [markdown]
# ### 2.3 查询影厅座位列表

# %%
cinema_id=11
hall_id=4427
url_tail="/sync/gateway"
api_name="gateway.sync.seats"
data={
    "merCode":ID,
     "timestamp":int(time.time()),
     "version":"1.0",
     "signType":"MD5",
     "api":api_name,
     "bizData":json.dumps({"cinemaId":cinema_id,"hallId":hall_id})}
md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
data["signMsg"]=sign

requests.post(url=url_head+url_tail,data=data).json()

# %%
from collections import Counter
city_id_list = c.static_cluster.dianying_cinema_mao.distinct("cityId")
city_id_cursor =[item['cityId'] for item in c.static_cluster.dianying_cinema_mao.find({},{"cityId":1})]
counter = Counter(city_id_cursor)
pprint(counter)

# %%
Counter([1])

# %% [markdown]
# ### 2.4 查询场次列表y

# %%
cinema_id=1
start_date="2018-03-09"
url_tail="/sync/gateway"
api_name="gateway.sync.show"
data={
    "merCode":ID,
     "timestamp":int(time.time()),
     "version":"1.0",
     "signType":"MD5",
     "api":api_name,
     "bizData":json.dumps({"cinemaId":cinema_id,"startDate":start_date})}
md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
data["signMsg"]=sign


resp_data=requests.post(url=url_head+url_tail,data=data).json()
pprint(resp_data)
# document={}
# for item in resp_data['data']['data']:
#     cinema_id=item.pop("cinemaId")
#     film_id=item.pop("filmId")
#     document.setdefault(film_id,[])
#     document[film_id].append(item)

# for k,v in document.items():
#     c.dev.dianying_film_mao.update_one({"cinemaId":cinema_id,"id":k},
#                                  {"$set":{"screenings":v}},upsert=True)
#     query_the_movie_information(k)
# Out:
# {'api': 'gateway.sync.show',
#  'code': '0',
#  'data': {'bizCode': '0',
#           'bizMsg': 'SUCCESS',
#           'data': [{'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1217637,
#                     'filmName': '厉害了，我的国',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '国语',
#                     'minPrice': 3000,
#                     'movieStandId': None,
#                     'price': 7000,
#                     'settlePriceForCinema': 3200,
#                     'settlePriceForMerchant': 3500,
#                     'showId': '201803130004156',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520926200000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1217637,
#                     'filmName': '厉害了，我的国',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '国语',
#                     'minPrice': 3000,
#                     'movieStandId': None,
#                     'price': 7000,
#                     'settlePriceForCinema': 3200,
#                     'settlePriceForMerchant': 3500,
#                     'showId': '201803130004155',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520928000000,
#                     'showVersionType': '2D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 1217637,
#                     'filmName': '厉害了，我的国',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '国语',
#                     'minPrice': 0,
#                     'movieStandId': None,
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803130002820',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520928000000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 247083,
#                     'filmName': '闺蜜2',
#                     'hallCode': '0000000000000006',
#                     'hallName': '7号激光厅',
#                     'language': '国语',
#                     'minPrice': 3000,
#                     'movieStandId': '00108562017',
#                     'price': 7000,
#                     'settlePriceForCinema': 3100,
#                     'settlePriceForMerchant': 3400,
#                     'showId': '201803100168985',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520648700000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000004',
#                     'hallName': '5号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3600,
#                     'settlePriceForMerchant': 3900,
#                     'showId': '201803100168981',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520649000000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1204720,
#                     'filmName': '妈妈咪鸭',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '国语',
#                     'minPrice': 3000,
#                     'movieStandId': '00108622017',
#                     'price': 7000,
#                     'settlePriceForCinema': 3100,
#                     'settlePriceForMerchant': 3400,
#                     'showId': '201803100169007',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520649300000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343762,
#                     'filmName': '比得兔',
#                     'hallCode': '0000000000000005',
#                     'hallName': '6号激光厅',
#                     'language': '国语',
#                     'minPrice': 2000,
#                     'movieStandId': '05100192018',
#                     'price': 7000,
#                     'settlePriceForCinema': 2100,
#                     'settlePriceForMerchant': 2400,
#                     'showId': '201803100168989',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520649600000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 2900,
#                     'settlePriceForMerchant': 3200,
#                     'showId': '201803100183468',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520650500000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 2900,
#                     'settlePriceForMerchant': 3200,
#                     'showId': '201803100183469',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520650500000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1217637,
#                     'filmName': '厉害了，我的国',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '国语',
#                     'minPrice': 3000,
#                     'movieStandId': None,
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168987',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520655300000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000005',
#                     'hallName': '6号激光厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168970',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520655900000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 247083,
#                     'filmName': '闺蜜2',
#                     'hallCode': '0000000000000006',
#                     'hallName': '7号激光厅',
#                     'language': '国语',
#                     'minPrice': 3000,
#                     'movieStandId': '00108562017',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168984',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520655900000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168960',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520656200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343762,
#                     'filmName': '比得兔',
#                     'hallCode': '0000000000000004',
#                     'hallName': '5号厅',
#                     'language': '国语',
#                     'minPrice': 2000,
#                     'movieStandId': '05100192018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168988',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520658000000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168980',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520659200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168969',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520659800000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168959',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520661300000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000006',
#                     'hallName': '7号激光厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168979',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520663100000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000004',
#                     'hallName': '5号厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168968',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520664300000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168958',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520665200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 346272,
#                     'filmName': '捉妖记2',
#                     'hallCode': '0000000000000005',
#                     'hallName': '6号激光厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100952018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168982',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520665200000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168978',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520668200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168967',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520669100000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1217637,
#                     'filmName': '厉害了，我的国',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '国语',
#                     'minPrice': 3000,
#                     'movieStandId': None,
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168986',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520670000000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000006',
#                     'hallName': '7号激光厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168957',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520672100000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000005',
#                     'hallName': '6号激光厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168966',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520672700000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000004',
#                     'hallName': '5号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168977',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520673600000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168956',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520674200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1201381,
#                     'filmName': '恋爱回旋',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '日语',
#                     'minPrice': 2000,
#                     'movieStandId': '01200242018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168992',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520676000000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168976',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520677200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168965',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520678400000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000006',
#                     'hallName': '7号激光厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168955',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520680800000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000005',
#                     'hallName': '6号激光厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168964',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520682000000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000004',
#                     'hallName': '5号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168975',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520682600000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168954',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520683200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1201381,
#                     'filmName': '恋爱回旋',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '日语',
#                     'minPrice': 2000,
#                     'movieStandId': '01200242018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168991',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520683800000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168974',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520686200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803100168963',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520687700000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000006',
#                     'hallName': '7号激光厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3800,
#                     'settlePriceForMerchant': 4100,
#                     'showId': '201803100168953',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520689500000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000005',
#                     'hallName': '6号激光厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 2900,
#                     'settlePriceForMerchant': 3200,
#                     'showId': '201803100168962',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520691300000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000004',
#                     'hallName': '5号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3600,
#                     'settlePriceForMerchant': 3900,
#                     'showId': '201803100168973',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520691600000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1201381,
#                     'filmName': '恋爱回旋',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '日语',
#                     'minPrice': 2000,
#                     'movieStandId': '01200242018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3300,
#                     'settlePriceForMerchant': 3600,
#                     'showId': '201803100168990',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520691600000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 2900,
#                     'settlePriceForMerchant': 3200,
#                     'showId': '201803100183467',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520692200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3600,
#                     'settlePriceForMerchant': 3900,
#                     'showId': '201803100168972',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520695200000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 2900,
#                     'settlePriceForMerchant': 3200,
#                     'showId': '201803100183466',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520697000000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803100168961',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520650500000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '01900162018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803100168971',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520650500000,
#                     'showVersionType': '2D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803100168952',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520692200000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803100168951',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520697000000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000004',
#                     'hallName': '5号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3600,
#                     'settlePriceForMerchant': 3900,
#                     'showId': '201803090192238',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520584800000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 2800,
#                     'settlePriceForMerchant': 3100,
#                     'showId': '201803090324610',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520586900000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000006',
#                     'hallName': '7号激光厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3600,
#                     'settlePriceForMerchant': 3900,
#                     'showId': '201803090192237',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520587500000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 2800,
#                     'settlePriceForMerchant': 3100,
#                     'showId': '201803090324609',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520588700000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1217637,
#                     'filmName': '厉害了，我的国',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '国语',
#                     'minPrice': 3000,
#                     'movieStandId': None,
#                     'price': 7000,
#                     'settlePriceForCinema': 3300,
#                     'settlePriceForMerchant': 3600,
#                     'showId': '201803090192214',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520591700000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000005',
#                     'hallName': '6号激光厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3300,
#                     'settlePriceForMerchant': 3600,
#                     'showId': '201803090192225',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520592900000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3700,
#                     'settlePriceForMerchant': 4000,
#                     'showId': '201803090192236',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520592900000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000004',
#                     'hallName': '5号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3700,
#                     'settlePriceForMerchant': 4000,
#                     'showId': '201803090192235',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520594100000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3700,
#                     'settlePriceForMerchant': 4000,
#                     'showId': '201803090036782',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520595600000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000006',
#                     'hallName': '7号激光厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3700,
#                     'settlePriceForMerchant': 4000,
#                     'showId': '201803090192234',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520596500000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1201381,
#                     'filmName': '恋爱回旋',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '日语',
#                     'minPrice': 2000,
#                     'movieStandId': '01200242018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3300,
#                     'settlePriceForMerchant': 3600,
#                     'showId': '201803090192222',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520597400000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3700,
#                     'settlePriceForMerchant': 4000,
#                     'showId': '201803090192218',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520598300000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3700,
#                     'settlePriceForMerchant': 4000,
#                     'showId': '201803090192233',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520601900000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 343136,
#                     'filmName': '小萝莉的猴神大叔',
#                     'hallCode': '0000000000000005',
#                     'hallName': '6号激光厅',
#                     'language': '英语',
#                     'minPrice': 2000,
#                     'movieStandId': '01900162018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3300,
#                     'settlePriceForMerchant': 3600,
#                     'showId': '201803090192224',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520602200000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000004',
#                     'hallName': '5号厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3700,
#                     'settlePriceForMerchant': 4000,
#                     'showId': '201803090192232',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520603400000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 2800,
#                     'settlePriceForMerchant': 3100,
#                     'showId': '201803090324608',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520604300000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1201381,
#                     'filmName': '恋爱回旋',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '日语',
#                     'minPrice': 2000,
#                     'movieStandId': '01200242018',
#                     'price': 7000,
#                     'settlePriceForCinema': 3100,
#                     'settlePriceForMerchant': 3400,
#                     'showId': '201803090192221',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520605200000,
#                     'showVersionType': '2D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 1182552,
#                     'filmName': '红海行动',
#                     'hallCode': '0000000000000006',
#                     'hallName': '7号激光厅',
#                     'language': '国语',
#                     'minPrice': 3500,
#                     'movieStandId': '00100012018',
#                     'price': 9000,
#                     'settlePriceForCinema': 3500,
#                     'settlePriceForMerchant': 3800,
#                     'showId': '201803090192231',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520605800000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 2800,
#                     'settlePriceForMerchant': 3100,
#                     'showId': '201803090324607',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520607300000,
#                     'showVersionType': '3D'},
#                    {'canSell': True,
#                     'cinemaId': 1,
#                     'fee': 300,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '英语',
#                     'minPrice': 2500,
#                     'movieStandId': '05100222018',
#                     'price': 9000,
#                     'settlePriceForCinema': 2800,
#                     'settlePriceForMerchant': 3100,
#                     'showId': '201803090324606',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520610900000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090014044',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520586900000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090027153',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520586900000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090035508',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520586900000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090036783',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520586900000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000007',
#                     'hallName': '8号激光厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090192219',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520588700000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090014043',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520595600000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090027152',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520595600000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090035507',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520595600000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090014042',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520604300000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090027151',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520604300000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090035506',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520604300000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000002',
#                     'hallName': '2号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090036781',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520604300000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000001',
#                     'hallName': '1号巨幕厅(大)',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090192217',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520607300000,
#                     'showVersionType': '3D'},
#                    {'canSell': False,
#                     'cinemaId': 1,
#                     'fee': 0,
#                     'filmId': 341138,
#                     'filmName': '黑豹',
#                     'hallCode': '0000000000000003',
#                     'hallName': '3号厅',
#                     'language': '英语',
#                     'minPrice': 0,
#                     'movieStandId': '05100222018',
#                     'price': 0,
#                     'settlePriceForCinema': 0,
#                     'settlePriceForMerchant': 0,
#                     'showId': '201803090192216',
#                     'showScreenType': '普通',
#                     'showStartTime': 1520610900000,
#                     'showVersionType': '3D'}]},
#  'msg': 'SUCCESS',
#  'version': '1.0'}

# %%
cache_hot = c.dpprdb(0).smembers("dpp:maoyan.cache:hot:10")

# %%
c.dpprdb(0).srem("dpp:maoyan.cache:hot:10", *value)
# Out:
# 6

# %%
value={'1132373','1132973','1136547','1142586','1157354','1170264'}

# %%
c.dpprdb(0).sadd("dpp:maoyan.cache:hot:10", *cache_hot)
# Out:
# 0

# %%
cache_hot
# Out:
# {'1132373',
#  '1132973',
#  '1136547',
#  '1142586',
#  '1157354',
#  '1170264',
#  '1177097',
#  '1177952',
#  '1182552',
#  '1189089',
#  '1189346',
#  '1190357',
#  '1197732',
#  '1199446',
#  '1199974',
#  '1200609',
#  '1200984',
#  '1201381',
#  '1203436',
#  '1203620',
#  '1203768',
#  '1204714',
#  '1204720',
#  '1204800',
#  '1205145',
#  '1207099',
#  '1208113',
#  '1208122',
#  '1208343',
#  '1208748',
#  '1209260',
#  '1210930',
#  '1211063',
#  '1211086',
#  '1211465',
#  '1211482',
#  '1211538',
#  '1211570',
#  '1211693',
#  '1212450',
#  '1212533',
#  '1212772',
#  '1212787',
#  '1212979',
#  '1212982',
#  '1213016',
#  '1213057',
#  '1213080',
#  '1213224',
#  '1213237',
#  '1213242',
#  '1213724',
#  '1213729',
#  '1217159',
#  '13457',
#  '246083',
#  '246100',
#  '246131',
#  '246371',
#  '246714',
#  '247083',
#  '247948',
#  '248639',
#  '306969',
#  '329733',
#  '337226',
#  '337443',
#  '337511',
#  '338463',
#  '338493',
#  '340946',
#  '341084',
#  '341138',
#  '341323',
#  '341540',
#  '341897',
#  '341999',
#  '342754',
#  '343136',
#  '343526',
#  '343762',
#  '343887',
#  '343905',
#  '343944',
#  '343945',
#  '344080',
#  '344081',
#  '344264',
#  '344323',
#  '344453',
#  '344627',
#  '344661',
#  '344771',
#  '344929',
#  '344990',
#  '344995',
#  '345011',
#  '345627',
#  '345862',
#  '345963',
#  '346180',
#  '346272',
#  '346625',
#  '346658',
#  '368135',
#  '393',
#  '475721',
#  '49',
#  '51',
#  '558308',
#  '652628',
#  '655258',
#  '667783',
#  '672130',
#  '71946',
#  '78537',
#  '828745',
#  '858598'}

# %% [markdown]
# ### 2.6锁座

# %%
def lock_seat(cinema_id,show_id):
    url_tail="/trade/gateway"
    api_name="gateway.trade.lock"
    data={
        "merCode":ID,
         "timestamp":int(time.time()),
         "version":"1.0",
         "signType":"MD5",
         "api":api_name,
         "bizData":json.dumps({"cinemaId":cinema_id,
                              "showId":show_id,
                              "seatsJSON":'{"count":"2","list":[{"sectionId":"01","seatNo":"A_10","columnId":"01","rowId":"A"},{"sectionId":"01","seatNo":"A_09","columnId":"02","rowId":"A"}]}',
                               "orderCode":"blm10086",
                               "mobile":"1008611",
                               "settlePrice":10000,
                               "sellPrice":10000
                              })}
    md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
    sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
    data["signMsg"]=sign

    resp_data=requests.post(url=url_head+url_tail,data=data).json()
    pprint(resp_data)
lock_seat(11,201707250000050)

# %% [markdown]
# ### 2.8确认订单

# %%
def confirm_order(order_id):
    url_tail="/trade/gateway"
    api_name="gateway.trade.fixOrder"
    data={
        "merCode":ID,
         "timestamp":int(time.time()),
         "version":"1.0",
         "signType":"MD5",
         "api":api_name,
         "bizData":json.dumps({"orderId":order_id})}
    md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
    sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
    data["signMsg"]=sign

    resp_data=requests.post(url=url_head+url_tail,data=data).json()
    pprint(resp_data)
query_the_order_information(69262689)

# %% [markdown]
# ### 2.11查询订单信息

# %%
def query_the_order_information(order_id):
    url_tail="/trade/gateway"
    api_name="gateway.trade.queryOrder"
    data={
        "merCode":ID,
         "timestamp":int(time.time()),
         "version":"1.0",
         "signType":"MD5",
         "api":api_name,
         "bizData":json.dumps({"orderId":order_id})}
    md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
    sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
    data["signMsg"]=sign

    resp_data=requests.post(url=url_head+url_tail,data=data).json()
    pprint(resp_data)
query_the_order_information(71150649)
# Out:
# {'api': 'gateway.trade.queryOrder',
#  'code': '0',
#  'data': {'bizCode': '0',
#           'bizMsg': 'SUCCESS',
#           'data': {'cinemaId': 12769,
#                    'exchangeTime': None,
#                    'fixFailTime': None,
#                    'fixSucTime': 1518775910000,
#                    'hallId': 141461,
#                    'lockTime': 1518775826851,
#                    'orderCode': 'bp203643778805406',
#                    'orderId': 71150649,
#                    'orderStatus': '5',
#                    'qrCode': '2018021759021365',
#                    'seatsJSON': '{"count":1,"list":[{"sectionId":"0000000000000001","seatNo":"0000000000000001-4-06","columnId":"06","rowId":"4"}]}',
#                    'sellPrice': '5900',
#                    'settlePrice': '5900',
#                    'showId': '201802170186888',
#                    'ticketCode': '2018021759021365',
#                    'ticketCodeName': '验证码'}},
#  'msg': 'SUCCESS',
#  'version': '1.0'}

# %% [markdown]
# ### 2.12 查询电影信息

# %%
def query_the_movie_information(movie_id):
#     url_tail="/mmdb/gateway"
#     api_name="mmdb.movieInfo"
    url_tail = "/cmdata/gateway"
    api_name = "cmdata.movieInfo"
    data={
        "merCode":ID,
         "timestamp":int(time.time()),
         "version":"1.0",
         "signType":"MD5",
         "api":api_name,
         "bizData":json.dumps({"movieId":movie_id})}
    md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
    sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
    data["signMsg"]=sign

    resp_data=requests.post(url=url_head+url_tail,data=data).json()
    pprint(resp_data)
#     item=resp_data['data']['data']
#     film_id=item.pop("id")
#     c.dev.dianying_film_mao.update_many({"id":film_id},{"$set":item})

# %%
query_the_movie_information(1197732)

# %%
c.static_c

# %% [markdown]
# ### 2.13 查询热映电影列表

# %%
city_id=1

url_tail="/mmdb/gateway"
api_name="mmdb.hotMovies"
data={
    "merCode":ID,
     "timestamp":int(time.time()),
     "version":"1.0",
     "signType":"MD5",
     "api":api_name,
     "bizData":json.dumps({"cityId":city_id})}
md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
data["signMsg"]=sign

requests.post(url=url_head+url_tail,data=data).json()

# %% [markdown]
# ### 2.14 查询待映电影列表

# %%
city_id=1

url_tail="/mmdb/gateway"
api_name="mmdb.comingMovies"
data={
    "merCode":ID,
     "timestamp":int(time.time()),
     "version":"1.0",
     "signType":"MD5",
     "api":api_name,
     "bizData":json.dumps({"cityId":city_id})}
md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
data["signMsg"]=sign

requests.post(url=url_head+url_tail,data=data).json()

# %% [markdown]
# ### 2.15 查询电影热评列表

# %%
movie_id=248911

url_tail="/mmdb/gateway"
api_name="mmdb.hotComments"
data={
    "merCode":ID,
     "timestamp":int(time.time()),
     "version":"1.0",
     "signType":"MD5",
     "api":api_name,
     "bizData":json.dumps({"movieId":movie_id})}
md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
data["signMsg"]=sign

requests.post(url=url_head+url_tail,data=data).json()

# %% [markdown]
# ### 2.16 查询城市列表

# %%
url_tail="/base/gateway"
api_name="base.city"
data={
    "merCode":ID,
     "timestamp":int(time.time()),
     "version":"1.0",
     "signType":"MD5",
     "api":api_name}
md5_str="".join([k+"="+str(v)+"&" for k,v in sorted(data.items())])+"key="+KEY
sign=hashlib.md5(md5_str.encode('utf-8')).hexdigest().upper()
data["signMsg"]=sign
resp = requests.post(url=url_head+url_tail,data=data).json()
resp

# %%
city1={item['name']:item['id'] for item in resp['data']['data']}

# %%
maoyan = requests.get("http://mongorestapi.localdomain:8024/query/citys/dianying/maoyan").json()
city2={item['name']:item['channelCityId'] for item in maoyan['data']}

# %%
for city in city2:
    if city in city1:
        if city2[city] != city1[city]:
            print(city,city2[city],city1[city])

# %%
for item in c.static.dianying_cinema_mao.distinct('cinemaId').extend(c.static.dianying_film_mao.distinct('cinemaId')):
    print(item)
    break

# %%
for item in set(c.static.dianying_cinema_mao.distinct('cinemaId')+c.static.dianying_film_mao.distinct('cinemaId')):
    print(item)
    break

# %%
def filter_dict(coll, filter_value=None):
    if not isinstance(coll, dict):
        return coll
    if not isinstance(filter_value, list):
        filter_value = [filter_value]
    return {key: value for key, value in coll.items() if value not in filter_value}
filter_dict({'a':'','b':None,'c':1},filter_value=[None,''])

# %%
# %%timeit
a=list(range(1000))
b=list(range(100,1100))
set(a+b)

# %%
# %%timeit
a=list(range(1000))
b=list(range(100,1100))
a.extend(b)
set(a)

# %%
# %%timeit
a=set(list(range(1000)))
b=list(range(100,1100))
a.update(set(b))
