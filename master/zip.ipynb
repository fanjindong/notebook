# %%
from connection import ConnectionTask
import gzip,zlib
import sys
import json

c=ConnectionTask()
rrdb = c.prrdb(0)
data = json.dumps(list(c.static_cluster_ctrip.jiudian_hotels_2.find({},{'_id':0},limit=20)),default=str)

# %%
sys.getsizeof(data),sys.getsizeof(gzip.compress(bytes(data,'utf-8'))),sys.getsizeof(zlib.compress(bytes(data,'utf-8')))
# Out:
# (8922150, 180953, 191517)

# %%
# \x1f\x8b\x08\
s=gzip.compress(bytes("{}",'utf-8'))

# %%
# %%timeit
a=gzip.compress(bytes("a",'utf-8'))

# %%
a.encode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-e6028649de51> in <module>()
# ----> 1 a.encode('utf-8')
#
# AttributeError: 'bytes' object has no attribute 'encode'

# %%
b"aaa".startswith(b'\x1f\x8b\x08')
# Out:
# False

# %%
json.loads(bytes(json.dumps({"a":1}),'utf-8'))
# Out:
# {'a': 1}

# %%
# %%timeit
rrdb.set('gzip',gzip.compress(bytes(data,'utf-8')))
resp_cache = rrdb.get('gzip')
if resp_cache.startswith(b'\x1f\x8b\x08'):
    resp_cache = gzip.decompress(resp_cache)
mongo_data = json.loads(resp_cache)
# Out:
# 495 ms ± 20.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
isinstance(rrdb.get('gzip'),bytes)
# Out:
# False

# %%
rrdb.set('gzip','aaa')
# Out:
# True
