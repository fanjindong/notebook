# %%
import json
from pymongo import MongoClient
import logging
import time

class mongodb(object):
    abstract = True
    _loc = None
    _pro=None
    _stg=None
    
    @property
    def loc(self):
        if self._loc is None:
            _loc = MongoClient('mongodb://localhost:27017')
            self._loc = _loc["test"]
        return self._loc
    @property
    def pro(self):
        if self._pro is None:
            _pro = MongoClient('mongodb://mongoc:Boluome123@139.198.1.168:10017/')
            self._pro = _pro["boluome"]
        return self._pro
    @property
    def stg(self):
        if self._stg is None:
            _stg = MongoClient('mongodb://mongoc:Boluome123@139.198.1.168:12017/')
            self._stg = _stg["boluome"]
        return self._stg
m=mongodb()

# %%
with open('city.json','r') as fp:
    old_datas=json.loads(fp.read())

# %%
new_datas=[]
citys_sub=set()
for old_data in old_datas:
    new_data=old_data.copy()
    new_data.pop('Districts')
    new_data['Districts']=[]
    city=new_data['CityCode']
    update_datas=m.stg['jiudian_qunar_hotels'].find({'city':city},['district'])
    for update_data in update_datas:
        city_sub=update_data.get('district','')
        if city_sub:
            if city_sub not in citys_sub:
                citys_sub.add(city_sub)
                new_data['Districts'].append(
                    {'Id': city_sub, 
                     'Name': city_sub})       
    new_datas.append(new_data)
    print(city)
# print(json.dumps(new_datas,ensure_ascii=False,indent=2))
with open('city-districts-stg.json', 'w') as f:
    f.write(json.dumps(new_datas,ensure_ascii=False,indent=2))
# Out:
# beijing_city
# handan
# shijiazhuang
# baoding
# zhangjiakou
# chengde
# tangshan
# langfang
# cangzhou
# hengshui
# xingtai
# qinhuangdao
# shuozhou
# xinzhou
# taiyuan
# changzhi
# datong
# jincheng
# yangquan
# jinzhong
# linfen
# lvliang
# yuncheng
# shenyang
# tieling
# dalian
# anshan
# fushun
# benxi
# dandong
# jinzhou
# yingkou
# fuxin
# liaoyang
# chaoyang
# panjin
# huludao
# changchun
# tonghua
# baicheng
# liaoyuan
# jilin_city
# yanbian
# siping
# songyuan
# baishan
# haerbin
# qiqihaer
# jixi
# mudanjiang
# qitaihe
# jiamusi
# hegang
# shuangyashan
# suihua
# heihe
# daxinganling
# yichun_heilongjiang
# daqing
# nanjing
# wuxi
# zhenjiang
# suzhou_jiangsu
# nantong
# yangzhou
# yancheng
# xuzhou
# huaian
# lianyungang
# changzhou
# taizhou_jiangsu
# suqian
# hangzhou
# huzhou
# jiaxing
# ningbo
# shaoxing
# wenzhou
# lishui
# jinhua
# taizhou_zhejiang
# hefei
# wuhu
# bangbu
# huainan
# maanshan
# huaibei
# tongling
# anqing
# huangshan
# chuzhou
# fuyang_anhui
# ...
