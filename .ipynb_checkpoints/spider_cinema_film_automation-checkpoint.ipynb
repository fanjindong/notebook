# %%
import json
import time
import traceback
import hashlib
import redis
import requests
from pprint import pprint

from pymongo import MongoClient, ReturnDocument


class ZhizhuwangTask():
    # 本地部署，所有和mongo、redis建立链接参数改变
    abstract = True
    _loc = None
    _pro = None  # 生产只可读
    _prow = None  # 生产可读写
    _stg = None
    _dev = None
    _rdb = None

    @property
    def loc(self):
        if self._loc is None:
            _loc = MongoClient('mongodb://localhost:27017')
            self._loc = _loc["boluome"]
        return self._loc

    @property
    def rdb(self):
        if self._rdb is None:
            self._rdb = redis.StrictRedis(
                host='127.0.0.1',
                port='6379',
                db=0,
                charset="utf-8",
                decode_responses=True
            )
        return self._rdb

    @property
    def pro(self):
        if self._pro is None:
            _pro = MongoClient(
                'mongodb://mongoc:Boluome123@139.198.1.168:10017/')
            self._pro = _pro["boluome"]
        return self._pro

    @property
    def prow(self):
        if self._prow is None:
            _prow = MongoClient(
                'mongodb://mongoc:Boluome123@139.198.1.168:10018/')
            self._prow = _prow["boluome"]
        return self._prow

    @property
    def stg(self):
        if self._stg is None:
            _stg = MongoClient(
                'mongodb://mongoc:Boluome123@139.198.1.168:12017/')
            self._stg = _stg["boluome"]
        return self._stg

    @property
    def dev(self):
        if self._dev is None:
            _dev = MongoClient(
                'mongodb://root:Boluome123@139.198.1.168:11017/')
            self._dev = _dev["boluome"]
        return self._dev

server = 'http://filmapi.spider.com.cn/v2/boluomi/'
app_key = 'boluomi'
app_secret = 'BV07RK5W9U3Z'
z=ZhizhuwangTask()

# %% [markdown]
# ## dianying_film_zzw 数据表
# + 13个字段
# + 城市ID获取列表
# + 根据城市ID调用电影院接口，存入数据库

# %%
def city_id_fetch():
    """获取所有城市ID列表，调用cinema接口爬取每个城市电影院信息，存入mongo数据库
    """
    city_url = 'http://filmapi.spider.com.cn/v2/boluomi/cityList.html'
    resp = None
    hstr = "{}{}".format(app_key, app_secret)
    sign = hashlib.md5(hstr.encode('utf-8')).hexdigest()
    post_data = {"key": app_key,
                 "sign": sign,
                 "filetype": "json"}

    try:
        resp = requests.post(city_url, params=post_data)
        resp_data = resp.json()
        city_data = resp_data['data']
    except Exception as e:
        print(e)

    for item in city_data:
        city_id = item['cityId']
        city_id_get_cinema_information(city_id)

# %%
def city_id_get_cinema_information(city_id):
    cinema_url = 'http://filmapi.spider.com.cn/v2/boluomi/cinemaList.html'
    hstr = "{}{}{}".format(city_id, app_key, app_secret)
    sign = hashlib.md5(hstr.encode('utf-8')).hexdigest()
    post_data = {"key": app_key,
                 "cityId": city_id,
                 "sign": sign,
                 "filetype": "json"}

    try:
        resp = requests.post(cinema_url, params=post_data)
        resp_data = resp.json()
        cinema_data = resp_data['data']
        for cinema in cinema_data:
            # cinema_list.add(cinema['cinemaId'])
            z.loc['dianying_cinema_zzw'].update_one(
                {'cinemaId': cinema['cinemaId']}, {'$set': cinema}, upsert=True)
            # mc_stg.boluome.dianying_cinema_zzw.update_one(
            #     {'cinemaId': cinema['cinemaId']}, {'$set': cinema}, upsert=True)
            # mc_pro.boluome.dianying_cinema_zzw.update_one(
            #     {'cinemaId': cinema['cinemaId']}, {'$set': cinema}, upsert=True)
    except Exception as e:
        print(city_id)
        print(traceback.format_exc())

# %% [markdown]
# ## dianying_film_zzw 数据表

# %%
def cinema_id_fetch():
    """从mongo数据库dianying_cinema_zzw表中，拿取电影院ID：cinemaId，分别调用电影信息接口
    """
    ts = time.time()
    range_date = []
    for i in range(5):
        range_date.append(
            time.strftime("%Y-%m-%d", time.localtime(ts + 86400 * i))
        )

    for cinema in z.loc['dianying_cinema_zzw'].find({}, {'_id': 0, 'cinemaId': 1}):
        cinema_id = cinema['cinemaId']
        film_datas_fetch_and_pretreatment(cinema_id)
        cinema_id_get_film_information(cinema_id, range_date)
    return ['cinema_id_fetch function is ok']

# %%
def film_datas_fetch_and_pretreatment(cinema_id):
    """获取所有电影票的数据，并预处理，提出item中的filmId字段建立key-value键值对映射
    """
    film_url = 'http://filmapi.spider.com.cn/v2/boluomi/filmList.html'
    film_id = ''
    hstr = "{}{}{}".format(film_id, app_key, app_secret)
    sign = hashlib.md5(hstr.encode('utf-8')).hexdigest()
    post_data = {"key": app_key,
                 "filmId": film_id,
                 "sign": sign,
                 "filetype": "json"}

#     try:
    resp = requests.post(film_url, params=post_data)
    resp_data = resp.json()
    for item in resp_data['data']:
        item['cinemaId'] = cinema_id
        film_id=item['filmId']
        z.loc['dianying_film_zzw'].update_one(
            {'filmId': film_id,'cinemaId':cinema_id}, {'$set': item},upsert=True
        )
#     except Exception as e:
#         print(traceback.format_exc())
    print(cinema_id,len(resp_data['data']),'is ok')
    return ['dilmList length is ',len(resp_data['data']),'fetch ok!']

# %%
def cinema_id_get_film_information(cinema_id, range_date):
    datas={}
    for date in range_date:
        show_url = 'http://filmapi.spider.com.cn/v2/boluomi/showList.html'
        film_id = ''
        hstr = "{}{}{}{}{}".format(
            cinema_id, film_id, date, app_key, app_secret)
        sign = hashlib.md5(hstr.encode('utf-8')).hexdigest()
        post_data = {"key": app_key,
                     "cinemaId": cinema_id,
                     "filmId": film_id,
                     "showDate": date,
                     "sign": sign,
                     "filetype": "json"}

        resp = requests.post(show_url, params=post_data)
        resp_data = resp.json()
        show_data = resp_data['data']
#         pprint(show_data)
        
        for item in show_data:
            film_id=item['filmId']
            datas.setdefault(film_id,[])
            datas[film_id].append(item)
    for key,value in datas.items():
        z.loc['dianying_film_zzw'].update_one(
            {'filmId': key,'cinemaId':cinema_id}, 
            {'$set': {'plans':value}},
            upsert=True)
#         mc_dev.boluome.dianying_film_zzw.update_one(
#             {'cinemaId': film['cinemaId'], 'filmId': film['filmId']}, {'$set': film}, upsert=True)
#         mc_stg.boluome.dianying_film_zzw.update_one(
#             {'cinemaId': film['cinemaId'], 'filmId': film['filmId']}, {'$set': film}, upsert=True)
#         mc_pro.boluome.dianying_film_zzw.update_one(
#             {'cinemaId': film['cinemaId'], 'filmId': film['filmId']}, {'$set': film}, upsert=True)

# %%
cinema_id_get_film_information('CMT54010204',['2017-02-25','2017-02-26'])

# %%
cinema_id_fetch()
# Out:
# CMT54010204 58 is ok
# {'201701327706': [{'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '04',
#                    'hallName': '民生银行',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336768',
#                    'showTime': '1730',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336619',
#                    'showTime': '1800',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '01',
#                    'hallName': '西藏福彩厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336483',
#                    'showTime': '1900',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '04',
#                    'hallName': '民生银行',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336212',
#                    'showTime': '1920',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336484',
#                    'showTime': '1955',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '05',
#                    'hallName': '星宇通讯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336765',
#                    'showTime': '2020',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '01',
#                    'hallName': '西藏福彩厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336769',
#                    'showTime': '2050',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '04',
#                    'hallName': '民生银行',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336319',
#                    'showTime': '2115',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336213',
#                    'showTime': '2150',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '05',
#                    'hallName': '星宇通讯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336479',
#                    'showTime': '2215',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '01',
#                    'hallName': '西藏福彩厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336618',
#                    'showTime': '2240',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '04',
#                    'hallName': '民生银行',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336376',
#                    'showTime': '2310',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336541',
#                    'showTime': '2345',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-25',
#                    'showId': '0205042188059',
#                    'showTime': '1030',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-25',
#                    'showId': '0205042187999',
#                    'showTime': '1225',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-25',
#                    'showId': '0205042188014',
#                    'showTime': '1415',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-25',
#                    'showId': '0205042188043',
#                    'showTime': '1615',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-26',
#                    'showId': '0205042191620',
#                    'showTime': '1030',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-26',
#                    'showId': '0205042191590',
#                    'showTime': '1225',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-26',
#                    'showId': '0205042191605',
#                    'showTime': '1415',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '100',
#                    'feePrice': '3.00',
#                    'filmId': '201701327706',
#                    'filmName': '生化危机：终章',
#                    'hallId': '03',
#                    'hallName': '奥特莱斯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-26',
#                    'showId': '0205042191664',
#                    'showTime': '1615',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'}],
#  '201701669206': [{'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '110',
#                    'feePrice': '3.00',
#                    'filmId': '201701669206',
#                    'filmName': '极限特工：终极回归',
#                    'hallId': '06',
#                    'hallName': '联通.沃厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336676',
#                    'showTime': '1835',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '110',
#                    'feePrice': '3.00',
#                    'filmId': '201701669206',
#                    'filmName': '极限特工：终极回归',
#                    'hallId': '06',
#                    'hallName': '联通.沃厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336480',
#                    'showTime': '2040',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '110',
#                    'feePrice': '3.00',
#                    'filmId': '201701669206',
#                    'filmName': '极限特工：终极回归',
#                    'hallId': '06',
#                    'hallName': '联通.沃厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336616',
#                    'showTime': '2250',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'}],
#  '201702148770': [{'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '110',
#                    'feePrice': '3.00',
#                    'filmId': '201702148770',
#                    'filmName': '欢乐好声音',
#                    'hallId': '05',
#                    'hallName': '星宇通讯厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336211',
#                    'showTime': '1815',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'}],
#  '201702657170': [{'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '120',
#                    'feePrice': '3.00',
#                    'filmId': '201702657170',
#                    'filmName': '刺客信条',
#                    'hallId': '02',
#                    'hallName': '邮储银行厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336139',
#                    'showTime': '1850',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '120',
#                    'feePrice': '3.00',
#                    'filmId': '201702657170',
#                    'filmName': '刺客信条',
#                    'hallId': '02',
#                    'hallName': '邮储银行厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336544',
#                    'showTime': '2105',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '120',
#                    'feePrice': '3.00',
#                    'filmId': '201702657170',
#                    'filmName': '刺客信条',
#                    'hallId': '02',
#                    'hallName': '邮储银行厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336379',
#                    'showTime': '2320',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '120',
#                    'feePrice': '3.00',
#                    'filmId': '201702657170',
#                    'filmName': '刺客信条',
#                    'hallId': '02',
#                    'hallName': '邮储银行厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-25',
#                    'showId': '0205042188044',
#                    'showTime': '1000',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '120',
#                    'feePrice': '3.00',
#                    'filmId': '201702657170',
#                    'filmName': '刺客信条',
#                    'hallId': '02',
#                    'hallName': '邮储银行厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-25',
#                    'showId': '0205042187984',
#                    'showTime': '1215',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '120',
#                    'feePrice': '3.00',
#                    'filmId': '201702657170',
#                    'filmName': '刺客信条',
#                    'hallId': '02',
#                    'hallName': '邮储银行厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-25',
#                    'showId': '0205042188074',
#                    'showTime': '1430',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '120',
#                    'feePrice': '3.00',
#                    'filmId': '201702657170',
#                    'filmName': '刺客信条',
#                    'hallId': '02',
#                    'hallName': '邮储银行厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-26',
#                    'showId': '0205042191665',
#                    'showTime': '1000',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '120',
#                    'feePrice': '3.00',
#                    'filmId': '201702657170',
#                    'filmName': '刺客信条',
#                    'hallId': '02',
#                    'hallName': '邮储银行厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-26',
#                    'showId': '0205042191575',
#                    'showTime': '1215',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '3D',
#                    'duration': '120',
#                    'feePrice': '3.00',
#                    'filmId': '201702657170',
#                    'filmName': '刺客信条',
#                    'hallId': '02',
#                    'hallName': '邮储银行厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '70.00',
#                    'showDate': '2017-02-26',
#                    'showId': '0205042191635',
#                    'showTime': '1430',
#                    'staPrice': '100.0',
#                    'userPrice': '73.00'}],
#  '201702829870': [{'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '2D',
#                    'duration': '130',
#                    'feePrice': '3.00',
#                    'filmId': '201702829870',
#                    'filmName': '爱乐之城',
#                    'hallId': '07',
#                    'hallName': 'VIP厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '91.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336615',
#                    'showTime': '1745',
#                    'staPrice': '130.0',
#                    'userPrice': '94.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '2D',
#                    'duration': '130',
#                    'feePrice': '3.00',
#                    'filmId': '201702829870',
#                    'filmName': '爱乐之城',
#                    'hallId': '07',
#                    'hallName': 'VIP厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '91.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336764',
#                    'showTime': '2010',
#                    'staPrice': '130.0',
#                    'userPrice': '94.00'},
#                   {'activityId': '',
#                    'cinemaId': 'CMT54010204',
#                    'cinemaName': '星美国际影城-拉萨神力店',
#                    'dimensional': '2D',
#                    'duration': '130',
#                    'feePrice': '3.00',
#                    'filmId': '201702829870',
#                    'filmName': '爱乐之城',
#                    'hallId': '07',
#                    'hallName': 'VIP厅',
#                    'isDiscount': 'n',
#                    'language': '英语',
#                    'merPrice': '91.00',
#                    'showDate': '2017-02-24',
#                    'showId': '0205042336478',
#                    'showTime': '2235',
#                    'staPrice': '130.0',
#                    'userPrice': '94.00'}]}
# ['cinema_id_fetch function is ok']

# %%
cinema_id_get_film_information('SD33033101','201612650770','2017-02-25')
# Out:
# [{'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201702148770',
#   'filmName': '欢乐好声音（中文3D）',
#   'hallId': '4',
#   'hallName': '4号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225DECELQWW',
#   'showTime': '1030',
#   'staPrice': '45.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '6',
#   'hallName': '6号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225VFAGWZ51',
#   'showTime': '1040',
#   'staPrice': '45.0',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '7',
#   'hallName': '7号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225V88TN462',
#   'showTime': '1100',
#   'staPrice': '45.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '2',
#   'hallName': '2号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '01317071702258NF6RNRL',
#   'showTime': '1120',
#   'staPrice': '45.0',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '2D',
#   'duration': '95',
#   'feePrice': '3.00',
#   'filmId': '201702685570',
#   'filmName': '合约男女',
#   'hallId': '1',
#   'hallName': '1号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '32.00',
#   'showDate': '2017-02-25',
#   'showId': '01317071702258Q07WLHC',
#   'showTime': '1140',
#   'staPrice': '40.00',
#   'userPrice': '35.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '3',
#   'hallName': '3号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '01317071702250RN644FB',
#   'showTime': '1200',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '8',
#   'hallName': '8号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '013170717022545LST0S7',
#   'showTime': '1200',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201702148770',
#   'filmName': '欢乐好声音（中文3D）',
#   'hallId': '4',
#   'hallName': '4号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225QFLF2J98',
#   'showTime': '1230',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '6',
#   'hallName': '6号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225W2PTS6A9',
#   'showTime': '1235',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201701669206',
#   'filmName': '极限特工（英文3D）',
#   'hallId': '5',
#   'hallName': '5号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225482202BN',
#   'showTime': '1300',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '7',
#   'hallName': '7号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225JD8RX888',
#   'showTime': '1310',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '2',
#   'hallName': '2号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225BD82B2N6',
#   'showTime': '1315',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '3',
#   'hallName': '3号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225HVN8RF04',
#   'showTime': '1350',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '8',
#   'hallName': '8号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225J0Z4HP64',
#   'showTime': '1410',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201702148770',
#   'filmName': '欢乐好声音（中文3D）',
#   'hallId': '4',
#   'hallName': '4号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '01317071702258OK7EGI0',
#   'showTime': '1430',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '6',
#   'hallName': '6号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225J825OZQX',
#   'showTime': '1430',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201701669206',
#   'filmName': '极限特工（英文3D）',
#   'hallId': '5',
#   'hallName': '5号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225V8R4BT8B',
#   'showTime': '1500',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '2',
#   'hallName': '2号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225N88DHLP8',
#   'showTime': '1510',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '7',
#   'hallName': '7号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '01317071702256848JFN6',
#   'showTime': '1520',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '2D',
#   'duration': '105',
#   'feePrice': '3.00',
#   'filmId': '201701107570',
#   'filmName': '乘风破浪（2D）',
#   'hallId': '1',
#   'hallName': '1号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '01317071702254NZ0X44B',
#   'showTime': '1530',
#   'staPrice': '70.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '3',
#   'hallName': '3号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '01317071702250BT86200',
#   'showTime': '1545',
#   'staPrice': '90.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '8',
#   'hallName': '8号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225XF8F0TT2',
#   'showTime': '1620',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '6',
#   'hallName': '6号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225NX20T9N1',
#   'showTime': '1625',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201702148770',
#   'filmName': '欢乐好声音（中文3D）',
#   'hallId': '4',
#   'hallName': '4号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225HOAEOEAC',
#   'showTime': '1635',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '2',
#   'hallName': '2号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '01317071702252R06V4NB',
#   'showTime': '1705',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201701669206',
#   'filmName': '极限特工（英文3D）',
#   'hallId': '5',
#   'hallName': '5号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225TJNBZ62H',
#   'showTime': '1705',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '7',
#   'hallName': '7号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '013170717022540PRH8X8',
#   'showTime': '1730',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '3',
#   'hallName': '3号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225LJ66X464',
#   'showTime': '1740',
#   'staPrice': '50.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '6',
#   'hallName': '6号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225P82ZRJ04',
#   'showTime': '1820',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '8',
#   'hallName': '8号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225BPPX04RP',
#   'showTime': '1830',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201702148770',
#   'filmName': '欢乐好声音（中文3D）',
#   'hallId': '4',
#   'hallName': '4号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225P4X2J4FF',
#   'showTime': '1840',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '2',
#   'hallName': '2号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '013170717022504H6F8J0',
#   'showTime': '1900',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201701669206',
#   'filmName': '极限特工（英文3D）',
#   'hallId': '5',
#   'hallName': '5号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225HHH0004T',
#   'showTime': '1910',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '3',
#   'hallName': '3号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225PN68D66B',
#   'showTime': '1930',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '7',
#   'hallName': '7号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '01317071702254NV206HB',
#   'showTime': '1940',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '2D',
#   'duration': '105',
#   'feePrice': '3.00',
#   'filmId': '201701107570',
#   'filmName': '乘风破浪（2D）',
#   'hallId': '1',
#   'hallName': '1号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '37.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225L0PZ8Z88',
#   'showTime': '2000',
#   'staPrice': '70.00',
#   'userPrice': '40.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '6',
#   'hallName': '6号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '013170717022540JZRL08',
#   'showTime': '2015',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '8',
#   'hallName': '8号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225J8JD60HB',
#   'showTime': '2040',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '4',
#   'hallName': '4号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225MIBEHPHN',
#   'showTime': '2040',
#   'staPrice': '90.0',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '2',
#   'hallName': '2号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225Z6XVDXLJ',
#   'showTime': '2055',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201701669206',
#   'filmName': '极限特工（英文3D）',
#   'hallId': '5',
#   'hallName': '5号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225DN28ZV68',
#   'showTime': '2115',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '3',
#   'hallName': '3号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225L8868L6X',
#   'showTime': '2125',
#   'staPrice': '90.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '115',
#   'feePrice': '3.00',
#   'filmId': '201702657170',
#   'filmName': '刺客信条（英文3D）',
#   'hallId': '7',
#   'hallName': '7号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '013170717022586BZVL62',
#   'showTime': '2145',
#   'staPrice': '50.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '2D',
#   'duration': '95',
#   'feePrice': '3.00',
#   'filmId': '201702685570',
#   'filmName': '合约男女',
#   'hallId': '1',
#   'hallName': '1号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '32.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225ZV880Z6H',
#   'showTime': '2200',
#   'staPrice': '40.00',
#   'userPrice': '35.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '6',
#   'hallName': '6号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225F0622H0N',
#   'showTime': '2210',
#   'staPrice': '50.0',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '110',
#   'feePrice': '3.00',
#   'filmId': '201701516070',
#   'filmName': '功夫瑜伽（中文3D）',
#   'hallId': '4',
#   'hallName': '4号厅',
#   'isDiscount': 'n',
#   'language': '国语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225XV4UGP2K',
#   'showTime': '2230',
#   'staPrice': '50.00',
#   'userPrice': '45.00'},
#  {'activityId': '',
#   'cinemaId': 'SD33033101',
#   'cinemaName': '嘉善德纳国际影城',
#   'dimensional': '3D',
#   'duration': '100',
#   'feePrice': '3.00',
#   'filmId': '201701327706',
#   'filmName': '生化危机：终章（3D动作）',
#   'hallId': '2',
#   'hallName': '2号厅',
#   'isDiscount': 'n',
#   'language': '英语',
#   'merPrice': '42.00',
#   'showDate': '2017-02-25',
#   'showId': '0131707170225H6DNGUN5',
#   'showTime': '2245',
#   'staPrice': '50.0',
#   'userPrice': '45.00'}]
